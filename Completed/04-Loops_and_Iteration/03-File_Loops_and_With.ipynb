# %% [markdown]
# # 📘 03 - File Loops and `with`
#
# Use `with open(...)` to read files and process content.

# %% [markdown]
# ## ✅ Learning Goals
# - Open and read files using `with`
# - Loop over lines in a file
# - Use `.strip()` and `.split()` to process text

# %%
# %cd sample_data/
# Out:
# /content/sample_data

# %%
# 📝 Sample file read
with open('something.txt', 'r') as file:
    for line in file:
        print(line.strip())
# Out:
# EXT. SPACE
# FADE IN:
# Stars.
# The upbeat show tune, Put On Your Sunday Clothes, plays.
# “Out there, there’s a world outside of Yonkers...”
# More stars.
# Distant galaxies, constellations, nebulas...
# A single planet.
# Drab and brown.
# Moving towards it.
# Pushing through its polluted atmosphere.
# “...Close your eyes and see it glisten...”
# EXT. PLANET’S SURFACE - CONTINUOUS
# A range of mountains takes form in the haze.
# Moving closer.
# The mountains are piles of TRASH.
# The entire surface is nothing but waste.
# “...We’re gonna find adventure in the evening air...”
# A silhouetted city in the distance.
# What looks like skyscrapers turns into trash.
# Thousands of neatly stacked CUBES OF TRASH, stories high.
# Rows and rows of stacked cubes, like city avenues.
# They go on for miles.
# EXT. AVENUE OF TRASH
# “...Beneath your parasol the world is all a smile...”
# Something moving on the ground far below.
# A figure at the foot of a trash heap.
# A SMALL SERVICE ROBOT diligently cubing trash.
# Rusted, ancient.
# Cute.
# Every inch of him engineered for trash compacting.
# Mini-shovel hands collect junk.
# Scoop it into his open chassis.
# His front plate closes slowly, compressing waste.
# A faded label on his corroded chest plate:
# “Waste Allocation Loader - Earth Class” (WALLY)
# Wally spits out a cube of trash.
# Stacks it with the others.
# Something catches his eye.
# Tugs on a piece of metal stuck in the stack.
# A hubcap.
# The sun reflects off it.
# Wally checks the sky.
# ON TRASH HEAP HORIZON
# The sun sets through the smoggy haze.
# “...And we won’t come back until we’ve kissed a girl --”
# He places the hubcap in his compactor.
# Presses a button on his chest.
# The song stops playing.
# The end of a work day.
# Wally attaches a lunch cooler to his back.
# Whistles for his pet COCKROACH.
# The insect hops on his shoulder.
# They motor down from the top of a GIANT TRASH TOWER.
# EXT. AVENUES OF TRASH - DUSK
# Wally travels alone.
# Traverses miles of desolate waste.
# Oblivious to roving storms of toxic weather.
# Passes haunting structures buried within the trash.
# Buildings, highways, entire cities...
# Everything branded with the SAME COMPANY LOGO.
# “Buy N Large”
# “BNL” stores, restaurants, banks...transportation!
# The corporation ran every aspect of life.
# There’s even a BNL LOGO on Wally’s chest plate.
# CLOSE ON NEWSPAPER Wally drives over.
# Headline: “TOO MUCH TRASH!! Earth Covered!!”
# The deck: “BNL CEO Declares Global Emergency!”
# A photo of the BNL CEO giving a weak smile.
# Wally’s old treads are threadbare.
# Practically falling apart.
# Cause a bumpy ride for his cockroach.
# He passes the remains of other RUSTED WALL-E UNITS.
# Fancies one with NEWER TREADS than his own...
# EXT. DESERTED STREET - MOMENTS LATER
# Wally now sports the newer treads.
# Rolls past a SERIES OF HOLOGRAPHIC BILLBOARDS.
# The solar-powered ads still activate when he passes them.
# 2.
# BILLBOARD ANNOUNCER (V.O.)
# (Ad #1: BNL logo over trash)
# Too much garbage in your face?
# (Ad #2: starliner in space)
# There’s plenty of space out in space!
# (Ad #3: starliners take off
# from Earth)
# BNL starliners leaving each day.
# (Ad #4: WALL-E units wave
# goodbye)
# We’ll clean up the mess while you’re
# away.
# EXT. EDGE OF THE CITY
# Wally drives down a deserted overpass.
# Activates an even LARGER HOLOGRAPHIC BILLBOARD.
# CLOSE ON BILLBOARD AD
# Shows off a CITY-SIZED LUXURY STARLINER.
# Depicts passengers enjoying all its amenities.
# BILLBOARD ANNOUNCER (V.O.)
# The jewel of the BNL fleet: “The Axiom”.
# Spend your five year cruise in style.
# Waited on 24 hours a day by our fully
# automated crew, while your Captain and
# Autopilot chart a course for non-stop
# entertainment, fine dining. And with our
# all-access hover chairs, even Grandma can
# join the fun! There’s no need to walk!
# “The Axiom”. Putting the “star” in
# Executive Starliner.
# The BNL CEO appears at the end.
# Waves goodbye as the Axiom takes off.
# BUY N LARGE CEO
# Because, at BNL, space is the final “fun”-
# tier.
# The holographic billboard powers off.
# Reveals the AXIOM’S DESERTED LAUNCHPAD in the distance.
# The mammoth structure sits across the bay.
# Now empty and dry. A polluted, dead valley.
# ON COLLAPSED BRIDGE RAMP
# Near its edge rests a WALL-E UNIT TRANSPORT TRUCK.
# A giant child’s Tonka Truck left to weather the elements.
# A “Buy N Large” logo on its side.
# Wally approaches the rear of the truck.
# 3.
# Pulls on a lever.
# The back lowers.
# Wally motors up the ramp.
# INT. TRUCK - CONTINUOUS
# Open racks for storing WALL-Es line both walls.
# KNICKKNACKS OF FOUND JUNK littered everywhere.
# The tired robot removes his newfound treads.
# Ahh... Home.
# Wally motors down the center aisle.
# Flicks on an ancient BETAMAX PLAYER.
# Jury-rigged to an iPod.
# Pushes in a cassette labeled, “Hello Dolly!”
# The image is very poor quality.
# Actors sing and dance to Put On Your Sunday Clothes (POYSC).
# The same song Wally worked to.
# WALLY
# [Hums POYSC]
# Wally opens his cooler.
# Newfound knickknacks.
# Pulls out the hubcap from his chest.
# Looks back at the TV.
# Mimics the dancers on the screen.
# Pretends the hubcap is a hat.
# Continues to unpack:
# A spork.
# A Rubik’s Cube (unsolved).
# A Zippo Lighter.
# He presses a BUTTON by the rack of shelves.
# They rotate until an empty space appears.
# His new items are lovingly added to the shelf.
# The Zippo joins a pre-existing LIGHTER COLLECTION.
# A new song, It Only Takes A Moment, plays on the video.
# Wally is drawn to it.
# Presses his “Record” button.
# ON TV SCREEN
# Two lovers sing gently to one another.
# They kiss...hold hands...
# Wally tilts his head as he watches.
# Curious.
# Holds his own hands.
# 4.
# EXT. TRUCK - NIGHT
# Wally motors outside.
# Turns over his Igloo cooler to clean it out.
# Pauses to take in the night sky.
# STARS struggle to be seen through the polluted haze.
# Wally presses the “Play” button on his chest.
# The newly sampled It Only Takes A Moment (IOTAM) plays.
# The wind picks up.
# A WARNING LIGHT sounds on Wally’s chest.
# He looks out into the night.
# A RAGING SANDSTORM approaches off the bay...
# Unfazed, Wally heads back in the truck.
# IOTAM still gently playing.
# ...The massive wave of sand roars closer...
# Wally raises the door.
# Pauses.
# WHISTLES for his cockroach to come inside.
# The door shuts just as the storm hits.
# Obliterates everything in view.
# INT. TRUCK - SAME
# Wally alone in the center of his shelter.
# Unwraps a BNL SPONGECAKE (think Twinkie).
# Lays it out for the cockroach to sleep in.
# It happily dives in.
# Wally collapses himself into a storable cube.
# Backs into an empty shelf space.
# Rocks it like a cradle...
# ...and shuts down for the night.
# Outside the wind howls like the Hounds of Hell.
# INT. WALLY’S TRUCK - NEXT MORNING
# Wally’s CHARGE METER flashes “WARNING”.
# He wakes. Unboxes.
# Groggy and lifeless.
# Stumbles outside.
# EXT. ROOF OF WALLY’S TRUCK
# The morning sun.
# Wally fully exposed in its light.
# His front panel splayed out like a tanning shield.
# A solar collector.
# 5.
# His CHARGE METER chimes full.
# Solar panels fold away into hiding.
# Wally, now awake, collects his lunch cooler.
# Heads off to work.
# ...and accidentally runs over the cockroach.
# Horrified, Wally reverses.
# Reveals the FLATTENED INSECT under his tread.
# The cockroach simply pops back to life.
# No biggie. Ready to go.
# Relieved, Wally resumes their commute.
# EXT. WALLY’S WORK SITE - THAT MORNING
# A SERIES OF “WALLY AT WORK” MOMENTS:
# - CU of Wally’s hands digging into garbage.
# CU of trash being scooped into his chest compactor.
# A cube lands by the cockroach.
# - Wally discovers a BRA in the garbage.
# Unsure what it’s for.
# Tries placing it over his eyes, like glasses.
# Tosses it in his cooler.
# - Wally finds a set of CAR KEYS.
# Presses the remote lock.
# Somewhere in the distance a CAR ALARM CHIRPS.
# - Plays with a paddle ball.
# The ball keeps smacking him in the face.
# He doesn’t like it.
# - Wally discovers a DIAMOND RING in a JEWEL CASE.
# Throws out the ring. Keeps the case.
# The jewel case drops into the cooler, then...
# ...A RUBBER DUCKY...
# ...A BOBBLE HEAD DOLL...
# ...An OLD BOOT...
# ...A TROPHY...
# - Wally finds a FIRE EXTINGUISHER.
# Activates it.
# FOAM blasts in his face.
# It’s tossed far, far away from his cooler.
# - Wally’s shovel hand strikes something solid.
# Faces a REFRIGERATOR much larger than himself.
# Now what?
# - CU on fridge door.
# A WELDING BEAM moves down its center.
# It emits from between Wally’s SPLIT BINOCULAR EYES.
# 6.
# The door falls apart in two pieces. Reveals...
# ...a SMALL PLANT
# in its early stage of growth.
# Wally is entranced.
# Carefully, he extracts the section of earth around it.
# CLOSE ON IGLOO COOLER
# Wally gently places the plant inside the old boot.
# Dusts dirt off the leaves.
# EXT. TRUCK - DUSK
# Robot and faithful cockroach return home.
# Wally stops short of the threshold.
# Stares at the ground.
# Continues staring.
# A RED DOT
# quivers on the dirt.
# A single laser point of light.
# Wally moves to touch it...
# ...The dot races along the ground.
# Wally drops his Igloo.
# Chases after the dot.
# EXT. EMPTY BAY
# The dot leads Wally deep into the polluted expanse.
# He is so fixated on it he doesn’t notice
# MANY LASER POINTS
# coming from every direction.
# All racing into the valley over the contour of the terrain.
# Triangulating towards a center.
# Wally’s dot suddenly stops.
# Slowly he reaches for it.
# Can’t grab it. Just light.
# ALL THE DOTS converge in front of him.
# The ground shakes.
# Wally becomes confused.
# Doesn’t see above him.
# The SUN growing brighter behind the cloud cover.
# A noise. Building.
# 7.
# Rocket engines.
# Wally senses he should look to the sky.
# Now THREE SUNS are descending on him.
# Wally runs for it.
# An enormous COLUMN OF FIRE blocks his path.
# A second column of fire.
# A third.
# Trapped.
# Wally cubes the ground beneath him.
# Working fast.
# Noise deafening.
# Heat rising.
# Digs in just as a tide of flame carpets the ground...
# ...Then suddenly quiet.
# Smoke clears.
# CLOSE ON THE SCORCHED EARTH
# Wally’s head rises out of the dirt.
# Glows red hot from the heat.
# Trembles with fright.
# Everything in shadow.
# Something very big looms over him.
# Wally climbs out of his hole.
# Bangs his head on metal.
# WIDE on a massive SPACESHIP.
# Rests ominously in the empty bay.
# A PORTAL on its underside opens.
# Frightened, Wally tries to hide.
# Nowhere to go.
# He places a SMALL ROCK on his head. Boxes up.
# A DEVICE lowers to the ground on a long stem.
# Scans the surface.
# Wally creeps closer for a better look.
# The device unfolds.
# Wally boxes up again.
# A CAPSULE descends from a chute in the stem.
# ROBOT ARMS emerge from the device.
# Place the capsule on the ground. Press buttons.
# The capsule falls away in sections, to reveal...
# ...a PROBE ROBOT.
# It hovers gracefully above the ground.
# White. Egg-shaped.
# 8.
# Blue-lit eyes.
# Female.
# Eve.
# Wally is transfixed.
# Inches closer.
# Watches Eve from behind the device.
# Tilts his head.
# Time stops.
# She’s the most beautiful thing he’s ever seen.
# Eve hovers over the ground.
# A BLUE RAY emits from her front panel.
# Fans out 180 degrees.
# Scans random objects and areas.
# The device rises back into the ship.
# Exposes Wally.
# He rushes for cover behind the nearest rock.
# Never takes his eyes off Eve.
# Watches her float away from the ship.
# ...from the ship?
# The ship!
# Engines roar back to life.
# Wally digging furiously.
# The rocket takes off.
# Smoke clears.
# Again, a red hot Wally peeks out from the ground.
# Looks for Eve.
# She is watching the ship rise into the clouds.
# Waits until it is completely out of sight...
# ...then Eve rises high up into the air.
# She flies around the bay.
# Soars like a graceful bird.
# Does loops in the sky.
# Zooms right past Wally’s rock.
# He is hypnotized.
# Eve descends gently to the ground...
# Wally sneaks up closer.
# Hides behind another boulder.
# Slips.
# Makes a NOISE.
# Instantly, Eve whips around.
# Her arm converts into a LASER CANNON.
# Blasts Wally’s boulder to smithereens.
# ...Smoke clears...All quiet.
# Eve, now cold and dangerous.
# 9.
# Scans the area.
# No sign of life.
# All business again.
# Hovers away to probe more of the planet.
# ON OTHER SIDE OF BOULDER CRATER
# Wally boxed up behind what little remains of the rock.
# Trembles uncontrollably.
# EXT. AVENUE OF TRASH - DAY
# Eve wanders through the pillars of cubed trash.
# Scans random areas.
# Wally spies from the shadows.
# Too frightened to approach.
# She moves on. He follows.
# EXT. TIRE DUMP - DAY
# Eve probes a mound of tires.
# Wally hiding nearby.
# He flinches at the sight of
# HIS COCKROACH
# innocently approaching Eve from behind.
# She spins around.
# Blasts the insect.
# Wally is gut-punched.
# The cockroach climbs out of the smoking crater.
# Unscathed. Still curious.
# Eve finds the insect intriguing.
# Lowers her arm.
# The end separates into individual hovering sections...
# ...A HAND.
# She lets the insect crawl up her arm.
# Wiggles into her workings.
# It tickles.
# EVE
# [Giggles]
# Wally relaxes.
# CHUCKLES privately.
# Eve sonically picks up Wally’s location.
# Locks onto him.
# 10.
# Arm converts to laser cannon.
# Fires rapidly.
# Quick glimpses of Wally dodging the blasts.
# Trash piles are systematically obliterated around him.
# Wally now exposed.
# Nowhere to hide.
# Boxes himself up. Shakes uncontrollably.
# Eve holds her fire.
# EVE
# (electronic hums)
# [Identify yourself.]
# She slowly approaches Wally’s box.
# Keeps her gun trained on him.
# EVE
# (electronic hums)
# [Repeat. Identify yourself.]
# Wally peeks out from his box.
# Doesn’t understand a thing she says.
# Doesn’t care.
# Can’t believe she’s real.
# The cockroach climbs down her gun arm.
# Jumps onto his master.
# Eve scans Wally.
# A RED LIGHT appears on her chest.
# Buzzes “negative”.
# He’s not what she’s looking for.
# She retracts her gun arm.
# Hovers off.
# Wally watches her go. Lovestruck.
# WALLY
# [Sigh.]
# DISSOLVE TO:
# INT. ABANDONED BNL SUPERSTORE - NEXT DAY
# LOUIS ARMSTRONG’S “LA VIE EN ROSE” PLAYS
# Eve scans through the market.
# Wally follows from a safe distance.
# A stray puppy-dog.
# Eve glances over at him.
# Wally panics.
# Bumps into a RACK OF SHOPPING CARTS.
# Creates an avalanche.
# 11.
# They chase him down a flight of stairs.
# Wally reaches the exit doors.
# Won’t open!
# Carts pig pile on top of him.
# EXT. BNL REFINERY - NIGHT
# Wally perched on the roof.
# Patiently watches Eve fly.
# She scans the ground below her, like a searchlight.
# Eve comes in for a landing below.
# Shuts down for the night.
# Wally waits.
# Quietly sneaks down the refinery fire escape.
# Accidentally trips. Tumbles to the ground.
# Eve doesn’t wake.
# Wally creeps up to her.
# Opens his arms wide...
# ...and measures her.
# Turns to a pile of trash.
# Splits open his eyes. Begins welding something...
# DISSOLVE TO:
# EXT. BNL REFINERY - NEXT MORNING
# Eve powers up again.
# Does a double take.
# A TRASH SCULPTURE OF EVE stands in front of her.
# She hovers away, unimpressed.
# Doesn’t notice Wally hiding behind a PILE OF PIPES.
# Wally kicks the pipes in frustration.
# They roll on top of him.
# SONG ENDS
# MONTAGE OF EVE SEARCHING
# - Scans a car engine.
# Negative.
# Slams the hood shut.
# - Scans a Port-A-Potty.
# Negative.
# Slams the door shut.
# - Scans an Apollo capsule.
# Negative.
# Slams the hatch shut.
# - Scans a FREIGHTER HOLD.
# 12.
# Negative.
# Slams the lid shut.
# EXT. DERELICT SHIPYARD - DUSK
# Eve hovers over the freighter.
# Frustrated.
# Not finding what she’s looking for.
# Wally eavesdrops from afar.
# Eve flies past the ship’s CRANE MAGNET.
# Gets stuck.
# Wrestles to free herself.
# Furious, she BLOWS UP THE ENTIRE SHIP.
# The reaction startles Wally.
# Eve slumps down against a dredged anchor.
# She gives up.
# Concerned, Wally cautiously approaches.
# Sits at the other end of the anchor.
# Both robots stare silently at the fiery wreck.
# Then...
# ...slowly, very slowly, Wally inches towards her.
# Musters the courage to speak, when --
# She suddenly turns to him:
# EVE
# (hums)
# [So what’s your story?]
# Wally falls backwards with surprise.
# Me?
# Eve scrolls through a variety of languages:
# EVE
# (German)
# [Directive?]
# (Japanese)
# [Directive?]
# WALLY
# [Huh?]
# EVE
# (Swahili)
# [Directive?]
# (English)
# Directive?
# WALLY
# (beeps)
# [Oh, I understand that!]
# 13.
# EVE
# Directive?
# Wally eagerly turns to some nearby trash.
# Scoops it into his compactor.
# Proudly spits out a cube.
# Points to Eve.
# WALLY
# (struggles to speak)
# Di...rec...t--
# EVE
# Directive?
# Wally nods.
# EVE
# Classified.
# WALLY
# (beeps)
# [Oh. Sorry.]
# She scans his CHEST LOGO.
# EVE
# Name?
# WALLY
# (struggles again)
# W-wally? ...Wally.
# EVE
# (smooth; almost perfect)
# Wwww-aaaa-leee...
# Wally nearly melts.
# She says his name so beautifully.
# Moves closer.
# EVE
# Wally.
# (giggles)
# Eve.
# Wally tries to repeat it:
# WALLY
# Eeee...?
# EVE
# (slower)
# Eve.
# 14.
# WALLY
# Eeeaaah?
# EVE
# Eeeve. Eeeve.
# WALLY
# Eee--vah!
# She giggles again.
# Wally likes making her giggle.
# WALLY
# Eee-vah! Ee --
# EVE
# Eve.
# The wind kicks up.
# The WARNING LIGHT sounds on Wally’s chest.
# He moves to grab her.
# WALLY
# (Gasp!) Eee-vah!
# EVE
# (hums)
# [Hey watch it! Don’t come any closer!]
# She draws her gun on him.
# Doesn’t understand the danger.
# The sandstorm rushes up behind her.
# Too late.
# Wally collapses into a box.
# The storm hits full force.
# Eve is instantly lost, disoriented.
# EVE
# Wally? Wally?
# WALLY’S HAND appears out of the dust.
# Calmly takes Eve’s hand.
# INT. TRUCK - MOMENTS LATER
# The back door lowers.
# A rush of wind and sand.
# Wally pulls Eve inside. Closes the door.
# She coughs up dust.
# Wally hits a switch...
# Strings of CHRISTMAS LIGHTS fill the space.
# His racks of oddities painted in colored light.
# 15.
# An air of enchantment.
# Eve is taken aback.
# WALLY
# (beeps)
# [Come on in.]
# She drifts through the sea of knickknacks.
# Becomes spooked by a SINGING BILLY BASS FISH.
# Threatens to shoot it, but Wally calms her down.
# He is compelled to show her everything.
# Hands her an eggbeater...
# ...bubble wrap (so infectious to pop)...
# ...a lightbulb (lights when she holds it)...
# ...the Rubik’s Cube (she solves it immediately)...
# ...his Hello Dolly tape.
# Curious, she begins unspooling the tape.
# WALLY
# (loud beeps)
# [My tape!!]
# He grabs it back. Protective.
# Inserts it carefully into the VCR. Please still work.
# The movie eventually appears on the TV.
# Plays a clip of POYSC.
# Wally is relieved.
# WALLY
# (beeps)
# [What do you think?]
# Mimics the dancing for Eve.
# Encourages her to try.
# She clumsily hops up and down.
# Makes dents in the floor. Rattles everything.
# Wally politely stops her.
# WALLY
# (beeps)
# [How ‘bout we try a different move?]
# Spins in a circle. Arms out.
# Eve copies.
# Spins faster, and faster...
# Too fast.
# Accidentally strikes Wally. He flies into the shelves.
# Eve helps him up from the mess.
# Wally’s LEFT BINOCULAR EYE falls off.
# Dangles from two wires.
# Eve GASPS with concern.
# Wally placates her.
# 16.
# WALLY
# (beeps)
# [It’s fine.]
# Feels his way to the rack of shelves.
# Rotates them until...
# ...SPARE WALL-E PARTS appear.
# Replaces his broken eye with a new one.
# Eve is relieved.
# She eyes his LIGHTER COLLECTION.
# Flicks open a Zippo. Ignites a FLAME.
# Wally freezes.
# He had no idea it could do that.
# Moves closer to inspect it...
# ON WALLY
# It’s the closest he’s ever been to Eve.
# She remains focused on the lighter.
# Wally stares up at her.
# ...The tiny flame flickering between them...
# ...The Hello Dolly video plays IOTAM in the background...
# Suddenly, he is moved to express his love.
# Musters the courage to open his fingers...
# ...Timidly reaches his hand out to hers...
# -- Eve turns and looks at him.
# Wally instantly chokes.
# Pulls his hand back.
# Eve becomes intrigued with the TV.
# Scans the image of the lovers singing IOTAM...
# Wally watches her.
# His infatuation still palpable.
# Then he remembers...
# WALLY
# Ee-vah!
# He rushes to his shelves.
# Eve watches him rummage through junk.
# A drum falls down on his head.
# She giggles, charmed by it all.
# Something about Wally...
# She is drawn back to the lovers on TV...
# ...then the lit Zippo lighter in her hand.
# A tap on her shoulder.
# She turns to find Wally holding something.
# The plant.
# Eve immediately locks onto it.
# 17.
# Drops the lighter.
# In a flash...
# ...her chest opens...
# ...a TRACTOR BEAM snatches the plant away...
# ...stores it inside her...
# Then she shuts down completely.
# Only a SINGLE GREEN LIGHT pulsing on her chest.
# Wally is stunned.
# What’d I do?
# Waves his hand in front of her face.
# WALLY
# Ee-vah?
# Knocks on her chest plate.
# No response.
# Wally panics.
# Gently shakes her.
# WALLY
# Ee-vah?
# Still no response.
# WALLY
# Ee-vah? ...Ee-vah?!
# CAMERA MOVES IN on the blinking green light...
# DISSOLVE TO:
# EXT. ROOF OF WALLY’S TRUCK - DAY
# The morning sun.
# Wally places Eve in his charging spot.
# Aims her hovering form to face the sun.
# Waits.
# MONTAGE OF WALLY TRYING TO REVIVE EVE:
# - Several hot days pass with Wally holding vigil in the heat.
# - A THUNDERSTORM approaches on the horizon.
# Wally holds an UMBRELLA over Eve.
# Gets struck by lightning.
# Holds up another umbrella.
# Gets struck again.
# - A SANDSTORM blows through.
# Wally pops out of a dune on the truck’s roof.
# Lifts up an UPSIDE-DOWN BARREL that protected Eve.
# 18.
# - Wally pries open a panel on Eve’s chest.
# Reveals her pulsing BLUE HEART-BATTERY.
# Attaches JUMPER CABLES to his own HEART-BATTERY.
# Tries to connect the other end to hers.
# An automatic defense system blows him off truck.
# - Wally & cockroach take Eve for a walk.
# Pull her along on a LEASH OF CHRISTMAS LIGHTS.
# - Wally gives Eve a boat ride on a LAKE OF SLUDGE.
# Uses an industrial tire as a boat.
# Rows like a gondolier with a road sign.
# - Wally sits by the empty bay with Eve.
# Watches the SUNSET.
# Burns “WALL-E + EVE” on a public trash can.
# Tries to pull out her hand to hold it.
# It snaps back into place, trapping his hand.
# END OF MONTAGE
# EXT. ROOF OF WALLY’S TRUCK - NIGHT
# Wally has set up the TV on the roof.
# The blank Eve floating next to him.
# Tries unsuccessfully to play PONG with her.
# Still no response.
# Finally, he gives up.
# WALLY
# [defeated sigh]
# EXT. TRUCK - NEXT MORNING
# Wally loads up his cooler.
# Checks on Eve one more time.
# Still nothing...
# Heads off to work, defeated.
# EXT. WORK SITE - LATER
# Wally simply going through the motions.
# No spirit in him at all.
# Stops.
# Pulls out the Zippo lighter.
# Flicks it a few times.
# A RUSH OF WIND blows out the flame.
# Distant rumbling.
# Wally looks in the direction of his home.
# A BRIGHT GLOW is lowering down through the clouds.
# 19.
# WALLY
# (beeps)
# [Oh no.]
# EXT. TRASH ALLEY - DAY
# Wally racing as fast as he can.
# The cockroach clings onto him for dear life.
# EXT. TRUCK - DAY
# The RECON SPACESHIP towers over his truck.
# A ROBOT ARM cherry-picks Eve from the roof.
# Lifts her up and into the ship’s cargo hold.
# Wally racing in the distance.
# WALLY
# EE-VAH!! EE-VAH!!
# Reaches the end of the collapsed bridge ramp.
# Forced to watch Eve disappear into the ship.
# The cargo doors slam shut.
# The first of the THREE ROCKET ENGINES powers up.
# Wally heads down a hill of rubble to the ship.
# Notices his cockroach tagging along behind him.
# Leads it back to the top of the hill.
# WALLY
# (beeps)
# [Stay.]
# The insect mopes.
# Droops its little antennae.
# Wally motors back down to the rocket...
# BASE OF RECON SHIP
# The engines blast a WALL OF SMOKE.
# Preparation for launch...
# INT. RECON SHIP
# Eve is secured into a slot.
# Joins a ROW OF OTHER EVE PROBES.
# All dormant.
# Only Eve flashes a GREEN LIGHT.
# The CAMERA DRIFTS BACK out a window...
# OUTSIDE THE SHIP
# 20.
# ...where Wally steadily climbs up the side.
# The ship’s engines ignite.
# Wally clamps his hands tight to a metal support.
# The rocket takes off into space.
# EXT. TOP OF HILL
# The cockroach watches his master go.
# EXT. RECON SHIP
# The spaceship roars through the sky.
# Wally tightens his grip, battling the G’s.
# He looks ahead. SCREAMS.
# HUNDREDS OF BNL SATELLITES
# litter the outer atmosphere.
# The ship bursts through the layer.
# EXT. SPACE - CONTINUOUS
# The recon ship breaks free of the planet.
# Its boosters shut down.
# Wally takes in the sudden QUIETNESS OF SPACE.
# Looks back at his planet.
# WALLY
# Oooh...
# Weightlessness takes effect.
# Wally almost floats away.
# Grabs hold of the ship.
# Knocks on a WINDOW near Eve.
# WALLY
# E-vah!
# No response. She remains shut down.
# Wally points out at the stars.
# It is the most spectacular light show possible.
# And Wally has a front row seat.
# MONTAGE OF CELESTIAL SPECTACLES
# - The ship flies past the MOON.
# A BILLBOARD stands next to the abandoned APOLLO MOON ROVER.
# “BNL Outlet Coming Soon.”
# - The ship passes by the SUN.
# Wally pops open his solar panels.
# 21.
# Instantly recharges.
# - The ship cruises alongside SATURN’S OUTER RINGS.
# Wally runs his hand through the tiny particles of ice.
# DISSOLVE TO:
# EXT. RECON SHIP - DAYS LATER
# A DUMBBELL NEBULA slowly twists in space.
# Wally is mesmerized by it.
# Leads his eye to a LIGHT, growing in the distance ahead.
# A planet?
# No. A starliner.
# Gigantic in size.
# The “AXIOM”.
# The now tiny recon ship heads straight for it.
# INT. DOCKING BAY
# TWO TUG-ROCKETS guide the ship in.
# It locks into GIANT BRACES fixed on the deck.
# The impact knocks Wally off.
# He lands in the scaffolding of the front brace.
# Suddenly the entire dock comes to life.
# Robotic arms and service robots of all types appear.
# ...Rise from the floor...
# ..Lower from the ceiling...
# It’s a cacophony of automation.
# They all attend to the ship.
# EVE
# and four other probes slide out of the ship’s side.
# Suspended in a horizontal rack.
# Wally is surprised to find her facing him.
# She remains shut down.
# Just a few feet away with a giant abyss between them.
# WALLY
# Ee-vah... ?
# A SQUAD OF CLEANER ROBOTS emerge onto the dock.
# A small roller BRUSH-BOT (M-O) leads.
# M-O
# (beeps)
# [Hold up.]
# 22.
# Waits for the FLOOR LINES to appear.
# Depict their exact path of action.
# M-O
# (beeps)
# [Okay. Go.]
# They file out on the line.
# A crane-bot lowers Eve from the rack.
# M-O and his cleaning crew stand ready.
# M-O scans Eve.
# ON M-O’S DISPLAY POV
# Scan reads: “%16 Foreign Contaminant.”
# M-O is disgusted.
# Revs his brush roller. Moves in for the clean.
# A VACU-BOT follows after him.
# Then a SPRAY-BOT and BUFFER-BOT finish off.
# The cleaning crew waits for probe #2.
# Wally studies the routine.
# Figures out a way to climb down to Eve.
# When the crane returns, Wally poses as probe #3.
# The crane grabs him instead.
# M-O turns around to clean the next probe.
# Wally is lowered in front of him.
# Boxes up.
# Confused, M-O scans him.
# ON M-O’S DISPLAY POV
# Scan reads: “%100 Foreign Contaminant.”
# M-O is horrified by such filth.
# A RED SIREN LIGHT rises from his head.
# M-O
# [Oh, no, no, no. This is all wrong.]
# He scrubs Wally full force.
# Wally’s front panel pushes him away.
# Confused, M-O moves to clean him again.
# Wally backs away.
# Leaves a DIRT TRAIL.
# M-O curses:
# M-O
# [You made the floor all dirty! Stop it!]
# 23.
# M-O furiously scrubs the floor.
# Wally peeks out, amused by this neurotic little guy.
# ON FAR WALL
# Two STEWARD ROBOTS come out of the wall.
# Act like hovering caution signs.
# A small robot (GOPHER) shoots out a PNEUMATIC TUBE.
# He bears epaulet like shoulders and a siren for a face.
# Gopher beeps an ELECTRONIC ORDER for the Stewards to follow.
# BACK ON M-O AND WALLY
# M-O just finishes cleaning the floor.
# Wally is fascinated.
# Impishly makes another mark.
# M-O compulsively cleans it. Can’t resist.
# M-O
# [Look, it stays clean. You got that?]
# Wally wipes the bottom of his tread on M-O’s face.
# M-O loses it.
# Scrubs his own face.
# Gopher and his steward escort arrive.
# The cleaning crew stand at attention.
# Wally boxes back up with the probes.
# Gopher begins scanning each probe.
# Moves down the line.
# Scans Wally...moves on to the next probe...
# Stops -- Wait a minute.
# Turns back.
# Wally is gone.
# Gopher shrugs it off. Proceeds...
# Reaches Eve.
# Doesn’t notice Wally hidden behind her.
# Gopher scans her BLINKING PLANT LIGHT --
# The entire dock goes to “Code Green”!
# Alarms sound.
# Green lights flash.
# All automation stops.
# In rapid succession...
# ...A HOVER-TRANSPORT glides up to Gopher...
# ...A crane-bot loads Eve...
# ...Curved energy bands lock her down...
# ...Gopher assumes the driver’s seat...
# It’s all moving too fast for Wally.
# Suddenly Eve’s transport heads for the ELEVATOR.
# 24.
# WALLY
# Ee-vah!
# Wally chases after them.
# Grabs onto the back of the transport.
# They disappear into the elevator.
# The cleaning crew files out.
# Follow their lines back to their hold.
# M-O stops short.
# Notices Wally’s FILTHY TRACKS crossing his path.
# ON M-O’S DISPLAY
# Reads: “FOREIGN CONTAMINANT”
# The tracks lead to the elevator.
# M-O’s neurosis takes over.
# Must clean dirt.
# He makes a radical decision and...
# ...jumps off his line.
# Starts methodically cleaning the dirt trail.
# INT. ELEVATOR
# Gopher waits patiently as the floors pass.
# Wally hidden behind the transport.
# Peeks at Eve.
# Pets her blank faceplate.
# WALLY
# (quiet beeps)
# [It’ll be okay, Eve.]
# The ELEVATOR DOORS suddenly open.
# INT. ROBOT SERVICE TUNNEL - CONTINUOUS
# DOZENS OF ROBOTS speed along a multi-lane passageway.
# All following glowing lines on the floor.
# Wally’s head whipsaws back and forth.
# Tries to process it all.
# Doesn’t notice Gopher’s transport merge into traffic...
# ...without him!
# Wally shrinks from the high-speed traffic.
# Timidly attempts to merge.
# Sticks out one tread...
# -- Instantly causes a ROBOT PILE-UP.
# Wally boxes up. Guns it.
# Weaves across all the lines on the floor.
# Bounces off robots like bumper cars.
# 25.
# Barely able to navigate the chaos.
# Takes refuge in the middle of an INTERSECTION.
# Scans for Eve...
# ON WALLY’S POV DISPLAY
# ...a PAINT-BOT paints a wall sign...
# ...A GARBAGE-BOT dumps trash into a wall chute...
# ...Down the hall, Eve’s transport glides up a ramp...
# WALLY
# EE-VAH!
# Wally chases after them.
# INT. UPPER HALLWAY - CONTINUOUS
# Wally flies up the ramp.
# Nearly collides with a merging HOVER CHAIR.
# It blocks his way.
# Wally gains alongside it, and discovers
# A HUMAN PASSENGER
# sitting, reclined, in the chair.
# He is large, round and soft - like a big baby.
# Wears a red, BNL jumpsuit.
# The chair seems to be steering itself.
# Guided by floor lines, just like the robots.
# Speaker headrests block his peripheral vision.
# A HOLOGRAPHIC SCREEN floats inches in front of his face.
# He converses with a SECOND PASSENGER on screen:
# PASSENGER #1
# Well, I’ve been in my cabin all morning
# so let’s hover over to the driving range
# and hit a few virtual balls into space.
# PASSENGER #2 (ON SCREEN)
# Nah, we did that yesterday. I don’t want
# to do that.
# PASSENGER #1
# Well then what do you want to do?
# ON WALLY
# He looks over his shoulder.
# Passenger #2 is floating right next to them.
# Isolated in his own hover chair.
# Also in a red jumpsuit. Also a big baby.
# 26.
# PASSENGER #2
# I don’t know. Something.
# Both humans are totally unaware of the other’s presence.
# They all exit the hallway. Merge into the...
# ECONOMY CLASS COURTYARD
# Wally is in awe.
# Hundreds of floors of GUEST ROOMS rise on all sides.
# THOUSANDS OF PASSENGERS fill the giant space.
# All reclined and riding on hover chairs.
# MULTIPLE FLOOR LINES guide their chairs in all directions.
# Humans have become the most extreme form of couch potatoes.
# Absolutely no reason to ever get up.
# No purpose.
# Every one of them engrossed in their video screens.
# Cocooned in virtual worlds.
# Over-developed fingers tap ARMREST KEYPADS.
# The controls allow them to steer...
# ...order food...
# ...play games...
# ...and most of all...
# ...CHAT MINDLESSLY with other passengers:
# The CHATTER is deafening.
# No one notices Wally at all.
# He drives into the endless human traffic.
# MISC. FEMALE PASSENGER
# Bot, over here!
# A DRINK-BOT floats over to a passenger.
# Puts a fresh drink in her open hand.
# Wally flows with the traffic into a LARGE TUNNEL.
# MISC. PASSENGERS
# I can’t hear you...I’m in a tunnel.
# You’re breaking up...Oh, okay. You’re
# back. I can hear you now...
# They spill out into the BRIGHT LIGHT of the
# MAIN CONCOURSE (COACH CLASS)
# A city-sized, mall-like environment.
# All under a GIANT DOME.
# The ceiling simulates the sun and sky.
# A BNL LOGO (w/ time & temp) appears on the FACE OF THE SUN.
# 27.
# SHIP’S COMPUTER (V.O.)
# Buy N Large. Everything you need to be
# happy. Your day is very important to us.
# Wally is gobsmacked.
# A PASSENGER (JOHN) hovers up alongside him.
# Tries to hand off his empty drink cup to Wally.
# JOHN
# Hey, Drink-bot.
# Wally shies away.
# John reaches farther out with the cup.
# JOHN
# Here, take the cup. Take the cup -- Whoa!
# Reaches too far.
# John falls to the floor.
# Flails like an upside down turtle.
# Unable to stand on his baby legs.
# Instantly, SIRENS.
# Wally watches TWO STEWARDS arrive.
# Block John’s accident.
# EMERGENCY LINES appear on the floor.
# Redirect the hover chair traffic.
# John reaches out for assistance.
# Nobody notices. Just drive past.
# JOHN
# Stewards? Hello? Uhh, help.
# STEWARD
# Please remain stationary. A service-bot
# will be here to assist you momentarily.
# Suddenly John begins to rise.
# JOHN
# Uhh...Hey! What’s going on?
# Wally lifting him up from behind.
# Loads him back onto his chair.
# John doesn’t know how to react.
# Wally waves hello.
# WALLY
# Wally!
# JOHN
# Uhh... John.
# 28.
# WALLY
# Ee-vah?
# JOHN
# Uh no, John.
# Wally scans the concourse.
# Spots Eve’s transport about to board a MONORAIL.
# He races after them.
# Abandons the stunned John.
# WALLY
# Ee-vah!
# JOHN
# (small wave)
# Bye...Wally.
# ON MONORAIL
# It pulls out of the station.
# Wally leaps on.
# Barely catches the last car.
# It glides down the concourse.
# INT. “ALL DAY” CARE CENTER
# A NANNY-BOT supervises a group of TODDLERS.
# All wearing matching BNL ONESIES.
# Motionless in their HOVER RINGS.
# They stare at educational programming on their holo-screens.
# NANNY-BOT
# “A”! “A” is for “Axiom”, your home sweet
# home. “B”! “B” is for “Buy N Large”, your
# very best friend...
# OUT THE WINDOW
# Wally’s monorail glides past.
# ON MONORAIL
# Wally takes in the overstimulating scenery.
# Dozens of THEMED FOOD RESTAURANTS whizz by.
# Each specialty is served in the same JUMBO PLASTIC CUP.
# SHIP’S COMPUTER (V.O.)
# Mmmmm! Time for lunch in a cup.
# Wally now notices his fellow passengers.
# They all slurp from similar cups.
# 29.
# Next, the monorail passes a BEAUTY SALON.
# BEAUTICIAN-BOTS primp and style passengers.
# SHIP’S COMPUTER (V.O.)
# Feel beautiful.
# BEAUTICIAN-BOTS
# (pre-recorded lines)
# ...It’s the new you...Oh stunning...You
# look great...I know honey...Ahh. Men...
# They pass through the FASHION DISTRICT.
# ENORMOUS BILLBOARDS hawk the latest color schemes.
# SHIP’S COMPUTER (V.O.)
# Attention, Axiom shoppers. Try blue! It’s
# the new red!
# MONORAIL PASSENGERS
# Oooohh...
# Passengers next to Wally press their chair buttons.
# Their JUMPSUITS change from RED TO BLUE.
# WALLY
# Whoa.
# Their monorail speeds into a glass tunnel.
# INSIDE THE TUNNEL
# Wally looks past a PASSENGER (MARY) next to him.
# Spots Eve on the other side.
# Wally tries to sneak behind Mary.
# But her chair moves backwards.
# Smashes Wally against the back wall.
# No way getting past her.
# Wally politely tries to get Mary’s attention.
# She’s oblivious.
# Chats incessantly on her holo-screen:
# MARY
# Date?! (derisive snort) Don't get me
# started! Every holo-date I've been on has
# been a virtual disaster! If I could just
# meet one who wasn't so superficial. There
# are no good men out there!...
# Wally tries to fold back her speaker headrest.
# Accidentally breaks it off.
# MARY (CONT’D)
# ...I know! I know ‘cause I've scrolled
# through them all -- (Gasp) What the --?
# 30.
# Mary’s chair shorts out.
# ...holo-screen shuts off...
# ...jumpsuit defaults back to red...
# For the first time Mary has an unobstructed view.
# Her eyes slowly dilate.
# It’s as if she’s seeing the world for the first time...
# MARY
# (mesmerized)
# Huh... ?
# Her gaze falls on Wally.
# He waves politely.
# WALLY
# Wally.
# MARY
# (beat)
# M-mary.
# WALLY
# Ee-vah.
# He points to Eve on the other side of Mary.
# Gestures he’d like to get by.
# She is slow to understand.
# MARY
# Huh? Oh, uh, sure go ahead.
# Mary moves her hover chair back.
# Wally rolls over to Eve.
# Pats her protectively.
# WALLY
# Ee-vah...
# INT. AXIOM/LIDO DECK - DAY
# The monorail emerges into “First Class.”
# A vast, circular plaza of pools.
# Surrounded by a ring of high rise apartments.
# Hundreds of passengers lounge poolside.
# All serviced by their personal UMBRELLA-BOTS.
# POOLSIDE PASSENGER
# (claps; umbrella-bot opens)
# Shade.
# ON MONORAIL
# It stops at the BRIDGE PLAZA.
# 31.
# The base of the Axiom’s Bridge Tower.
# The passengers exit.
# Follow their respective lines.
# Gopher drives Eve (and Wally) towards the tower.
# Pass over a GIANT BNL LOGO on the plaza floor.
# ON MARY
# She is the last to exit the car.
# Doesn’t follow any lines.
# Excited by her newfound awareness.
# Looks out on the Lido Deck as the monorail pulls away.
# MARY
# I didn’t know we had a pool!
# INT. BRIDGE LOBBY
# Eve’s transport enters the cavernous hall.
# A lone TYPING-BOT is stationed at the far end.
# A bridge elevator behind him.
# Blocked by a force field gate.
# The transport pulls up to the typing-bot.
# Gopher BEEPS.
# The typing-bot responds by typing.
# Slowly. One...button...at...a...time...
# Finally, the gate lowers. Elevator doors open.
# The typing-bot watches the transport enter the elevator.
# Notices Wally hiding at the back.
# Wally gives it a FRIENDLY WAVE as the doors close.
# The elevator shoots up to the bridge.
# The typing-bot looks at its hand.
# Mimics Wally’s waving gesture.
# Huh. Never done that before.
# Tries it some more...
# INSIDE THE ELEVATOR
# Wally looks out on the descending Lido Deck.
# Marvels at it all.
# His view suddenly goes dark.
# The elevator doors open on...
# INT. BRIDGE - CONTINUOUS
# The large circular room is dimly lit.
# Windows to SPACE on one side, a LIDO DECK view on the other.
# A massive console wraps around its entirety.
# Covered in buttons. A sea of thinking lights.
# 32.
# A CAPTAIN’S WHEEL automatically steers.
# Gopher drives into the middle of the room. Beeps.
# Suddenly the wheel disengages.
# The autopilot (AUTO).
# A single camera eye lights up its center.
# A periscope stem connects Auto to the ceiling.
# Slides along rails up to Gopher, who salutes.
# Auto eyes Eve. Scans her.
# Wally sneaks back into the shadows.
# Auto detects Eve’s plant light.
# Goes still...
# Begins computing rapidly.
# The number “A113” flashes on his lens.
# An ELECTRONIC EXCHANGE begins between Auto and Gopher.
# Wally watches the interchange. Nervous.
# Without warning, Auto heads in his direction.
# Wally boxes up.
# A CIRCULAR SECTION OF FLOOR lights directly below him.
# Irises open, like a trapdoor.
# Wally drops...
# INT. CAPTAIN’S QUARTERS - DAY - CONTINUOUS
# ...and hits the floor hard in the room below.
# Someone stirs, then resumes SNORING.
# Auto lowers through the portal.
# A CLOCK ALARM BUZZER activates.
# AUTOPILOT
# Captain. You are needed on the bridge.
# Shoots back up. The portal closes.
# Wally peeks out of his box.
# ON WALLY’S POV
# PAN across the nautical-themed cabin.
# One wall lined with PORTRAITS OF FORMER CAPTAINS.
# Their years of service listed below.
# The autopilot in the background of each picture.
# Each generation of Captain more devolved than the other.
# From human to gelatinous blob.
# We stop on the FINAL PORTRAIT.
# A blobby Captain.
# It looms above the actual CAPTAIN, snoring in bed.
# He reaches out in his sleep to quiet the snooze alarm.
# Smacks Wally’s box by mistake.
# 33.
# Activates the POYSC SAMPLE.
# It plays loud.
# The Captain sits straight up, half-awake:
# CAPTAIN
# -- All hands on deck!!
# Wally is frantic to turn off the music as...
# ...PREP ROBOTS burst from the cabinetry...
# ...a BEAUTICIAN-BOT, MASSAGE-BOT and WARDROBE-BOT...
# ...The Captain’s bed automatically raises...
# ...Forms into a hover chair...
# The robots rapidly massage, brush, primp and dress him.
# BEAUTICIAN-BOT
# (pre-recorded)
# Morning! Just a trim?
# Wally blends in with the primping.
# Uselessly wiggles the Captain’s toes.
# CAPTAIN
# (Giggles)
# Lines light on the floor.
# Lead his chair automatically to the elevator.
# Wally sneaks aboard just as the doors close.
# ON THE BRIDGE
# Elevator doors swish open.
# The Captain still half-asleep.
# Claps his hands twice.
# On cue, a COFFEE MAKER rises from the console.
# Pours a cup.
# CLASSICAL MUSIC PLAYS on overhead speakers.
# The Captain’s chair links with a LIT FLOOR PATH.
# Leads him over to the coffee.
# Wally stays lockstep behind him.
# Auto glides over to the Captain.
# AUTOPILOT
# Sir --
# CAPTAIN
# Coffee.
# Wally hides under the console just in time.
# The Captain reaches for his coffee.
# Makes a minimal effort.
# Easier to adjust his chairback slowly forward...
# ...almost there...and...he grabs the coffee.
# 34.
# AUTOPILOT
# Sir, the annual --
# The Captain gives Auto the hand.
# Sips his coffee.
# CAPTAIN
# Protocol, Auto. First things first.
# (to the room)
# Computer, status report.
# His chair automatically arcs along the console.
# SPECIFIC PANELS light up as he passes.
# CAPTAIN
# (sips coffee)
# Mechanical systems?...Reactor
# core temperature?...Passenger
# count?...Regenerative food
# buffet?...Jacuzzi Ph
# balance... Atmospheric
# conditions...laundry service
# volume...
# SHIP’S COMPUTER
# Unchanged...unchanged...
# unchanged...unchanged...
# unchanged...unchanged...
# unchanged...
# ON WALLY
# He eyes Eve on the transport across the room.
# Has to get to her.
# But Auto is right above him. Can’t move.
# AUTOPILOT
# Captain...
# Auto calls up a screen on the console.
# Displays the recon-ship and a flashing positive probe.
# Waits patiently for the Captain to notice.
# Finally, the Captain turns...
# CAPTAIN
# Okay, Auto.
# AUTOPILOT
# Sir, the annual reconnaissance has --
# ...but then notices the time.
# CAPTAIN
# 12:30?!
# (disappointed sigh)
# Auto, why didn’t you wake me for the
# morning announcements?
# He slingshots his chair to the Lido Deck side of the bridge.
# Wally nearly collides with him.
# 35.
# Ducks back under the console.
# CAPTAIN
# Honestly, it’s the one thing I get to do
# on this ship.
# Grabs a large dial.
# TIME OF DAY ICONS surround it.
# Cranks it from mid-day back to sunrise.
# OUT ON LIDO DECK
# - The FAKE NOON SUN reverses at high speed to a SUNRISE.
# - Passengers’ LUNCH CUPS switch to BREAKFAST CUPS.
# - Poolside passengers’ umbrella-bots close up.
# An ANNOUNCEMENT WHISTLE BLOWS over the intercom.
# A SECTION OF SKY DOME becomes a JUMBOTRON SCREEN.
# Displays a live video feed of the Captain.
# The image also shows up on every passenger’s CHAIR SCREEN.
# CAPTAIN (ON INTERCOM)
# (unmotivated)
# Well, good morning everybody, and welcome
# to day 255,642 aboard the Axiom. As
# always, weather’s a balmy 72 degrees and
# sunny, and -- Oh, hey, I see the ship’s
# log is showing that today is our 700th
# anniversary of our five year cruise.
# Well, I’m sure our forefathers would be
# proud to know that 700 years later we’d
# be...
# (deflates)
# ...doing the exact same thing...they were
# doing...
# Cut to VARIOUS ASPECTS OF AXIOM LIVING.
# The listening passengers look just as bored as the Captain.
# CAPTAIN (INTERCOM)
# (snaps out of ennui)
# SO! Be sure next mealtime to ask for your
# free...
# (hard to pronounce)
# ...septuacentennial cupcake -- in a cup.
# Also today we have, uh...uh...Hey, Auto,
# what’s that flashing button?
# (mic feedback whine)
# BACK ON THE BRIDGE
# The Captain stares at a FLASHING BUTTON on the console.
# It bears the same PLANT ICON as Eve’s display.
# 36.
# AUTOPILOT (O.S.)
# Captain?
# The Captain turns to Auto.
# For the first time he notices Eve. Finally.
# Auto hovers over her. Salutes.
# AUTOPILOT
# Probe One has returned positive.
# CAPTAIN
# Positive?
# Auto re-activates Eve.
# She wakes.
# Rises to salute the Captain.
# Across the room, Wally watches with sheer joy.
# She’s okay!
# He is compelled to head straight for her...
# CAPTAIN
# But...no probe’s ever come back
# positive...
# (looks at flashing button)
# ...before.
# The flashing button is practically calling to him.
# Can’t resist. Presses it.
# Instantly SHADES close on all the windows.
# The room goes dark.
# ...Wally is forced to hide under the console again...
# A LARGE HOLO-SCREEN appears right above him.
# Pre-recorded footage of the BNL CEO plays:
# BUY N LARGE CEO
# Greetings and congratulations, Captain!
# If you’re seeing this, that means your
# Extraterrestrial Vegetation Evaluator,
# or...
# (air quotes)
# ...”EVE” probe, has returned from Earth
# with a confirmed specimen of ongoing
# photosynthesis!
# The Captain stares slack-jawed at the screen.
# Wally sneaks under the console towards Eve...
# BUY N LARGE CEO
# That’s right, it means it’s time to go
# back home!
# 37.
# CAPTAIN
# (nervous)
# Home? W-w-we’re going back?
# BUY N LARGE CEO
# Now that Earth has been restored to a
# life-sustaining status, by golly, we can
# begin “Operation Recolonize”!
# A section of the console illuminates.
# An ancient, dusty MANUAL slides out...
# ...into a passing Wally’s hands.
# Wally immediately boxes up.
# Holds the manual over his head.
# The Captain mistakes Wally for a book podium.
# Grabs the manual. Blows dust off the cover.
# It reads: “OPERATION RECOLONIZE”.
# Below the title, the same PLANT ICON from Eve’s display.
# BUY N LARGE CEO
# Simply follow this manual’s instructions
# to place the plant in your ship’s holodetector, and the --
# (bad edit)
# -- Axiom -- will immediately navigate
# your return to Earth! It’s that easy!
# ON VIDEO SCREEN (DURING SPEECH)
# An animated diagram depicts a stage below the ship’s bridge.
# The symbol of a HOLO-DETECTOR rises up.
# A STICK FIGURE places a plant inside the machine.
# A STARLINER ICON flies back towards Earth.
# The Captain listens closely to the instructions.
# Wally paying attention as well.
# CAPTAIN
# Huh?
# WALLY
# Huh?
# Wally notices he has a clear shot to Eve.
# Heads in her direction.
# BUY N LARGE CEO
# Now, due to the effects of micro-gravity,
# you and your passengers may have suffered
# some slight bone loss. But I’m sure a few
# laps around your ship’s jogging track
# will get you back in shape in no time.
# The Captain looks at his VESTIGIAL LEGS.
# 38.
# CAPTAIN
# We have a jogging track?
# BUY N LARGE CEO
# If you have any further questions just
# consult your operation manual. See you
# back home real soon.
# The transmission ends.
# The Captain examines the manual.
# Holds it out in front of him.
# CAPTAIN
# (reads; to himself)
# Operate... Manuel...
# (aloud; cautious)
# Manuel, relay instructions. Manuel?
# Auto intervenes.
# Clips the corner of the cover with his handle...
# ...and simply opens the book.
# The Captain is both fascinated and intimidated.
# Lifts the cover with his own fingers.
# CAPTAIN
# Wow... Will you look at that?
# ON EVE
# Wally taps her shoulder.
# Not now Wally -- Double take!
# EVE
# Wally?!
# WALLY
# (tiny wave)
# Ee-vah!
# Eve is in a state of disbelief.
# Shoves Wally into the shadows under the console.
# EVE
# (hushed; angry)
# [Wally, what are you doing here?! You
# can’t be here! You’re going to get me in
# trouble!...]
# Makes a flurry of clandestine gestures at him.
# Wally just stares at her.
# Smitten.
# 39.
# WALLY
# (swoons)
# Ee-vah...
# ON THE CAPTAIN
# He manages to turn to the FIRST PAGE OF INSTRUCTIONS.
# CAPTAIN
# (reads aloud)
# Well, let’s open her up. Step One. Voice
# command, “Confirm Acquisition.”
# SHIP’S COMPUTER
# Confirm Acquisition.
# The bridge suddenly jumps to life.
# Green lights flash.
# A LARGE DEVICE appears from the ceiling...
# ...Scans the entire room...
# ...Identifies Eve...
# ...Rides along the ceiling rails...
# ...Stations itself directly above Eve...
# ...Arms unfold. Position her...
# ...A VOICE ARM swings into the Captain’s face:
# SHIP’S COMPUTER
# Voice authorization required.
# CAPTAIN
# ...Uh...
# SHIP’S COMPUTER
# Accepted.
# A BUTTON-PUSHING ARM lowers.
# Presses a sequence of buttons on Eve...
# Her chest lights up.
# The doors open.
# The Captain winces...
# ...and nothing is inside.
# CAPTAIN
# Where’s the thingie?
# AUTOPILOT
# Plant.
# CAPTAIN
# Plant. Right. Right. Where is it?
# (checks manual)
# Maybe we missed a step. Show me how you
# change the text again...
# 40.
# Auto and the Captain turn away. Re-read the manual.
# Eve is stunned.
# Searches her chest cavity for the plant.
# Then she remembers...
# EVE
# Plant! Wally...
# (turns on him)
# Wally!
# Wally flinches. Surprised by her anger.
# Eve opens Wally’s chest. Empty.
# Picks him up. Scans the floor.
# Nothing.
# WALLY
# Ee-vah?
# EVE
# (angry electronics)
# [Find it!] PLANT!
# Wally scared of her.
# Starts searching.
# CAPTAIN (O.S.)
# Why don’t you scan her to be sure.
# Eve jumps back to attention.
# Auto slides up to her.
# Scans her chest cavity.
# AUTOPILOT
# Contains no specimen. Probe’s memory is
# faulty.
# CAPTAIN
# So, then...we’re NOT going to Earth?
# AUTOPILOT
# (shakes his wheel)
# Negative.
# CAPTAIN
# So, uh, I guess things go back to normal,
# huh?
# AUTOPILOT
# Correct, Captain.
# CAPTAIN
# (privately relieved)
# Well, false alarm!
# 41.
# SHIP’S COMPUTER (V.O.)
# False alarm.
# Instantly the plant retrieval device retracts.
# Exits back into the ceiling.
# The shades rise.
# Lights go back on.
# CAPTAIN
# The probe must be defective. Gopher, send
# her to the Repair Ward.
# Eve turns.
# Excuse me?
# Gopher hops to attention.
# Traps Eve in his SUSPENSION BEAM.
# Loads her back onto the transport...
# CAPTAIN
# Have them run diagnostics on her. Make
# sure she’s not malfunctioning -- EEYAH!!
# ...and reveals WALLY.
# Everyone stares at him.
# Long awkward pause.
# Wally innocently motors over to the Captain.
# Shakes his hand.
# WALLY
# Wally.
# Leaves a CLUMP OF DIRT in his palm.
# The Captain stares at it.
# Turns to Auto.
# CAPTAIN
# Have “Wally” cleaned.
# INT. LOBBY - MOMENTS LATER
# The elevator opens.
# Gopher’s transport drives out.
# Both Eve and Wally strapped on it with energy bands.
# The typing-bot has now mastered waving.
# ...
# It goes berserk.
# Leaps at the entire army of Stewards.
# Robot parts fly everywhere.
# Eve and Wally can’t watch the carnage.
# BACK IN THE CAPTAIN’S QUARTERS
# He sets Eve’s CYLINDRICAL DEVICE on the floor behind him.
# It projects her stored memories.
# UP ON THE BRIDGE
# Auto watches steward blips disappear from his screen.
# A MESSAGE SCREEN pops up.
# It’s the Captain.
# ...and he’s holding the plant?
# CAPTAIN (ON SCREEN)
# Ha, ha! Look what I got, Auto!
# Auto’s single lens irises wide.
# AUTO
# Not possible.
# CAPTAIN (ON SCREEN)
# That’s right! The plant! Oh, you want it?
# Come and get it, Blinky!
# AUTO
# No.
# INT. CAPTAIN’S QUARTERS - SAME
# The Captain hovers in front of Eve’s memory screen.
# It projects a STILL IMAGE OF WALLY HOLDING THE PLANT.
# The Captain blocks the camera’s view of Wally.
# Pretends to be holding the projected plant himself.
# CAPTAIN
# Ha ha!
# HEARS AUTO coming.
# Turns off the vid-com.
# 80.
# Yanks his bundle of wires out of the wall.
# The room goes dark again.
# CLOSE ON CEILING
# The aperture opens.
# Auto lowers into the dark.
# Cautiously searches the empty room...
# AUTO
# Captain? Captain...?
# ON AUTO’S POV
# PANS across the portraits of other captains...
# ...past our present Captain...
# ...The eyes in the portrait dart nervously...
# -- wait a minute.
# The Captain lunges at him.
# Grabs Auto by the steering wheel.
# Hangs onto it like Cap’n Ahab in a gale.
# His lower extremities of no use.
# AUTO
# Let go. Let go.
# Auto panics.
# Zips back up through the hole in the ceiling.
# The Captain gets stuck between floors...
# CAPTAIN
# What too heavy for ya, huh?!
# UP ON THE BRIDGE
# ...Auto tries to pull free.
# The Captain won’t let go.
# Auto ends up yanking him through.
# The Captain rides Auto like a bucking bronco.
# Auto swings violently back and forth.
# CAPTAIN
# You’re not getting away from me, one-eye!
# -- OOF! -- Is that all you got?!
# Gopher drops out of his pneumatic tube.
# Sees the Captain fighting Auto.
# Charges at the Captain...
# ...who kicks him straight out the window...
# ON LIDO DECK
# 81.
# Gopher plummets...
# ...his SHADOW growing over the POOL...
# ...and smashes in a heap on the cement.
# The end.
# ON WALLY AND EVE
# We PAN OVER the smoking wreckage of the stewards.
# The massage-bot floats above it all.
# Pants like a wild beast.
# One steward still twitches.
# The massage-bot crushes him with one blow.
# Eve grabs Wally and the plant.
# They take off for the Concourse Level.
# M-O and the Rejects follow behind.
# ON THE BRIDGE
# CAPTAIN
# That’s it!...A little closer!
# Must..press...button.
# The Captain reaches his one free hand out for...
# ...the HOLO-DETECTOR BUTTON.
# CAPTAIN
# Gotcha! Ha ha!
# His hand slams down hard on it.
# KLAXONS sound all over the ship.
# VARIOUS ANGLES AROUND THE AXIOM
# ...Floodlights kick on everywhere...
# ...The LIDO DECK POOLS automatically cover up...
# ...Stray PASSENGERS pause to take in the alarms...
# ...SPACE-LIFE PRESERVERS burst from their hover chairs...
# ...Inflate around their necks...
# ...GREEN LINES appear on the floors...
# ...SLEEPING PASSENGERS are involuntarily led out of their
# cabins...
# ...Every hover chair follows the illuminated lines...
# The procedure is completely automated.
# The passengers are all confused.
# Helpless to stop it.
# INT. LIDO DECK
# The passengers glide in by the thousands.
# Form concentric circles over the closed-up pools.
# Fill the multi-storied balconies on all sides.
# 82.
# ON JOHN AND MARY
# They arrive together at the Lido Deck.
# Mary notices a group of toddlers scared and crying.
# A NANNY-BOT tries vainly to placate them.
# NANNY-BOT
# Remain calm. Remain calm.
# CLOSE ON BRIDGE PLAZA
# The BNL LOGO on the floor rotates.
# A large cylindrical device rises from the stage...
# ...The ship’s HOLO-DETECTOR.
# JUMBOTRONS activate on the dome.
# Show the bridge.
# Everyone can see the Captain wrestling Auto.
# He tries to speak to them during the fight:
# CAPTAIN
# (strained; in command)
# Ladies and Gentlemen! This is your
# Captain speaking! We’re having a slight
# malfunction with the Autopilot! Please
# remain calm!
# The passengers get caught up in the conflict.
# Treat it as if it were a televised fight.
# ON THE REAR OF THE DECK
# Eve and Wally fly out of the transport tunnel.
# Make a beeline for the holo-detector.
# Ready and waiting for the plant...
# ...almost there...
# ON BRIDGE
# AUTO
# Enough.
# Auto furiously spins his wheel.
# Throws the Captain to the floor.
# The entire ship lists dangerously to one side.
# ON LIDO DECK
# Eve and Wally slam into the holo-detector’s side.
# Wally drops the plant.
# It tumbles off the bridge plaza.
# Eve is forced to set Wally down.
# 83.
# He clings to the holo-detector.
# She flies off to retrieve the plant.
# The hover chairs stay locked on their lines.
# Passengers all slip off their chairs.
# Their uniform color defaults back to RED.
# Slowly slide across the deck.
# And for the first time...
# ...all of humanity reaches out to one another.
# CLOSE UPS of hands holding hands.
# Everyone piles up on the listing side.
# The plant is buried underneath the mass of humanity.
# Eve searches desperately amongst them.
# ON JOHN & MARY
# They hang together off their chairs.
# CRYING TODDLERS just above them.
# The kiddies slip out of their hover rings.
# Mary GASPS in horror.
# Yells to John:
# MARY
# John, get ready to have some kids!
# They purposefully let go of their chairs.
# Grab hands, forming a human chain.
# Catch the toddlers.
# All slide together down the Lido Deck.
# The TODDLERS GIGGLE the whole way down.
# They land at the bottom, next to Eve.
# An empty monorail car tips off the upper deck...
# ...lands on the pool level.
# It begins sliding down the Lido Deck.
# Smashes vacant hover chairs in its wake.
# MARY
# (Gasp)
# LOOK OUT!
# Eve looks up. Sees the Monorail sliding towards them.
# She stops the car before it hits.
# Struggles to hold it up.
# Can’t let it crush the passengers below her.
# ON BRIDGE
# Auto keeps the ship tilted.
# Glides over to the HOLO-DETECTOR BUTTON.
# Switches it off.
# ON LIDO DECK
# 84.
# The holo-detector begins to lower back into the floor...
# Wally is still hanging onto it.
# Barely functioning.
# He uses all his strength...
# ...and wedges himself under the UPPER LIP of the detector.
# Stops it from disappearing into the floor.
# The pressure squeezes Wally into a box.
# ON BRIDGE
# The holo-detector button buzzes and flashes.
# Something’s wrong.
# Auto calls up a LIDO DECK SECURITY CAMERA VIEW.
# Discovers Wally wedged in the device.
# AUTO
# No.
# Auto presses down on the “off” button.
# ON WALLY
# The holo-detector’s hydraulics fight against him.
# Wally desperately fights to hold it up.
# Begins slowly to expand himself...
# ...and push the holo-detector back up!!
# ON BRIDGE
# The Captain watches Wally’s heroic rise on screen.
# Auto flips out his TASER.
# Jams it into the “off” button.
# Short circuits it.
# CAPTAIN
# NO!!
# BACK ON WALLY
# The holo-detector reverses full force.
# Crushes Wally.
# We can’t tell if he survived the crush.
# Eve calls out for him.
# Trapped, holding up the monorail car above the passengers.
# BACK ON BRIDGE
# The Captain watches Wally being crushed.
# That’s it.
# He braces his arms against the floor...
# 85.
# ...and rises up on HIS OWN TWO FEET...
# ON JUMBOTRON SCREEN
# The passengers collectively GASP.
# Their Captain is standing...
# ...and walking himself up the railing...
# ...towards Auto!
# They CHEER!
# ON BRIDGE
# Auto hears the distant cheering.
# Wonders what’s up.
# CAPTAIN (O.S.)
# Auto!
# Auto whips around.
# Shocked to see the Captain standing (albeit wobbly).
# Finds himself face to face with him.
# Auto flips out his TASER.
# Rushes at him.
# The Captain grabs it. They wrestle.
# The taser ARCS in the Captain’s face.
# He flinches. Looks up.
# Sees a CONTROL PANEL high up on Auto’s column...
# ...and smirks.
# The Captain looks Auto in the eye.
# Raises a finger up to the control panel...
# ...to the “AUTOPILOT” BUTTON...
# ...and flicks the switch to “MANUAL”.
# CAPTAIN
# (grits his teeth)
# Auto, you are relieved of duty.
# AUTO
# Noo --
# Auto is instantly turned off.
# The Captain smiles triumphantly.
# Grabs the wheel with both hands.
# Makes the ship level again.
# ON LIDO DECK
# The passengers all spill across the deck.
# Shaken but OK.
# Eve sets the monorail down.
# Rockets over to the holo-detector.
# 86.
# Wally is pinned under the lip of the holo-detector.
# Eve tries to lift it up.
# It won’t budge.
# She looks back to the crowd.
# EVE
# PLANT! PLANT!
# ON M-O
# He searches the crowd for the plant.
# Humans begin to stand for the first time all around him.
# Through his POV he spots the plant mixed in among them.
# “FOREIGN CONTAMINANT” flashes on his display screen.
# ON EVE
# She fights to keep the machine from crushing Wally further.
# M-O (O.S.)
# Ee-vah!
# M-O holds the plant up from across the Lido Deck.
# The vacu-bot shoots it into the hands of a passenger.
# Humans and robots form an impromptu fire line.
# Toss it up to Eve on stage.
# She shoves the plant into the device.
# The detector instantly scans the plant.
# SHIP’S COMPUTER (V.O.)
# Plant origin verified. Course set for
# Earth.
# Slowly, the holo-detector rises...
# Wally topples out from underneath.
# Badly crushed and leaking oil.
# Eve GASPS in horror.
# M-O and the Rejects avert their eyes.
# Passengers recoil as well.
# WIDE ON DOME CEILING
# It converts into a GIANT STAR CHART.
# Rapidly plots a course for Earth.
# SHIP’S COMPUTER (V.O.)
# Ten seconds to hyperjump.
# Eve lifts Wally up.
# No sign of life.
# EVE
# No! WALLY!!
# 87.
# M-O’s head drops in despair.
# The passengers witness grief for the first time.
# Begin to have new feelings of their own: sadness, sympathy.
# Mary begins to cry.
# Buries her head in John’s shoulder.
# MARY
# Oh no! Wally...
# SHIP’S COMPUTER
# Nine, eight, seven, six, five, four,
# three, two, one, zero.
# The ceiling countdown hits “0:00.”
# EXT. AXIOM
# The ship jumps to light speed.
# BACK INSIDE
# The passengers and robots are thrown off their feet.
# Everyone holds on to one another.
# INT. BRIDGE
# The Captain struggles to keep control of the steering wheel.
# Fights the G-forces.
# INT. LIDO DECK
# Humans and robots hang on for dear life.
# John and Mary cling to each other and the babies.
# ON EVE
# She holds tightly to Wally.
# Still calling out his name.
# No response.
# ON SPACE
# The Axiom zooms through hyperspace.
# EXT. EARTH - HILLSIDE - DAY
# The cockroach waits obediently on the hill.
# Exactly where Wally told him to stay.
# His antennae twitch with boredom.
# 88.
# A RED DOT
# appears on the ground.
# The cockroach watches the dot run down the hillside.
# The ground begins to shake.
# Daylight dims.
# The insect looks to the sky.
# ON CLOUD COVER
# A DARK PATCH grows behind the clouds.
# Blots out the sunlight.
# The Axiom’s keel breaks through.
# Its shadow swallows up the entire landscape.
# The cockroach senses his master’s return.
# HUNDREDS OF RED DOTS rush past him.
# He eagerly chases after them.
# ON AXIOM
# The city-size starliner lowers gracefully from the sky.
# Pushes back the clouds to the horizon.
# EXT. OPPOSITE SIDE OF BAY - AXIOM PORT
# The CIRCLE OF DOTS triangulate over the abandoned berth.
# Converge over the port’s LANDING SHAFT.
# Thousands of feet deep.
# The ship’s keel descends into it.
# The earth shudders.
# Trash towers tumble in the distance.
# ...Then all is quiet.
# ON BELLY OF THE AXIOM
# A ROW OF GIANT DOORS open on the side of the ship.
# MULTIPLE GANGWAYS automatically extend.
# Connect with BUILT-IN TERMINALS on the port.
# The Captain walks out gingerly.
# Holding the boot w/ plant.
# The other passengers step out on their own legs.
# Wobble like toddlers.
# They squint up at the harsh sunlight.
# A commotion is heard from the back.
# Somebody trying to push through.
# EVE
# appears out of the crowd.
# Cradles a BOXED UP WALLY in her arms.
# 89.
# M-O and the Rejects follow behind her.
# They rush across the gangway.
# The cockroach meets up with Eve.
# Climbs up onto Wally.
# Doesn’t understand why his master isn’t responding.
# Eve urgently scans the landscape.
# Locks on to WALLY’S TRUCK in the distance.
# She takes to the air.
# M-O and the Rejects chase after her down the gangway.
# M-O
# (beeps)
# [Eve! Wait!]
# The Captain respectfully removes his hat.
# Good luck, friend.
# INT. WALLY’S TRUCK
# The interior is dark and still.
# Suddenly the junk jingles and clinks as the back door opens.
# Eve flies inside with Wally.
# Sets him on the floor.
# She scans the rotating shelves at high speed.
# Grabs a CAR JACK.
# Ratchets up Wally’s crushed body...
# QUICK SHOTS
# ...SPARE PARTS being grabbed by Eve...
# ...Frantically installs the new parts into Wally...
# ...Her arms a blur of precision in motion...
# ...Replaces his damaged CIRCUIT BOARD. The final piece...
# ...She opens his new solar panels...
# ...and BLASTS a hole in the ceiling with her gun.
# OUT ON THE EMPTY BAY
# The rejects stop.
# See the roof of Wally’s truck explode.
# Oh no.
# BACK IN THE TRUCK
# A shaft of sunlight beams down on Wally.
# Eve holds her breath, watches...
# Waits...
# ...Beep...
# ...Beep...
# 90.
# WALLY (O.S.)
# (Apple “reboot” SFX)
# Wally’s meter fully charges.
# His head slowly rises from his box.
# Blinks.
# The cockroach hops with joy.
# Eve is relieved.
# ...She holds out her hand to him.
# EVE
# (with love)
# Wally...
# Wally gives her a blank stare.
# He turns away from Eve. Motors out the truck.
# She grabs him.
# Turns him back around.
# EVE
# (It’s me!)
# Eve!
# Wally just stares.
# Doesn’t seem to know who she is.
# EVE
# (hums)
# [Here, look at these.]
# She grabs the RUBIK’S CUBE and LIGHT BULB from the shelf.
# The light bulb glows in her hand.
# She gives them to Wally.
# No reaction.
# EVE
# (Remember?)
# Wally?
# Wally looks blankly at the junk on the shelves.
# EVE
# (hums)
# [I know!]
# She hovers over to the video player.
# Plays HELLO DOLLY.
# Looks back to see if it has any effect.
# Wally is over at the shelves.
# Has scooped all his prized possessions into his compactor.
# Crushes them into a cube.
# Eve is gut-punched.
# 91.
# Wally motors outside.
# Runs over the cockroach on his way out.
# The insect pops back to life.
# Watches his friend in shock.
# EXT. WALLY’S TRUCK - DAY
# Wally rolls up to a nearby trash pile.
# Scoops up trash. Spits out a cube.
# Eve hovers over to him.
# Still in disbelief.
# EVE
# (somber)
# No.
# Wally continues to stack his cubes.
# She stops him.
# Lifts his head. Stares into his eyes.
# Nobody home.
# Eve presses his “play” button.
# Nothing but STATIC.
# Eve begins to panic.
# Shakes him.
# EVE
# Wally...Wally! WALLY!
# No response.
# He’s gone.
# She hovers in silence next to him for a long time...
# Finally, Eve grasps Wally’s hand.
# Forces his fingers to interlace with hers.
# Holds him close one last time.
# Leans her head against his.
# Hums softly.
# EVE
# [Hums IOTAM]
# She touches her forehead to his.
# Goodbye Wally.
# A TINY SPARK between them.
# Eve turns to hover away.
# Jerked back.
# Her fingers caught between his.
# She checks his eyes again.
# Nothing.
# But then...
# 92.
# ...a tiny SERVO NOISE.
# She looks down at their hands.
# CLOSE ON WALLY’S FINGERS
# They start to move.
# Slowly close around Eve’s.
# She looks back at his face.
# Wally’s eyes gradually come into focus.
# His brows raise...
# WALLY
# Ee-vah?
# EVE
# Wally!
# He notices their hands entwined.
# His dream come true.
# WALLY
# (amazed)
# Ee-vah!!
# She giggles.
# INSIDE THE TRUCK
# The “Hello Dolly” tape reaches the finale of IOTAM.
# “And that is all that love’s about...”
# BACK OUTSIDE
# Eve and Wally stare into each other’s eyes.
# M-O and the Rejects finally reach the truck.
# They begin to celebrate.
# Wally’s alive!
# Then M-O realizes they need privacy.
# Herds the Rejects O.S.
# M-O
# Go! Go, go go!
# Wally and Eve’s foreheads touch.
# Together now and ever more.
# “...and we’ll recall when time runs out...”
# DISSOLVE TO:
# CLOSE UP OF THE PLANT
# 93.
# Newly planted in the earth.
# Small hands water it gently.
# PULL OUT to reveal it surrounded by kids.
# The Captain instructs them.
# John and Mary help unload equipment from the Axiom.
# Robots and passengers stream off the ship.
# CAPTAIN
# This is called “farming”! You kids are
# going to grow all kinds of plants:
# vegetable plants, pizza plants!
# (laughs)
# Ahh, it’s good to be home...
# The CAMERA PULLS OUT from the Axiom...
# ...over the bay...
# “...That it only took a moment...”
# ...past Wally & Eve holding hands in his truck...
# ...over M-O and the Rejects cleaning outside...
# ...Through the trash towers of the city...
# ...past a FIELD OF PLANTS, sprouting from its peak...
# ...up through the cloud cover...
# ...out into space...
# “...To be loved a whole life long.”
# ...and settles on...
# ...our single...
# ...drab...
# ...brown...
# ...little planet.
# IRIS OUT
# THE END
# 94.

# %%
# 🔍 Process each line
with open('something.txt', 'r') as f:
    for line in f:
        parts = line.strip().split(',')
        print('Parts:', parts)
# Out:
# Parts: ['EXT. SPACE']
# Parts: ['FADE IN:']
# Parts: ['Stars.']
# Parts: ['The upbeat show tune', ' Put On Your Sunday Clothes', ' plays.']
# Parts: ['“Out there', ' there’s a world outside of Yonkers...”']
# Parts: ['More stars.']
# Parts: ['Distant galaxies', ' constellations', ' nebulas...']
# Parts: ['A single planet.']
# Parts: ['Drab and brown.']
# Parts: ['Moving towards it.']
# Parts: ['Pushing through its polluted atmosphere.']
# Parts: ['“...Close your eyes and see it glisten...”']
# Parts: ['EXT. PLANET’S SURFACE - CONTINUOUS']
# Parts: ['A range of mountains takes form in the haze.']
# Parts: ['Moving closer.']
# Parts: ['The mountains are piles of TRASH.']
# Parts: ['The entire surface is nothing but waste.']
# Parts: ['“...We’re gonna find adventure in the evening air...”']
# Parts: ['A silhouetted city in the distance.']
# Parts: ['What looks like skyscrapers turns into trash.']
# Parts: ['Thousands of neatly stacked CUBES OF TRASH', ' stories high.']
# Parts: ['Rows and rows of stacked cubes', ' like city avenues.']
# Parts: ['They go on for miles.']
# Parts: ['EXT. AVENUE OF TRASH']
# Parts: ['“...Beneath your parasol the world is all a smile...”']
# Parts: ['Something moving on the ground far below.']
# Parts: ['A figure at the foot of a trash heap.']
# Parts: ['A SMALL SERVICE ROBOT diligently cubing trash.']
# Parts: ['Rusted', ' ancient.']
# Parts: ['Cute.']
# Parts: ['Every inch of him engineered for trash compacting.']
# Parts: ['Mini-shovel hands collect junk.']
# Parts: ['Scoop it into his open chassis.']
# Parts: ['His front plate closes slowly', ' compressing waste.']
# Parts: ['A faded label on his corroded chest plate:']
# Parts: ['“Waste Allocation Loader - Earth Class” (WALLY)']
# Parts: ['Wally spits out a cube of trash.']
# Parts: ['Stacks it with the others.']
# Parts: ['Something catches his eye.']
# Parts: ['Tugs on a piece of metal stuck in the stack.']
# Parts: ['A hubcap.']
# Parts: ['The sun reflects off it.']
# Parts: ['Wally checks the sky.']
# Parts: ['ON TRASH HEAP HORIZON']
# Parts: ['The sun sets through the smoggy haze.']
# Parts: ['“...And we won’t come back until we’ve kissed a girl --”']
# Parts: ['He places the hubcap in his compactor.']
# Parts: ['Presses a button on his chest.']
# Parts: ['The song stops playing.']
# Parts: ['The end of a work day.']
# Parts: ['Wally attaches a lunch cooler to his back.']
# Parts: ['Whistles for his pet COCKROACH.']
# Parts: ['The insect hops on his shoulder.']
# Parts: ['They motor down from the top of a GIANT TRASH TOWER.']
# Parts: ['EXT. AVENUES OF TRASH - DUSK']
# Parts: ['Wally travels alone.']
# Parts: ['Traverses miles of desolate waste.']
# Parts: ['Oblivious to roving storms of toxic weather.']
# Parts: ['Passes haunting structures buried within the trash.']
# Parts: ['Buildings', ' highways', ' entire cities...']
# Parts: ['Everything branded with the SAME COMPANY LOGO.']
# Parts: ['“Buy N Large”']
# Parts: ['“BNL” stores', ' restaurants', ' banks...transportation!']
# Parts: ['The corporation ran every aspect of life.']
# Parts: ['There’s even a BNL LOGO on Wally’s chest plate.']
# Parts: ['CLOSE ON NEWSPAPER Wally drives over.']
# Parts: ['Headline: “TOO MUCH TRASH!! Earth Covered!!”']
# Parts: ['The deck: “BNL CEO Declares Global Emergency!”']
# Parts: ['A photo of the BNL CEO giving a weak smile.']
# Parts: ['Wally’s old treads are threadbare.']
# Parts: ['Practically falling apart.']
# Parts: ['Cause a bumpy ride for his cockroach.']
# Parts: ['He passes the remains of other RUSTED WALL-E UNITS.']
# Parts: ['Fancies one with NEWER TREADS than his own...']
# Parts: ['EXT. DESERTED STREET - MOMENTS LATER']
# Parts: ['Wally now sports the newer treads.']
# Parts: ['Rolls past a SERIES OF HOLOGRAPHIC BILLBOARDS.']
# Parts: ['The solar-powered ads still activate when he passes them.']
# Parts: ['2.']
# Parts: ['BILLBOARD ANNOUNCER (V.O.)']
# Parts: ['(Ad #1: BNL logo over trash)']
# Parts: ['Too much garbage in your face?']
# Parts: ['(Ad #2: starliner in space)']
# Parts: ['There’s plenty of space out in space!']
# Parts: ['(Ad #3: starliners take off']
# Parts: ['from Earth)']
# Parts: ['BNL starliners leaving each day.']
# Parts: ['(Ad #4: WALL-E units wave']
# Parts: ['goodbye)']
# Parts: ['We’ll clean up the mess while you’re']
# Parts: ['away.']
# Parts: ['EXT. EDGE OF THE CITY']
# Parts: ['Wally drives down a deserted overpass.']
# Parts: ['Activates an even LARGER HOLOGRAPHIC BILLBOARD.']
# Parts: ['CLOSE ON BILLBOARD AD']
# Parts: ['Shows off a CITY-SIZED LUXURY STARLINER.']
# Parts: ['Depicts passengers enjoying all its amenities.']
# Parts: ['BILLBOARD ANNOUNCER (V.O.)']
# Parts: ['The jewel of the BNL fleet: “The Axiom”.']
# Parts: ['Spend your five year cruise in style.']
# Parts: ['Waited on 24 hours a day by our fully']
# Parts: ['automated crew', ' while your Captain and']
# Parts: ['Autopilot chart a course for non-stop']
# Parts: ['entertainment', ' fine dining. And with our']
# Parts: ['all-access hover chairs', ' even Grandma can']
# Parts: ['join the fun! There’s no need to walk!']
# Parts: ['“The Axiom”. Putting the “star” in']
# Parts: ['Executive Starliner.']
# Parts: ['The BNL CEO appears at the end.']
# Parts: ['Waves goodbye as the Axiom takes off.']
# Parts: ['BUY N LARGE CEO']
# Parts: ['Because', ' at BNL', ' space is the final “fun”-']
# Parts: ['tier.']
# Parts: ['The holographic billboard powers off.']
# Parts: ['Reveals the AXIOM’S DESERTED LAUNCHPAD in the distance.']
# Parts: ['The mammoth structure sits across the bay.']
# Parts: ['Now empty and dry. A polluted', ' dead valley.']
# Parts: ['ON COLLAPSED BRIDGE RAMP']
# Parts: ['Near its edge rests a WALL-E UNIT TRANSPORT TRUCK.']
# Parts: ['A giant child’s Tonka Truck left to weather the elements.']
# Parts: ['A “Buy N Large” logo on its side.']
# Parts: ['Wally approaches the rear of the truck.']
# Parts: ['3.']
# Parts: ['Pulls on a lever.']
# Parts: ['The back lowers.']
# Parts: ['Wally motors up the ramp.']
# Parts: ['INT. TRUCK - CONTINUOUS']
# Parts: ['Open racks for storing WALL-Es line both walls.']
# Parts: ['KNICKKNACKS OF FOUND JUNK littered everywhere.']
# Parts: ['The tired robot removes his newfound treads.']
# Parts: ['Ahh... Home.']
# Parts: ['Wally motors down the center aisle.']
# Parts: ['Flicks on an ancient BETAMAX PLAYER.']
# Parts: ['Jury-rigged to an iPod.']
# Parts: ['Pushes in a cassette labeled', ' “Hello Dolly!”']
# Parts: ['The image is very poor quality.']
# Parts: ['Actors sing and dance to Put On Your Sunday Clothes (POYSC).']
# Parts: ['The same song Wally worked to.']
# Parts: ['WALLY']
# Parts: ['[Hums POYSC]']
# Parts: ['Wally opens his cooler.']
# Parts: ['Newfound knickknacks.']
# Parts: ['Pulls out the hubcap from his chest.']
# Parts: ['Looks back at the TV.']
# Parts: ['Mimics the dancers on the screen.']
# Parts: ['Pretends the hubcap is a hat.']
# Parts: ['Continues to unpack:']
# Parts: ['A spork.']
# Parts: ['A Rubik’s Cube (unsolved).']
# Parts: ['A Zippo Lighter.']
# Parts: ['He presses a BUTTON by the rack of shelves.']
# Parts: ['They rotate until an empty space appears.']
# Parts: ['His new items are lovingly added to the shelf.']
# Parts: ['The Zippo joins a pre-existing LIGHTER COLLECTION.']
# Parts: ['A new song', ' It Only Takes A Moment', ' plays on the video.']
# Parts: ['Wally is drawn to it.']
# Parts: ['Presses his “Record” button.']
# Parts: ['ON TV SCREEN']
# Parts: ['Two lovers sing gently to one another.']
# Parts: ['They kiss...hold hands...']
# Parts: ['Wally tilts his head as he watches.']
# Parts: ['Curious.']
# Parts: ['Holds his own hands.']
# Parts: ['4.']
# Parts: ['EXT. TRUCK - NIGHT']
# Parts: ['Wally motors outside.']
# Parts: ['Turns over his Igloo cooler to clean it out.']
# Parts: ['Pauses to take in the night sky.']
# Parts: ['STARS struggle to be seen through the polluted haze.']
# Parts: ['Wally presses the “Play” button on his chest.']
# Parts: ['The newly sampled It Only Takes A Moment (IOTAM) plays.']
# Parts: ['The wind picks up.']
# Parts: ['A WARNING LIGHT sounds on Wally’s chest.']
# Parts: ['He looks out into the night.']
# Parts: ['A RAGING SANDSTORM approaches off the bay...']
# Parts: ['Unfazed', ' Wally heads back in the truck.']
# Parts: ['IOTAM still gently playing.']
# Parts: ['...The massive wave of sand roars closer...']
# Parts: ['Wally raises the door.']
# Parts: ['Pauses.']
# Parts: ['WHISTLES for his cockroach to come inside.']
# Parts: ['The door shuts just as the storm hits.']
# Parts: ['Obliterates everything in view.']
# Parts: ['INT. TRUCK - SAME']
# Parts: ['Wally alone in the center of his shelter.']
# Parts: ['Unwraps a BNL SPONGECAKE (think Twinkie).']
# Parts: ['Lays it out for the cockroach to sleep in.']
# Parts: ['It happily dives in.']
# Parts: ['Wally collapses himself into a storable cube.']
# Parts: ['Backs into an empty shelf space.']
# Parts: ['Rocks it like a cradle...']
# Parts: ['...and shuts down for the night.']
# Parts: ['Outside the wind howls like the Hounds of Hell.']
# Parts: ['INT. WALLY’S TRUCK - NEXT MORNING']
# Parts: ['Wally’s CHARGE METER flashes “WARNING”.']
# Parts: ['He wakes. Unboxes.']
# Parts: ['Groggy and lifeless.']
# Parts: ['Stumbles outside.']
# Parts: ['EXT. ROOF OF WALLY’S TRUCK']
# Parts: ['The morning sun.']
# Parts: ['Wally fully exposed in its light.']
# Parts: ['His front panel splayed out like a tanning shield.']
# Parts: ['A solar collector.']
# Parts: ['5.']
# Parts: ['His CHARGE METER chimes full.']
# Parts: ['Solar panels fold away into hiding.']
# Parts: ['Wally', ' now awake', ' collects his lunch cooler.']
# Parts: ['Heads off to work.']
# Parts: ['...and accidentally runs over the cockroach.']
# Parts: ['Horrified', ' Wally reverses.']
# Parts: ['Reveals the FLATTENED INSECT under his tread.']
# Parts: ['The cockroach simply pops back to life.']
# Parts: ['No biggie. Ready to go.']
# Parts: ['Relieved', ' Wally resumes their commute.']
# Parts: ['EXT. WALLY’S WORK SITE - THAT MORNING']
# Parts: ['A SERIES OF “WALLY AT WORK” MOMENTS:']
# Parts: ['- CU of Wally’s hands digging into garbage.']
# Parts: ['CU of trash being scooped into his chest compactor.']
# Parts: ['A cube lands by the cockroach.']
# Parts: ['- Wally discovers a BRA in the garbage.']
# Parts: ['Unsure what it’s for.']
# Parts: ['Tries placing it over his eyes', ' like glasses.']
# Parts: ['Tosses it in his cooler.']
# Parts: ['- Wally finds a set of CAR KEYS.']
# Parts: ['Presses the remote lock.']
# Parts: ['Somewhere in the distance a CAR ALARM CHIRPS.']
# Parts: ['- Plays with a paddle ball.']
# Parts: ['The ball keeps smacking him in the face.']
# Parts: ['He doesn’t like it.']
# Parts: ['- Wally discovers a DIAMOND RING in a JEWEL CASE.']
# Parts: ['Throws out the ring. Keeps the case.']
# Parts: ['The jewel case drops into the cooler', ' then...']
# Parts: ['...A RUBBER DUCKY...']
# Parts: ['...A BOBBLE HEAD DOLL...']
# Parts: ['...An OLD BOOT...']
# Parts: ['...A TROPHY...']
# Parts: ['- Wally finds a FIRE EXTINGUISHER.']
# Parts: ['Activates it.']
# Parts: ['FOAM blasts in his face.']
# Parts: ['It’s tossed far', ' far away from his cooler.']
# Parts: ['- Wally’s shovel hand strikes something solid.']
# Parts: ['Faces a REFRIGERATOR much larger than himself.']
# Parts: ['Now what?']
# Parts: ['- CU on fridge door.']
# Parts: ['A WELDING BEAM moves down its center.']
# Parts: ['It emits from between Wally’s SPLIT BINOCULAR EYES.']
# Parts: ['6.']
# Parts: ['The door falls apart in two pieces. Reveals...']
# Parts: ['...a SMALL PLANT']
# Parts: ['in its early stage of growth.']
# Parts: ['Wally is entranced.']
# Parts: ['Carefully', ' he extracts the section of earth around it.']
# Parts: ['CLOSE ON IGLOO COOLER']
# Parts: ['Wally gently places the plant inside the old boot.']
# Parts: ['Dusts dirt off the leaves.']
# Parts: ['EXT. TRUCK - DUSK']
# Parts: ['Robot and faithful cockroach return home.']
# Parts: ['Wally stops short of the threshold.']
# Parts: ['Stares at the ground.']
# Parts: ['Continues staring.']
# Parts: ['A RED DOT']
# Parts: ['quivers on the dirt.']
# Parts: ['A single laser point of light.']
# Parts: ['Wally moves to touch it...']
# Parts: ['...The dot races along the ground.']
# Parts: ['Wally drops his Igloo.']
# Parts: ['Chases after the dot.']
# Parts: ['EXT. EMPTY BAY']
# Parts: ['The dot leads Wally deep into the polluted expanse.']
# Parts: ['He is so fixated on it he doesn’t notice']
# Parts: ['MANY LASER POINTS']
# Parts: ['coming from every direction.']
# Parts: ['All racing into the valley over the contour of the terrain.']
# Parts: ['Triangulating towards a center.']
# Parts: ['Wally’s dot suddenly stops.']
# Parts: ['Slowly he reaches for it.']
# Parts: ['Can’t grab it. Just light.']
# Parts: ['ALL THE DOTS converge in front of him.']
# Parts: ['The ground shakes.']
# Parts: ['Wally becomes confused.']
# Parts: ['Doesn’t see above him.']
# Parts: ['The SUN growing brighter behind the cloud cover.']
# Parts: ['A noise. Building.']
# Parts: ['7.']
# Parts: ['Rocket engines.']
# Parts: ['Wally senses he should look to the sky.']
# Parts: ['Now THREE SUNS are descending on him.']
# Parts: ['Wally runs for it.']
# Parts: ['An enormous COLUMN OF FIRE blocks his path.']
# Parts: ['A second column of fire.']
# Parts: ['A third.']
# Parts: ['Trapped.']
# Parts: ['Wally cubes the ground beneath him.']
# Parts: ['Working fast.']
# Parts: ['Noise deafening.']
# Parts: ['Heat rising.']
# Parts: ['Digs in just as a tide of flame carpets the ground...']
# Parts: ['...Then suddenly quiet.']
# Parts: ['Smoke clears.']
# Parts: ['CLOSE ON THE SCORCHED EARTH']
# Parts: ['Wally’s head rises out of the dirt.']
# Parts: ['Glows red hot from the heat.']
# Parts: ['Trembles with fright.']
# Parts: ['Everything in shadow.']
# Parts: ['Something very big looms over him.']
# Parts: ['Wally climbs out of his hole.']
# Parts: ['Bangs his head on metal.']
# Parts: ['WIDE on a massive SPACESHIP.']
# Parts: ['Rests ominously in the empty bay.']
# Parts: ['A PORTAL on its underside opens.']
# Parts: ['Frightened', ' Wally tries to hide.']
# Parts: ['Nowhere to go.']
# Parts: ['He places a SMALL ROCK on his head. Boxes up.']
# Parts: ['A DEVICE lowers to the ground on a long stem.']
# Parts: ['Scans the surface.']
# Parts: ['Wally creeps closer for a better look.']
# Parts: ['The device unfolds.']
# Parts: ['Wally boxes up again.']
# Parts: ['A CAPSULE descends from a chute in the stem.']
# Parts: ['ROBOT ARMS emerge from the device.']
# Parts: ['Place the capsule on the ground. Press buttons.']
# Parts: ['The capsule falls away in sections', ' to reveal...']
# Parts: ['...a PROBE ROBOT.']
# Parts: ['It hovers gracefully above the ground.']
# Parts: ['White. Egg-shaped.']
# Parts: ['8.']
# Parts: ['Blue-lit eyes.']
# Parts: ['Female.']
# Parts: ['Eve.']
# Parts: ['Wally is transfixed.']
# Parts: ['Inches closer.']
# Parts: ['Watches Eve from behind the device.']
# Parts: ['Tilts his head.']
# Parts: ['Time stops.']
# Parts: ['She’s the most beautiful thing he’s ever seen.']
# Parts: ['Eve hovers over the ground.']
# Parts: ['A BLUE RAY emits from her front panel.']
# Parts: ['Fans out 180 degrees.']
# Parts: ['Scans random objects and areas.']
# Parts: ['The device rises back into the ship.']
# Parts: ['Exposes Wally.']
# Parts: ['He rushes for cover behind the nearest rock.']
# Parts: ['Never takes his eyes off Eve.']
# Parts: ['Watches her float away from the ship.']
# Parts: ['...from the ship?']
# Parts: ['The ship!']
# Parts: ['Engines roar back to life.']
# Parts: ['Wally digging furiously.']
# Parts: ['The rocket takes off.']
# Parts: ['Smoke clears.']
# Parts: ['Again', ' a red hot Wally peeks out from the ground.']
# Parts: ['Looks for Eve.']
# Parts: ['She is watching the ship rise into the clouds.']
# Parts: ['Waits until it is completely out of sight...']
# Parts: ['...then Eve rises high up into the air.']
# Parts: ['She flies around the bay.']
# Parts: ['Soars like a graceful bird.']
# Parts: ['Does loops in the sky.']
# Parts: ['Zooms right past Wally’s rock.']
# Parts: ['He is hypnotized.']
# Parts: ['Eve descends gently to the ground...']
# Parts: ['Wally sneaks up closer.']
# Parts: ['Hides behind another boulder.']
# Parts: ['Slips.']
# Parts: ['Makes a NOISE.']
# Parts: ['Instantly', ' Eve whips around.']
# Parts: ['Her arm converts into a LASER CANNON.']
# Parts: ['Blasts Wally’s boulder to smithereens.']
# Parts: ['...Smoke clears...All quiet.']
# Parts: ['Eve', ' now cold and dangerous.']
# Parts: ['9.']
# Parts: ['Scans the area.']
# Parts: ['No sign of life.']
# Parts: ['All business again.']
# Parts: ['Hovers away to probe more of the planet.']
# Parts: ['ON OTHER SIDE OF BOULDER CRATER']
# Parts: ['Wally boxed up behind what little remains of the rock.']
# Parts: ['Trembles uncontrollably.']
# Parts: ['EXT. AVENUE OF TRASH - DAY']
# Parts: ['Eve wanders through the pillars of cubed trash.']
# Parts: ['Scans random areas.']
# Parts: ['Wally spies from the shadows.']
# Parts: ['Too frightened to approach.']
# Parts: ['She moves on. He follows.']
# Parts: ['EXT. TIRE DUMP - DAY']
# Parts: ['Eve probes a mound of tires.']
# Parts: ['Wally hiding nearby.']
# Parts: ['He flinches at the sight of']
# Parts: ['HIS COCKROACH']
# Parts: ['innocently approaching Eve from behind.']
# Parts: ['She spins around.']
# Parts: ['Blasts the insect.']
# Parts: ['Wally is gut-punched.']
# Parts: ['The cockroach climbs out of the smoking crater.']
# Parts: ['Unscathed. Still curious.']
# Parts: ['Eve finds the insect intriguing.']
# Parts: ['Lowers her arm.']
# Parts: ['The end separates into individual hovering sections...']
# Parts: ['...A HAND.']
# Parts: ['She lets the insect crawl up her arm.']
# Parts: ['Wiggles into her workings.']
# Parts: ['It tickles.']
# Parts: ['EVE']
# Parts: ['[Giggles]']
# Parts: ['Wally relaxes.']
# Parts: ['CHUCKLES privately.']
# Parts: ['Eve sonically picks up Wally’s location.']
# Parts: ['Locks onto him.']
# Parts: ['10.']
# Parts: ['Arm converts to laser cannon.']
# Parts: ['Fires rapidly.']
# Parts: ['Quick glimpses of Wally dodging the blasts.']
# Parts: ['Trash piles are systematically obliterated around him.']
# Parts: ['Wally now exposed.']
# Parts: ['Nowhere to hide.']
# Parts: ['Boxes himself up. Shakes uncontrollably.']
# Parts: ['Eve holds her fire.']
# Parts: ['EVE']
# Parts: ['(electronic hums)']
# Parts: ['[Identify yourself.]']
# Parts: ['She slowly approaches Wally’s box.']
# Parts: ['Keeps her gun trained on him.']
# Parts: ['EVE']
# Parts: ['(electronic hums)']
# Parts: ['[Repeat. Identify yourself.]']
# Parts: ['Wally peeks out from his box.']
# Parts: ['Doesn’t understand a thing she says.']
# Parts: ['Doesn’t care.']
# Parts: ['Can’t believe she’s real.']
# Parts: ['The cockroach climbs down her gun arm.']
# Parts: ['Jumps onto his master.']
# Parts: ['Eve scans Wally.']
# Parts: ['A RED LIGHT appears on her chest.']
# Parts: ['Buzzes “negative”.']
# Parts: ['He’s not what she’s looking for.']
# Parts: ['She retracts her gun arm.']
# Parts: ['Hovers off.']
# Parts: ['Wally watches her go. Lovestruck.']
# Parts: ['WALLY']
# Parts: ['[Sigh.]']
# Parts: ['DISSOLVE TO:']
# Parts: ['INT. ABANDONED BNL SUPERSTORE - NEXT DAY']
# Parts: ['LOUIS ARMSTRONG’S “LA VIE EN ROSE” PLAYS']
# Parts: ['Eve scans through the market.']
# Parts: ['Wally follows from a safe distance.']
# Parts: ['A stray puppy-dog.']
# Parts: ['Eve glances over at him.']
# Parts: ['Wally panics.']
# Parts: ['Bumps into a RACK OF SHOPPING CARTS.']
# Parts: ['Creates an avalanche.']
# Parts: ['11.']
# Parts: ['They chase him down a flight of stairs.']
# Parts: ['Wally reaches the exit doors.']
# Parts: ['Won’t open!']
# Parts: ['Carts pig pile on top of him.']
# Parts: ['EXT. BNL REFINERY - NIGHT']
# Parts: ['Wally perched on the roof.']
# Parts: ['Patiently watches Eve fly.']
# Parts: ['She scans the ground below her', ' like a searchlight.']
# Parts: ['Eve comes in for a landing below.']
# Parts: ['Shuts down for the night.']
# Parts: ['Wally waits.']
# Parts: ['Quietly sneaks down the refinery fire escape.']
# Parts: ['Accidentally trips. Tumbles to the ground.']
# Parts: ['Eve doesn’t wake.']
# Parts: ['Wally creeps up to her.']
# Parts: ['Opens his arms wide...']
# Parts: ['...and measures her.']
# Parts: ['Turns to a pile of trash.']
# Parts: ['Splits open his eyes. Begins welding something...']
# Parts: ['DISSOLVE TO:']
# Parts: ['EXT. BNL REFINERY - NEXT MORNING']
# Parts: ['Eve powers up again.']
# Parts: ['Does a double take.']
# Parts: ['A TRASH SCULPTURE OF EVE stands in front of her.']
# Parts: ['She hovers away', ' unimpressed.']
# Parts: ['Doesn’t notice Wally hiding behind a PILE OF PIPES.']
# Parts: ['Wally kicks the pipes in frustration.']
# Parts: ['They roll on top of him.']
# Parts: ['SONG ENDS']
# Parts: ['MONTAGE OF EVE SEARCHING']
# Parts: ['- Scans a car engine.']
# Parts: ['Negative.']
# Parts: ['Slams the hood shut.']
# Parts: ['- Scans a Port-A-Potty.']
# Parts: ['Negative.']
# Parts: ['Slams the door shut.']
# Parts: ['- Scans an Apollo capsule.']
# Parts: ['Negative.']
# Parts: ['Slams the hatch shut.']
# Parts: ['- Scans a FREIGHTER HOLD.']
# Parts: ['12.']
# Parts: ['Negative.']
# Parts: ['Slams the lid shut.']
# Parts: ['EXT. DERELICT SHIPYARD - DUSK']
# Parts: ['Eve hovers over the freighter.']
# Parts: ['Frustrated.']
# Parts: ['Not finding what she’s looking for.']
# Parts: ['Wally eavesdrops from afar.']
# Parts: ['Eve flies past the ship’s CRANE MAGNET.']
# Parts: ['Gets stuck.']
# Parts: ['Wrestles to free herself.']
# Parts: ['Furious', ' she BLOWS UP THE ENTIRE SHIP.']
# Parts: ['The reaction startles Wally.']
# Parts: ['Eve slumps down against a dredged anchor.']
# Parts: ['She gives up.']
# Parts: ['Concerned', ' Wally cautiously approaches.']
# Parts: ['Sits at the other end of the anchor.']
# Parts: ['Both robots stare silently at the fiery wreck.']
# Parts: ['Then...']
# Parts: ['...slowly', ' very slowly', ' Wally inches towards her.']
# Parts: ['Musters the courage to speak', ' when --']
# Parts: ['She suddenly turns to him:']
# Parts: ['EVE']
# Parts: ['(hums)']
# Parts: ['[So what’s your story?]']
# Parts: ['Wally falls backwards with surprise.']
# Parts: ['Me?']
# Parts: ['Eve scrolls through a variety of languages:']
# Parts: ['EVE']
# Parts: ['(German)']
# Parts: ['[Directive?]']
# Parts: ['(Japanese)']
# Parts: ['[Directive?]']
# Parts: ['WALLY']
# Parts: ['[Huh?]']
# Parts: ['EVE']
# Parts: ['(Swahili)']
# Parts: ['[Directive?]']
# Parts: ['(English)']
# Parts: ['Directive?']
# Parts: ['WALLY']
# Parts: ['(beeps)']
# Parts: ['[Oh', ' I understand that!]']
# Parts: ['13.']
# Parts: ['EVE']
# Parts: ['Directive?']
# Parts: ['Wally eagerly turns to some nearby trash.']
# Parts: ['Scoops it into his compactor.']
# Parts: ['Proudly spits out a cube.']
# Parts: ['Points to Eve.']
# Parts: ['WALLY']
# Parts: ['(struggles to speak)']
# Parts: ['Di...rec...t--']
# Parts: ['EVE']
# Parts: ['Directive?']
# Parts: ['Wally nods.']
# Parts: ['EVE']
# Parts: ['Classified.']
# Parts: ['WALLY']
# Parts: ['(beeps)']
# Parts: ['[Oh. Sorry.]']
# Parts: ['She scans his CHEST LOGO.']
# Parts: ['EVE']
# Parts: ['Name?']
# Parts: ['WALLY']
# Parts: ['(struggles again)']
# Parts: ['W-wally? ...Wally.']
# Parts: ['EVE']
# Parts: ['(smooth; almost perfect)']
# Parts: ['Wwww-aaaa-leee...']
# Parts: ['Wally nearly melts.']
# Parts: ['She says his name so beautifully.']
# Parts: ['Moves closer.']
# Parts: ['EVE']
# Parts: ['Wally.']
# Parts: ['(giggles)']
# Parts: ['Eve.']
# Parts: ['Wally tries to repeat it:']
# Parts: ['WALLY']
# Parts: ['Eeee...?']
# Parts: ['EVE']
# Parts: ['(slower)']
# Parts: ['Eve.']
# Parts: ['14.']
# Parts: ['WALLY']
# Parts: ['Eeeaaah?']
# Parts: ['EVE']
# Parts: ['Eeeve. Eeeve.']
# Parts: ['WALLY']
# Parts: ['Eee--vah!']
# Parts: ['She giggles again.']
# Parts: ['Wally likes making her giggle.']
# Parts: ['WALLY']
# Parts: ['Eee-vah! Ee --']
# Parts: ['EVE']
# Parts: ['Eve.']
# Parts: ['The wind kicks up.']
# Parts: ['The WARNING LIGHT sounds on Wally’s chest.']
# Parts: ['He moves to grab her.']
# Parts: ['WALLY']
# Parts: ['(Gasp!) Eee-vah!']
# Parts: ['EVE']
# Parts: ['(hums)']
# Parts: ['[Hey watch it! Don’t come any closer!]']
# Parts: ['She draws her gun on him.']
# Parts: ['Doesn’t understand the danger.']
# Parts: ['The sandstorm rushes up behind her.']
# Parts: ['Too late.']
# Parts: ['Wally collapses into a box.']
# Parts: ['The storm hits full force.']
# Parts: ['Eve is instantly lost', ' disoriented.']
# Parts: ['EVE']
# Parts: ['Wally? Wally?']
# Parts: ['WALLY’S HAND appears out of the dust.']
# Parts: ['Calmly takes Eve’s hand.']
# Parts: ['INT. TRUCK - MOMENTS LATER']
# Parts: ['The back door lowers.']
# Parts: ['A rush of wind and sand.']
# Parts: ['Wally pulls Eve inside. Closes the door.']
# Parts: ['She coughs up dust.']
# Parts: ['Wally hits a switch...']
# Parts: ['Strings of CHRISTMAS LIGHTS fill the space.']
# Parts: ['His racks of oddities painted in colored light.']
# Parts: ['15.']
# Parts: ['An air of enchantment.']
# Parts: ['Eve is taken aback.']
# Parts: ['WALLY']
# Parts: ['(beeps)']
# Parts: ['[Come on in.]']
# Parts: ['She drifts through the sea of knickknacks.']
# Parts: ['Becomes spooked by a SINGING BILLY BASS FISH.']
# Parts: ['Threatens to shoot it', ' but Wally calms her down.']
# Parts: ['He is compelled to show her everything.']
# Parts: ['Hands her an eggbeater...']
# Parts: ['...bubble wrap (so infectious to pop)...']
# Parts: ['...a lightbulb (lights when she holds it)...']
# Parts: ['...the Rubik’s Cube (she solves it immediately)...']
# Parts: ['...his Hello Dolly tape.']
# Parts: ['Curious', ' she begins unspooling the tape.']
# Parts: ['WALLY']
# Parts: ['(loud beeps)']
# Parts: ['[My tape!!]']
# Parts: ['He grabs it back. Protective.']
# Parts: ['Inserts it carefully into the VCR. Please still work.']
# Parts: ['The movie eventually appears on the TV.']
# Parts: ['Plays a clip of POYSC.']
# Parts: ['Wally is relieved.']
# Parts: ['WALLY']
# Parts: ['(beeps)']
# Parts: ['[What do you think?]']
# Parts: ['Mimics the dancing for Eve.']
# Parts: ['Encourages her to try.']
# Parts: ['She clumsily hops up and down.']
# Parts: ['Makes dents in the floor. Rattles everything.']
# Parts: ['Wally politely stops her.']
# Parts: ['WALLY']
# Parts: ['(beeps)']
# Parts: ['[How ‘bout we try a different move?]']
# Parts: ['Spins in a circle. Arms out.']
# Parts: ['Eve copies.']
# Parts: ['Spins faster', ' and faster...']
# Parts: ['Too fast.']
# Parts: ['Accidentally strikes Wally. He flies into the shelves.']
# Parts: ['Eve helps him up from the mess.']
# Parts: ['Wally’s LEFT BINOCULAR EYE falls off.']
# Parts: ['Dangles from two wires.']
# Parts: ['Eve GASPS with concern.']
# Parts: ['Wally placates her.']
# Parts: ['16.']
# Parts: ['WALLY']
# Parts: ['(beeps)']
# Parts: ['[It’s fine.]']
# Parts: ['Feels his way to the rack of shelves.']
# Parts: ['Rotates them until...']
# Parts: ['...SPARE WALL-E PARTS appear.']
# Parts: ['Replaces his broken eye with a new one.']
# Parts: ['Eve is relieved.']
# Parts: ['She eyes his LIGHTER COLLECTION.']
# Parts: ['Flicks open a Zippo. Ignites a FLAME.']
# Parts: ['Wally freezes.']
# Parts: ['He had no idea it could do that.']
# Parts: ['Moves closer to inspect it...']
# Parts: ['ON WALLY']
# Parts: ['It’s the closest he’s ever been to Eve.']
# Parts: ['She remains focused on the lighter.']
# Parts: ['Wally stares up at her.']
# Parts: ['...The tiny flame flickering between them...']
# Parts: ['...The Hello Dolly video plays IOTAM in the background...']
# Parts: ['Suddenly', ' he is moved to express his love.']
# Parts: ['Musters the courage to open his fingers...']
# Parts: ['...Timidly reaches his hand out to hers...']
# Parts: ['-- Eve turns and looks at him.']
# Parts: ['Wally instantly chokes.']
# Parts: ['Pulls his hand back.']
# Parts: ['Eve becomes intrigued with the TV.']
# Parts: ['Scans the image of the lovers singing IOTAM...']
# Parts: ['Wally watches her.']
# Parts: ['His infatuation still palpable.']
# Parts: ['Then he remembers...']
# Parts: ['WALLY']
# Parts: ['Ee-vah!']
# Parts: ['He rushes to his shelves.']
# Parts: ['Eve watches him rummage through junk.']
# Parts: ['A drum falls down on his head.']
# Parts: ['She giggles', ' charmed by it all.']
# Parts: ['Something about Wally...']
# Parts: ['She is drawn back to the lovers on TV...']
# Parts: ['...then the lit Zippo lighter in her hand.']
# Parts: ['A tap on her shoulder.']
# Parts: ['She turns to find Wally holding something.']
# Parts: ['The plant.']
# Parts: ['Eve immediately locks onto it.']
# Parts: ['17.']
# Parts: ['Drops the lighter.']
# Parts: ['In a flash...']
# Parts: ['...her chest opens...']
# Parts: ['...a TRACTOR BEAM snatches the plant away...']
# Parts: ['...stores it inside her...']
# Parts: ['Then she shuts down completely.']
# Parts: ['Only a SINGLE GREEN LIGHT pulsing on her chest.']
# Parts: ['Wally is stunned.']
# Parts: ['What’d I do?']
# Parts: ['Waves his hand in front of her face.']
# Parts: ['WALLY']
# Parts: ['Ee-vah?']
# Parts: ['Knocks on her chest plate.']
# Parts: ['No response.']
# Parts: ['Wally panics.']
# Parts: ['Gently shakes her.']
# Parts: ['WALLY']
# Parts: ['Ee-vah?']
# Parts: ['Still no response.']
# Parts: ['WALLY']
# Parts: ['Ee-vah? ...Ee-vah?!']
# Parts: ['CAMERA MOVES IN on the blinking green light...']
# Parts: ['DISSOLVE TO:']
# Parts: ['EXT. ROOF OF WALLY’S TRUCK - DAY']
# Parts: ['The morning sun.']
# Parts: ['Wally places Eve in his charging spot.']
# Parts: ['Aims her hovering form to face the sun.']
# Parts: ['Waits.']
# Parts: ['MONTAGE OF WALLY TRYING TO REVIVE EVE:']
# Parts: ['- Several hot days pass with Wally holding vigil in the heat.']
# Parts: ['- A THUNDERSTORM approaches on the horizon.']
# Parts: ['Wally holds an UMBRELLA over Eve.']
# Parts: ['Gets struck by lightning.']
# Parts: ['Holds up another umbrella.']
# Parts: ['Gets struck again.']
# Parts: ['- A SANDSTORM blows through.']
# Parts: ['Wally pops out of a dune on the truck’s roof.']
# Parts: ['Lifts up an UPSIDE-DOWN BARREL that protected Eve.']
# Parts: ['18.']
# Parts: ['- Wally pries open a panel on Eve’s chest.']
# Parts: ['Reveals her pulsing BLUE HEART-BATTERY.']
# Parts: ['Attaches JUMPER CABLES to his own HEART-BATTERY.']
# Parts: ['Tries to connect the other end to hers.']
# Parts: ['An automatic defense system blows him off truck.']
# Parts: ['- Wally & cockroach take Eve for a walk.']
# Parts: ['Pull her along on a LEASH OF CHRISTMAS LIGHTS.']
# Parts: ['- Wally gives Eve a boat ride on a LAKE OF SLUDGE.']
# Parts: ['Uses an industrial tire as a boat.']
# Parts: ['Rows like a gondolier with a road sign.']
# Parts: ['- Wally sits by the empty bay with Eve.']
# Parts: ['Watches the SUNSET.']
# Parts: ['Burns “WALL-E + EVE” on a public trash can.']
# Parts: ['Tries to pull out her hand to hold it.']
# Parts: ['It snaps back into place', ' trapping his hand.']
# Parts: ['END OF MONTAGE']
# Parts: ['EXT. ROOF OF WALLY’S TRUCK - NIGHT']
# Parts: ['Wally has set up the TV on the roof.']
# Parts: ['The blank Eve floating next to him.']
# Parts: ['Tries unsuccessfully to play PONG with her.']
# Parts: ['Still no response.']
# Parts: ['Finally', ' he gives up.']
# Parts: ['WALLY']
# Parts: ['[defeated sigh]']
# Parts: ['EXT. TRUCK - NEXT MORNING']
# Parts: ['Wally loads up his cooler.']
# Parts: ['Checks on Eve one more time.']
# Parts: ['Still nothing...']
# Parts: ['Heads off to work', ' defeated.']
# Parts: ['EXT. WORK SITE - LATER']
# Parts: ['Wally simply going through the motions.']
# Parts: ['No spirit in him at all.']
# Parts: ['Stops.']
# Parts: ['Pulls out the Zippo lighter.']
# Parts: ['Flicks it a few times.']
# Parts: ['A RUSH OF WIND blows out the flame.']
# Parts: ['Distant rumbling.']
# Parts: ['Wally looks in the direction of his home.']
# Parts: ['A BRIGHT GLOW is lowering down through the clouds.']
# Parts: ['19.']
# Parts: ['WALLY']
# Parts: ['(beeps)']
# Parts: ['[Oh no.]']
# Parts: ['EXT. TRASH ALLEY - DAY']
# Parts: ['Wally racing as fast as he can.']
# Parts: ['The cockroach clings onto him for dear life.']
# Parts: ['EXT. TRUCK - DAY']
# Parts: ['The RECON SPACESHIP towers over his truck.']
# Parts: ['A ROBOT ARM cherry-picks Eve from the roof.']
# Parts: ['Lifts her up and into the ship’s cargo hold.']
# Parts: ['Wally racing in the distance.']
# Parts: ['WALLY']
# Parts: ['EE-VAH!! EE-VAH!!']
# Parts: ['Reaches the end of the collapsed bridge ramp.']
# Parts: ['Forced to watch Eve disappear into the ship.']
# Parts: ['The cargo doors slam shut.']
# Parts: ['The first of the THREE ROCKET ENGINES powers up.']
# Parts: ['Wally heads down a hill of rubble to the ship.']
# Parts: ['Notices his cockroach tagging along behind him.']
# Parts: ['Leads it back to the top of the hill.']
# Parts: ['WALLY']
# Parts: ['(beeps)']
# Parts: ['[Stay.]']
# Parts: ['The insect mopes.']
# Parts: ['Droops its little antennae.']
# Parts: ['Wally motors back down to the rocket...']
# Parts: ['BASE OF RECON SHIP']
# Parts: ['The engines blast a WALL OF SMOKE.']
# Parts: ['Preparation for launch...']
# Parts: ['INT. RECON SHIP']
# Parts: ['Eve is secured into a slot.']
# Parts: ['Joins a ROW OF OTHER EVE PROBES.']
# Parts: ['All dormant.']
# Parts: ['Only Eve flashes a GREEN LIGHT.']
# Parts: ['The CAMERA DRIFTS BACK out a window...']
# Parts: ['OUTSIDE THE SHIP']
# Parts: ['20.']
# Parts: ['...where Wally steadily climbs up the side.']
# Parts: ['The ship’s engines ignite.']
# Parts: ['Wally clamps his hands tight to a metal support.']
# Parts: ['The rocket takes off into space.']
# Parts: ['EXT. TOP OF HILL']
# Parts: ['The cockroach watches his master go.']
# Parts: ['EXT. RECON SHIP']
# Parts: ['The spaceship roars through the sky.']
# Parts: ['Wally tightens his grip', ' battling the G’s.']
# Parts: ['He looks ahead. SCREAMS.']
# Parts: ['HUNDREDS OF BNL SATELLITES']
# Parts: ['litter the outer atmosphere.']
# Parts: ['The ship bursts through the layer.']
# Parts: ['EXT. SPACE - CONTINUOUS']
# Parts: ['The recon ship breaks free of the planet.']
# Parts: ['Its boosters shut down.']
# Parts: ['Wally takes in the sudden QUIETNESS OF SPACE.']
# Parts: ['Looks back at his planet.']
# Parts: ['WALLY']
# Parts: ['Oooh...']
# Parts: ['Weightlessness takes effect.']
# Parts: ['Wally almost floats away.']
# Parts: ['Grabs hold of the ship.']
# Parts: ['Knocks on a WINDOW near Eve.']
# Parts: ['WALLY']
# Parts: ['E-vah!']
# Parts: ['No response. She remains shut down.']
# Parts: ['Wally points out at the stars.']
# Parts: ['It is the most spectacular light show possible.']
# Parts: ['And Wally has a front row seat.']
# Parts: ['MONTAGE OF CELESTIAL SPECTACLES']
# Parts: ['- The ship flies past the MOON.']
# Parts: ['A BILLBOARD stands next to the abandoned APOLLO MOON ROVER.']
# Parts: ['“BNL Outlet Coming Soon.”']
# Parts: ['- The ship passes by the SUN.']
# Parts: ['Wally pops open his solar panels.']
# Parts: ['21.']
# Parts: ['Instantly recharges.']
# Parts: ['- The ship cruises alongside SATURN’S OUTER RINGS.']
# Parts: ['Wally runs his hand through the tiny particles of ice.']
# Parts: ['DISSOLVE TO:']
# Parts: ['EXT. RECON SHIP - DAYS LATER']
# Parts: ['A DUMBBELL NEBULA slowly twists in space.']
# Parts: ['Wally is mesmerized by it.']
# Parts: ['Leads his eye to a LIGHT', ' growing in the distance ahead.']
# Parts: ['A planet?']
# Parts: ['No. A starliner.']
# Parts: ['Gigantic in size.']
# Parts: ['The “AXIOM”.']
# Parts: ['The now tiny recon ship heads straight for it.']
# Parts: ['INT. DOCKING BAY']
# Parts: ['TWO TUG-ROCKETS guide the ship in.']
# Parts: ['It locks into GIANT BRACES fixed on the deck.']
# Parts: ['The impact knocks Wally off.']
# Parts: ['He lands in the scaffolding of the front brace.']
# Parts: ['Suddenly the entire dock comes to life.']
# Parts: ['Robotic arms and service robots of all types appear.']
# Parts: ['...Rise from the floor...']
# Parts: ['..Lower from the ceiling...']
# Parts: ['It’s a cacophony of automation.']
# Parts: ['They all attend to the ship.']
# Parts: ['EVE']
# Parts: ['and four other probes slide out of the ship’s side.']
# Parts: ['Suspended in a horizontal rack.']
# Parts: ['Wally is surprised to find her facing him.']
# Parts: ['She remains shut down.']
# Parts: ['Just a few feet away with a giant abyss between them.']
# Parts: ['WALLY']
# Parts: ['Ee-vah... ?']
# Parts: ['A SQUAD OF CLEANER ROBOTS emerge onto the dock.']
# Parts: ['A small roller BRUSH-BOT (M-O) leads.']
# Parts: ['M-O']
# Parts: ['(beeps)']
# Parts: ['[Hold up.]']
# Parts: ['22.']
# Parts: ['Waits for the FLOOR LINES to appear.']
# Parts: ['Depict their exact path of action.']
# Parts: ['M-O']
# Parts: ['(beeps)']
# Parts: ['[Okay. Go.]']
# Parts: ['They file out on the line.']
# Parts: ['A crane-bot lowers Eve from the rack.']
# Parts: ['M-O and his cleaning crew stand ready.']
# Parts: ['M-O scans Eve.']
# Parts: ['ON M-O’S DISPLAY POV']
# Parts: ['Scan reads: “%16 Foreign Contaminant.”']
# Parts: ['M-O is disgusted.']
# Parts: ['Revs his brush roller. Moves in for the clean.']
# Parts: ['A VACU-BOT follows after him.']
# Parts: ['Then a SPRAY-BOT and BUFFER-BOT finish off.']
# Parts: ['The cleaning crew waits for probe #2.']
# Parts: ['Wally studies the routine.']
# Parts: ['Figures out a way to climb down to Eve.']
# Parts: ['When the crane returns', ' Wally poses as probe #3.']
# Parts: ['The crane grabs him instead.']
# Parts: ['M-O turns around to clean the next probe.']
# Parts: ['Wally is lowered in front of him.']
# Parts: ['Boxes up.']
# Parts: ['Confused', ' M-O scans him.']
# Parts: ['ON M-O’S DISPLAY POV']
# Parts: ['Scan reads: “%100 Foreign Contaminant.”']
# Parts: ['M-O is horrified by such filth.']
# Parts: ['A RED SIREN LIGHT rises from his head.']
# Parts: ['M-O']
# Parts: ['[Oh', ' no', ' no', ' no. This is all wrong.]']
# Parts: ['He scrubs Wally full force.']
# Parts: ['Wally’s front panel pushes him away.']
# Parts: ['Confused', ' M-O moves to clean him again.']
# Parts: ['Wally backs away.']
# Parts: ['Leaves a DIRT TRAIL.']
# Parts: ['M-O curses:']
# Parts: ['M-O']
# Parts: ['[You made the floor all dirty! Stop it!]']
# Parts: ['23.']
# Parts: ['M-O furiously scrubs the floor.']
# Parts: ['Wally peeks out', ' amused by this neurotic little guy.']
# Parts: ['ON FAR WALL']
# Parts: ['Two STEWARD ROBOTS come out of the wall.']
# Parts: ['Act like hovering caution signs.']
# Parts: ['A small robot (GOPHER) shoots out a PNEUMATIC TUBE.']
# Parts: ['He bears epaulet like shoulders and a siren for a face.']
# Parts: ['Gopher beeps an ELECTRONIC ORDER for the Stewards to follow.']
# Parts: ['BACK ON M-O AND WALLY']
# Parts: ['M-O just finishes cleaning the floor.']
# Parts: ['Wally is fascinated.']
# Parts: ['Impishly makes another mark.']
# Parts: ['M-O compulsively cleans it. Can’t resist.']
# Parts: ['M-O']
# Parts: ['[Look', ' it stays clean. You got that?]']
# Parts: ['Wally wipes the bottom of his tread on M-O’s face.']
# Parts: ['M-O loses it.']
# Parts: ['Scrubs his own face.']
# Parts: ['Gopher and his steward escort arrive.']
# Parts: ['The cleaning crew stand at attention.']
# Parts: ['Wally boxes back up with the probes.']
# Parts: ['Gopher begins scanning each probe.']
# Parts: ['Moves down the line.']
# Parts: ['Scans Wally...moves on to the next probe...']
# Parts: ['Stops -- Wait a minute.']
# Parts: ['Turns back.']
# Parts: ['Wally is gone.']
# Parts: ['Gopher shrugs it off. Proceeds...']
# Parts: ['Reaches Eve.']
# Parts: ['Doesn’t notice Wally hidden behind her.']
# Parts: ['Gopher scans her BLINKING PLANT LIGHT --']
# Parts: ['The entire dock goes to “Code Green”!']
# Parts: ['Alarms sound.']
# Parts: ['Green lights flash.']
# Parts: ['All automation stops.']
# Parts: ['In rapid succession...']
# Parts: ['...A HOVER-TRANSPORT glides up to Gopher...']
# Parts: ['...A crane-bot loads Eve...']
# Parts: ['...Curved energy bands lock her down...']
# Parts: ['...Gopher assumes the driver’s seat...']
# Parts: ['It’s all moving too fast for Wally.']
# Parts: ['Suddenly Eve’s transport heads for the ELEVATOR.']
# Parts: ['24.']
# Parts: ['WALLY']
# Parts: ['Ee-vah!']
# Parts: ['Wally chases after them.']
# Parts: ['Grabs onto the back of the transport.']
# Parts: ['They disappear into the elevator.']
# Parts: ['The cleaning crew files out.']
# Parts: ['Follow their lines back to their hold.']
# Parts: ['M-O stops short.']
# Parts: ['Notices Wally’s FILTHY TRACKS crossing his path.']
# Parts: ['ON M-O’S DISPLAY']
# Parts: ['Reads: “FOREIGN CONTAMINANT”']
# Parts: ['The tracks lead to the elevator.']
# Parts: ['M-O’s neurosis takes over.']
# Parts: ['Must clean dirt.']
# Parts: ['He makes a radical decision and...']
# Parts: ['...jumps off his line.']
# Parts: ['Starts methodically cleaning the dirt trail.']
# Parts: ['INT. ELEVATOR']
# Parts: ['Gopher waits patiently as the floors pass.']
# Parts: ['Wally hidden behind the transport.']
# Parts: ['Peeks at Eve.']
# Parts: ['Pets her blank faceplate.']
# Parts: ['WALLY']
# Parts: ['(quiet beeps)']
# Parts: ['[It’ll be okay', ' Eve.]']
# Parts: ['The ELEVATOR DOORS suddenly open.']
# Parts: ['INT. ROBOT SERVICE TUNNEL - CONTINUOUS']
# Parts: ['DOZENS OF ROBOTS speed along a multi-lane passageway.']
# Parts: ['All following glowing lines on the floor.']
# Parts: ['Wally’s head whipsaws back and forth.']
# Parts: ['Tries to process it all.']
# Parts: ['Doesn’t notice Gopher’s transport merge into traffic...']
# Parts: ['...without him!']
# Parts: ['Wally shrinks from the high-speed traffic.']
# Parts: ['Timidly attempts to merge.']
# Parts: ['Sticks out one tread...']
# Parts: ['-- Instantly causes a ROBOT PILE-UP.']
# Parts: ['Wally boxes up. Guns it.']
# Parts: ['Weaves across all the lines on the floor.']
# Parts: ['Bounces off robots like bumper cars.']
# Parts: ['25.']
# Parts: ['Barely able to navigate the chaos.']
# Parts: ['Takes refuge in the middle of an INTERSECTION.']
# Parts: ['Scans for Eve...']
# Parts: ['ON WALLY’S POV DISPLAY']
# Parts: ['...a PAINT-BOT paints a wall sign...']
# Parts: ['...A GARBAGE-BOT dumps trash into a wall chute...']
# Parts: ['...Down the hall', ' Eve’s transport glides up a ramp...']
# Parts: ['WALLY']
# Parts: ['EE-VAH!']
# Parts: ['Wally chases after them.']
# Parts: ['INT. UPPER HALLWAY - CONTINUOUS']
# Parts: ['Wally flies up the ramp.']
# Parts: ['Nearly collides with a merging HOVER CHAIR.']
# Parts: ['It blocks his way.']
# Parts: ['Wally gains alongside it', ' and discovers']
# Parts: ['A HUMAN PASSENGER']
# Parts: ['sitting', ' reclined', ' in the chair.']
# Parts: ['He is large', ' round and soft - like a big baby.']
# Parts: ['Wears a red', ' BNL jumpsuit.']
# Parts: ['The chair seems to be steering itself.']
# Parts: ['Guided by floor lines', ' just like the robots.']
# Parts: ['Speaker headrests block his peripheral vision.']
# Parts: ['A HOLOGRAPHIC SCREEN floats inches in front of his face.']
# Parts: ['He converses with a SECOND PASSENGER on screen:']
# Parts: ['PASSENGER #1']
# Parts: ['Well', ' I’ve been in my cabin all morning']
# Parts: ['so let’s hover over to the driving range']
# Parts: ['and hit a few virtual balls into space.']
# Parts: ['PASSENGER #2 (ON SCREEN)']
# Parts: ['Nah', ' we did that yesterday. I don’t want']
# Parts: ['to do that.']
# Parts: ['PASSENGER #1']
# Parts: ['Well then what do you want to do?']
# Parts: ['ON WALLY']
# Parts: ['He looks over his shoulder.']
# Parts: ['Passenger #2 is floating right next to them.']
# Parts: ['Isolated in his own hover chair.']
# Parts: ['Also in a red jumpsuit. Also a big baby.']
# Parts: ['26.']
# Parts: ['PASSENGER #2']
# Parts: ['I don’t know. Something.']
# Parts: ['Both humans are totally unaware of the other’s presence.']
# Parts: ['They all exit the hallway. Merge into the...']
# Parts: ['ECONOMY CLASS COURTYARD']
# Parts: ['Wally is in awe.']
# Parts: ['Hundreds of floors of GUEST ROOMS rise on all sides.']
# Parts: ['THOUSANDS OF PASSENGERS fill the giant space.']
# Parts: ['All reclined and riding on hover chairs.']
# Parts: ['MULTIPLE FLOOR LINES guide their chairs in all directions.']
# Parts: ['Humans have become the most extreme form of couch potatoes.']
# Parts: ['Absolutely no reason to ever get up.']
# Parts: ['No purpose.']
# Parts: ['Every one of them engrossed in their video screens.']
# Parts: ['Cocooned in virtual worlds.']
# Parts: ['Over-developed fingers tap ARMREST KEYPADS.']
# Parts: ['The controls allow them to steer...']
# Parts: ['...order food...']
# Parts: ['...play games...']
# Parts: ['...and most of all...']
# Parts: ['...CHAT MINDLESSLY with other passengers:']
# Parts: ['The CHATTER is deafening.']
# Parts: ['No one notices Wally at all.']
# Parts: ['He drives into the endless human traffic.']
# Parts: ['MISC. FEMALE PASSENGER']
# Parts: ['Bot', ' over here!']
# Parts: ['A DRINK-BOT floats over to a passenger.']
# Parts: ['Puts a fresh drink in her open hand.']
# Parts: ['Wally flows with the traffic into a LARGE TUNNEL.']
# Parts: ['MISC. PASSENGERS']
# Parts: ['I can’t hear you...I’m in a tunnel.']
# Parts: ['You’re breaking up...Oh', ' okay. You’re']
# Parts: ['back. I can hear you now...']
# Parts: ['They spill out into the BRIGHT LIGHT of the']
# Parts: ['MAIN CONCOURSE (COACH CLASS)']
# Parts: ['A city-sized', ' mall-like environment.']
# Parts: ['All under a GIANT DOME.']
# Parts: ['The ceiling simulates the sun and sky.']
# Parts: ['A BNL LOGO (w/ time & temp) appears on the FACE OF THE SUN.']
# Parts: ['27.']
# Parts: ['SHIP’S COMPUTER (V.O.)']
# Parts: ['Buy N Large. Everything you need to be']
# Parts: ['happy. Your day is very important to us.']
# Parts: ['Wally is gobsmacked.']
# Parts: ['A PASSENGER (JOHN) hovers up alongside him.']
# Parts: ['Tries to hand off his empty drink cup to Wally.']
# Parts: ['JOHN']
# Parts: ['Hey', ' Drink-bot.']
# Parts: ['Wally shies away.']
# Parts: ['John reaches farther out with the cup.']
# Parts: ['JOHN']
# Parts: ['Here', ' take the cup. Take the cup -- Whoa!']
# Parts: ['Reaches too far.']
# Parts: ['John falls to the floor.']
# Parts: ['Flails like an upside down turtle.']
# Parts: ['Unable to stand on his baby legs.']
# Parts: ['Instantly', ' SIRENS.']
# Parts: ['Wally watches TWO STEWARDS arrive.']
# Parts: ['Block John’s accident.']
# Parts: ['EMERGENCY LINES appear on the floor.']
# Parts: ['Redirect the hover chair traffic.']
# Parts: ['John reaches out for assistance.']
# Parts: ['Nobody notices. Just drive past.']
# Parts: ['JOHN']
# Parts: ['Stewards? Hello? Uhh', ' help.']
# Parts: ['STEWARD']
# Parts: ['Please remain stationary. A service-bot']
# Parts: ['will be here to assist you momentarily.']
# Parts: ['Suddenly John begins to rise.']
# Parts: ['JOHN']
# Parts: ['Uhh...Hey! What’s going on?']
# Parts: ['Wally lifting him up from behind.']
# Parts: ['Loads him back onto his chair.']
# Parts: ['John doesn’t know how to react.']
# Parts: ['Wally waves hello.']
# Parts: ['WALLY']
# Parts: ['Wally!']
# Parts: ['JOHN']
# Parts: ['Uhh... John.']
# Parts: ['28.']
# Parts: ['WALLY']
# Parts: ['Ee-vah?']
# Parts: ['JOHN']
# Parts: ['Uh no', ' John.']
# Parts: ['Wally scans the concourse.']
# Parts: ['Spots Eve’s transport about to board a MONORAIL.']
# Parts: ['He races after them.']
# Parts: ['Abandons the stunned John.']
# Parts: ['WALLY']
# Parts: ['Ee-vah!']
# Parts: ['JOHN']
# Parts: ['(small wave)']
# Parts: ['Bye...Wally.']
# Parts: ['ON MONORAIL']
# Parts: ['It pulls out of the station.']
# Parts: ['Wally leaps on.']
# Parts: ['Barely catches the last car.']
# Parts: ['It glides down the concourse.']
# Parts: ['INT. “ALL DAY” CARE CENTER']
# Parts: ['A NANNY-BOT supervises a group of TODDLERS.']
# Parts: ['All wearing matching BNL ONESIES.']
# Parts: ['Motionless in their HOVER RINGS.']
# Parts: ['They stare at educational programming on their holo-screens.']
# Parts: ['NANNY-BOT']
# Parts: ['“A”! “A” is for “Axiom”', ' your home sweet']
# Parts: ['home. “B”! “B” is for “Buy N Large”', ' your']
# Parts: ['very best friend...']
# Parts: ['OUT THE WINDOW']
# Parts: ['Wally’s monorail glides past.']
# Parts: ['ON MONORAIL']
# Parts: ['Wally takes in the overstimulating scenery.']
# Parts: ['Dozens of THEMED FOOD RESTAURANTS whizz by.']
# Parts: ['Each specialty is served in the same JUMBO PLASTIC CUP.']
# Parts: ['SHIP’S COMPUTER (V.O.)']
# Parts: ['Mmmmm! Time for lunch in a cup.']
# Parts: ['Wally now notices his fellow passengers.']
# Parts: ['They all slurp from similar cups.']
# Parts: ['29.']
# Parts: ['Next', ' the monorail passes a BEAUTY SALON.']
# Parts: ['BEAUTICIAN-BOTS primp and style passengers.']
# Parts: ['SHIP’S COMPUTER (V.O.)']
# Parts: ['Feel beautiful.']
# Parts: ['BEAUTICIAN-BOTS']
# Parts: ['(pre-recorded lines)']
# Parts: ['...It’s the new you...Oh stunning...You']
# Parts: ['look great...I know honey...Ahh. Men...']
# Parts: ['They pass through the FASHION DISTRICT.']
# Parts: ['ENORMOUS BILLBOARDS hawk the latest color schemes.']
# Parts: ['SHIP’S COMPUTER (V.O.)']
# Parts: ['Attention', ' Axiom shoppers. Try blue! It’s']
# Parts: ['the new red!']
# Parts: ['MONORAIL PASSENGERS']
# Parts: ['Oooohh...']
# Parts: ['Passengers next to Wally press their chair buttons.']
# Parts: ['Their JUMPSUITS change from RED TO BLUE.']
# Parts: ['WALLY']
# Parts: ['Whoa.']
# Parts: ['Their monorail speeds into a glass tunnel.']
# Parts: ['INSIDE THE TUNNEL']
# Parts: ['Wally looks past a PASSENGER (MARY) next to him.']
# Parts: ['Spots Eve on the other side.']
# Parts: ['Wally tries to sneak behind Mary.']
# Parts: ['But her chair moves backwards.']
# Parts: ['Smashes Wally against the back wall.']
# Parts: ['No way getting past her.']
# Parts: ['Wally politely tries to get Mary’s attention.']
# Parts: ['She’s oblivious.']
# Parts: ['Chats incessantly on her holo-screen:']
# Parts: ['MARY']
# Parts: ["Date?! (derisive snort) Don't get me"]
# Parts: ["started! Every holo-date I've been on has"]
# Parts: ['been a virtual disaster! If I could just']
# Parts: ["meet one who wasn't so superficial. There"]
# Parts: ['are no good men out there!...']
# Parts: ['Wally tries to fold back her speaker headrest.']
# Parts: ['Accidentally breaks it off.']
# Parts: ['MARY (CONT’D)']
# Parts: ["...I know! I know ‘cause I've scrolled"]
# ...
# Parts: ['And for the first time...']
# Parts: ['...all of humanity reaches out to one another.']
# Parts: ['CLOSE UPS of hands holding hands.']
# Parts: ['Everyone piles up on the listing side.']
# Parts: ['The plant is buried underneath the mass of humanity.']
# Parts: ['Eve searches desperately amongst them.']
# Parts: ['ON JOHN & MARY']
# Parts: ['They hang together off their chairs.']
# Parts: ['CRYING TODDLERS just above them.']
# Parts: ['The kiddies slip out of their hover rings.']
# Parts: ['Mary GASPS in horror.']
# Parts: ['Yells to John:']
# Parts: ['MARY']
# Parts: ['John', ' get ready to have some kids!']
# Parts: ['They purposefully let go of their chairs.']
# Parts: ['Grab hands', ' forming a human chain.']
# Parts: ['Catch the toddlers.']
# Parts: ['All slide together down the Lido Deck.']
# Parts: ['The TODDLERS GIGGLE the whole way down.']
# Parts: ['They land at the bottom', ' next to Eve.']
# Parts: ['An empty monorail car tips off the upper deck...']
# Parts: ['...lands on the pool level.']
# Parts: ['It begins sliding down the Lido Deck.']
# Parts: ['Smashes vacant hover chairs in its wake.']
# Parts: ['MARY']
# Parts: ['(Gasp)']
# Parts: ['LOOK OUT!']
# Parts: ['Eve looks up. Sees the Monorail sliding towards them.']
# Parts: ['She stops the car before it hits.']
# Parts: ['Struggles to hold it up.']
# Parts: ['Can’t let it crush the passengers below her.']
# Parts: ['ON BRIDGE']
# Parts: ['Auto keeps the ship tilted.']
# Parts: ['Glides over to the HOLO-DETECTOR BUTTON.']
# Parts: ['Switches it off.']
# Parts: ['ON LIDO DECK']
# Parts: ['84.']
# Parts: ['The holo-detector begins to lower back into the floor...']
# Parts: ['Wally is still hanging onto it.']
# Parts: ['Barely functioning.']
# Parts: ['He uses all his strength...']
# Parts: ['...and wedges himself under the UPPER LIP of the detector.']
# Parts: ['Stops it from disappearing into the floor.']
# Parts: ['The pressure squeezes Wally into a box.']
# Parts: ['ON BRIDGE']
# Parts: ['The holo-detector button buzzes and flashes.']
# Parts: ['Something’s wrong.']
# Parts: ['Auto calls up a LIDO DECK SECURITY CAMERA VIEW.']
# Parts: ['Discovers Wally wedged in the device.']
# Parts: ['AUTO']
# Parts: ['No.']
# Parts: ['Auto presses down on the “off” button.']
# Parts: ['ON WALLY']
# Parts: ['The holo-detector’s hydraulics fight against him.']
# Parts: ['Wally desperately fights to hold it up.']
# Parts: ['Begins slowly to expand himself...']
# Parts: ['...and push the holo-detector back up!!']
# Parts: ['ON BRIDGE']
# Parts: ['The Captain watches Wally’s heroic rise on screen.']
# Parts: ['Auto flips out his TASER.']
# Parts: ['Jams it into the “off” button.']
# Parts: ['Short circuits it.']
# Parts: ['CAPTAIN']
# Parts: ['NO!!']
# Parts: ['BACK ON WALLY']
# Parts: ['The holo-detector reverses full force.']
# Parts: ['Crushes Wally.']
# Parts: ['We can’t tell if he survived the crush.']
# Parts: ['Eve calls out for him.']
# Parts: ['Trapped', ' holding up the monorail car above the passengers.']
# Parts: ['BACK ON BRIDGE']
# Parts: ['The Captain watches Wally being crushed.']
# Parts: ['That’s it.']
# Parts: ['He braces his arms against the floor...']
# Parts: ['85.']
# Parts: ['...and rises up on HIS OWN TWO FEET...']
# Parts: ['ON JUMBOTRON SCREEN']
# Parts: ['The passengers collectively GASP.']
# Parts: ['Their Captain is standing...']
# Parts: ['...and walking himself up the railing...']
# Parts: ['...towards Auto!']
# Parts: ['They CHEER!']
# Parts: ['ON BRIDGE']
# Parts: ['Auto hears the distant cheering.']
# Parts: ['Wonders what’s up.']
# Parts: ['CAPTAIN (O.S.)']
# Parts: ['Auto!']
# Parts: ['Auto whips around.']
# Parts: ['Shocked to see the Captain standing (albeit wobbly).']
# Parts: ['Finds himself face to face with him.']
# Parts: ['Auto flips out his TASER.']
# Parts: ['Rushes at him.']
# Parts: ['The Captain grabs it. They wrestle.']
# Parts: ['The taser ARCS in the Captain’s face.']
# Parts: ['He flinches. Looks up.']
# Parts: ['Sees a CONTROL PANEL high up on Auto’s column...']
# Parts: ['...and smirks.']
# Parts: ['The Captain looks Auto in the eye.']
# Parts: ['Raises a finger up to the control panel...']
# Parts: ['...to the “AUTOPILOT” BUTTON...']
# Parts: ['...and flicks the switch to “MANUAL”.']
# Parts: ['CAPTAIN']
# Parts: ['(grits his teeth)']
# Parts: ['Auto', ' you are relieved of duty.']
# Parts: ['AUTO']
# Parts: ['Noo --']
# Parts: ['Auto is instantly turned off.']
# Parts: ['The Captain smiles triumphantly.']
# Parts: ['Grabs the wheel with both hands.']
# Parts: ['Makes the ship level again.']
# Parts: ['ON LIDO DECK']
# Parts: ['The passengers all spill across the deck.']
# Parts: ['Shaken but OK.']
# Parts: ['Eve sets the monorail down.']
# Parts: ['Rockets over to the holo-detector.']
# Parts: ['86.']
# Parts: ['Wally is pinned under the lip of the holo-detector.']
# Parts: ['Eve tries to lift it up.']
# Parts: ['It won’t budge.']
# Parts: ['She looks back to the crowd.']
# Parts: ['EVE']
# Parts: ['PLANT! PLANT!']
# Parts: ['ON M-O']
# Parts: ['He searches the crowd for the plant.']
# Parts: ['Humans begin to stand for the first time all around him.']
# Parts: ['Through his POV he spots the plant mixed in among them.']
# Parts: ['“FOREIGN CONTAMINANT” flashes on his display screen.']
# Parts: ['ON EVE']
# Parts: ['She fights to keep the machine from crushing Wally further.']
# Parts: ['M-O (O.S.)']
# Parts: ['Ee-vah!']
# Parts: ['M-O holds the plant up from across the Lido Deck.']
# Parts: ['The vacu-bot shoots it into the hands of a passenger.']
# Parts: ['Humans and robots form an impromptu fire line.']
# Parts: ['Toss it up to Eve on stage.']
# Parts: ['She shoves the plant into the device.']
# Parts: ['The detector instantly scans the plant.']
# Parts: ['SHIP’S COMPUTER (V.O.)']
# Parts: ['Plant origin verified. Course set for']
# Parts: ['Earth.']
# Parts: ['Slowly', ' the holo-detector rises...']
# Parts: ['Wally topples out from underneath.']
# Parts: ['Badly crushed and leaking oil.']
# Parts: ['Eve GASPS in horror.']
# Parts: ['M-O and the Rejects avert their eyes.']
# Parts: ['Passengers recoil as well.']
# Parts: ['WIDE ON DOME CEILING']
# Parts: ['It converts into a GIANT STAR CHART.']
# Parts: ['Rapidly plots a course for Earth.']
# Parts: ['SHIP’S COMPUTER (V.O.)']
# Parts: ['Ten seconds to hyperjump.']
# Parts: ['Eve lifts Wally up.']
# Parts: ['No sign of life.']
# Parts: ['EVE']
# Parts: ['No! WALLY!!']
# Parts: ['87.']
# Parts: ['M-O’s head drops in despair.']
# Parts: ['The passengers witness grief for the first time.']
# Parts: ['Begin to have new feelings of their own: sadness', ' sympathy.']
# Parts: ['Mary begins to cry.']
# Parts: ['Buries her head in John’s shoulder.']
# Parts: ['MARY']
# Parts: ['Oh no! Wally...']
# Parts: ['SHIP’S COMPUTER']
# Parts: ['Nine', ' eight', ' seven', ' six', ' five', ' four', '']
# Parts: ['three', ' two', ' one', ' zero.']
# Parts: ['The ceiling countdown hits “0:00.”']
# Parts: ['EXT. AXIOM']
# Parts: ['The ship jumps to light speed.']
# Parts: ['BACK INSIDE']
# Parts: ['The passengers and robots are thrown off their feet.']
# Parts: ['Everyone holds on to one another.']
# Parts: ['INT. BRIDGE']
# Parts: ['The Captain struggles to keep control of the steering wheel.']
# Parts: ['Fights the G-forces.']
# Parts: ['INT. LIDO DECK']
# Parts: ['Humans and robots hang on for dear life.']
# Parts: ['John and Mary cling to each other and the babies.']
# Parts: ['ON EVE']
# Parts: ['She holds tightly to Wally.']
# Parts: ['Still calling out his name.']
# Parts: ['No response.']
# Parts: ['ON SPACE']
# Parts: ['The Axiom zooms through hyperspace.']
# Parts: ['EXT. EARTH - HILLSIDE - DAY']
# Parts: ['The cockroach waits obediently on the hill.']
# Parts: ['Exactly where Wally told him to stay.']
# Parts: ['His antennae twitch with boredom.']
# Parts: ['88.']
# Parts: ['A RED DOT']
# Parts: ['appears on the ground.']
# Parts: ['The cockroach watches the dot run down the hillside.']
# Parts: ['The ground begins to shake.']
# Parts: ['Daylight dims.']
# Parts: ['The insect looks to the sky.']
# Parts: ['ON CLOUD COVER']
# Parts: ['A DARK PATCH grows behind the clouds.']
# Parts: ['Blots out the sunlight.']
# Parts: ['The Axiom’s keel breaks through.']
# Parts: ['Its shadow swallows up the entire landscape.']
# Parts: ['The cockroach senses his master’s return.']
# Parts: ['HUNDREDS OF RED DOTS rush past him.']
# Parts: ['He eagerly chases after them.']
# Parts: ['ON AXIOM']
# Parts: ['The city-size starliner lowers gracefully from the sky.']
# Parts: ['Pushes back the clouds to the horizon.']
# Parts: ['EXT. OPPOSITE SIDE OF BAY - AXIOM PORT']
# Parts: ['The CIRCLE OF DOTS triangulate over the abandoned berth.']
# Parts: ['Converge over the port’s LANDING SHAFT.']
# Parts: ['Thousands of feet deep.']
# Parts: ['The ship’s keel descends into it.']
# Parts: ['The earth shudders.']
# Parts: ['Trash towers tumble in the distance.']
# Parts: ['...Then all is quiet.']
# Parts: ['ON BELLY OF THE AXIOM']
# Parts: ['A ROW OF GIANT DOORS open on the side of the ship.']
# Parts: ['MULTIPLE GANGWAYS automatically extend.']
# Parts: ['Connect with BUILT-IN TERMINALS on the port.']
# Parts: ['The Captain walks out gingerly.']
# Parts: ['Holding the boot w/ plant.']
# Parts: ['The other passengers step out on their own legs.']
# Parts: ['Wobble like toddlers.']
# Parts: ['They squint up at the harsh sunlight.']
# Parts: ['A commotion is heard from the back.']
# Parts: ['Somebody trying to push through.']
# Parts: ['EVE']
# Parts: ['appears out of the crowd.']
# Parts: ['Cradles a BOXED UP WALLY in her arms.']
# Parts: ['89.']
# Parts: ['M-O and the Rejects follow behind her.']
# Parts: ['They rush across the gangway.']
# Parts: ['The cockroach meets up with Eve.']
# Parts: ['Climbs up onto Wally.']
# Parts: ['Doesn’t understand why his master isn’t responding.']
# Parts: ['Eve urgently scans the landscape.']
# Parts: ['Locks on to WALLY’S TRUCK in the distance.']
# Parts: ['She takes to the air.']
# Parts: ['M-O and the Rejects chase after her down the gangway.']
# Parts: ['M-O']
# Parts: ['(beeps)']
# Parts: ['[Eve! Wait!]']
# Parts: ['The Captain respectfully removes his hat.']
# Parts: ['Good luck', ' friend.']
# Parts: ['INT. WALLY’S TRUCK']
# Parts: ['The interior is dark and still.']
# Parts: ['Suddenly the junk jingles and clinks as the back door opens.']
# Parts: ['Eve flies inside with Wally.']
# Parts: ['Sets him on the floor.']
# Parts: ['She scans the rotating shelves at high speed.']
# Parts: ['Grabs a CAR JACK.']
# Parts: ['Ratchets up Wally’s crushed body...']
# Parts: ['QUICK SHOTS']
# Parts: ['...SPARE PARTS being grabbed by Eve...']
# Parts: ['...Frantically installs the new parts into Wally...']
# Parts: ['...Her arms a blur of precision in motion...']
# Parts: ['...Replaces his damaged CIRCUIT BOARD. The final piece...']
# Parts: ['...She opens his new solar panels...']
# Parts: ['...and BLASTS a hole in the ceiling with her gun.']
# Parts: ['OUT ON THE EMPTY BAY']
# Parts: ['The rejects stop.']
# Parts: ['See the roof of Wally’s truck explode.']
# Parts: ['Oh no.']
# Parts: ['BACK IN THE TRUCK']
# Parts: ['A shaft of sunlight beams down on Wally.']
# Parts: ['Eve holds her breath', ' watches...']
# Parts: ['Waits...']
# Parts: ['...Beep...']
# Parts: ['...Beep...']
# Parts: ['90.']
# Parts: ['WALLY (O.S.)']
# Parts: ['(Apple “reboot” SFX)']
# Parts: ['Wally’s meter fully charges.']
# Parts: ['His head slowly rises from his box.']
# Parts: ['Blinks.']
# Parts: ['The cockroach hops with joy.']
# Parts: ['Eve is relieved.']
# Parts: ['...She holds out her hand to him.']
# Parts: ['EVE']
# Parts: ['(with love)']
# Parts: ['Wally...']
# Parts: ['Wally gives her a blank stare.']
# Parts: ['He turns away from Eve. Motors out the truck.']
# Parts: ['She grabs him.']
# Parts: ['Turns him back around.']
# Parts: ['EVE']
# Parts: ['(It’s me!)']
# Parts: ['Eve!']
# Parts: ['Wally just stares.']
# Parts: ['Doesn’t seem to know who she is.']
# Parts: ['EVE']
# Parts: ['(hums)']
# Parts: ['[Here', ' look at these.]']
# Parts: ['She grabs the RUBIK’S CUBE and LIGHT BULB from the shelf.']
# Parts: ['The light bulb glows in her hand.']
# Parts: ['She gives them to Wally.']
# Parts: ['No reaction.']
# Parts: ['EVE']
# Parts: ['(Remember?)']
# Parts: ['Wally?']
# Parts: ['Wally looks blankly at the junk on the shelves.']
# Parts: ['EVE']
# Parts: ['(hums)']
# Parts: ['[I know!]']
# Parts: ['She hovers over to the video player.']
# Parts: ['Plays HELLO DOLLY.']
# Parts: ['Looks back to see if it has any effect.']
# Parts: ['Wally is over at the shelves.']
# Parts: ['Has scooped all his prized possessions into his compactor.']
# Parts: ['Crushes them into a cube.']
# Parts: ['Eve is gut-punched.']
# Parts: ['91.']
# Parts: ['Wally motors outside.']
# Parts: ['Runs over the cockroach on his way out.']
# Parts: ['The insect pops back to life.']
# Parts: ['Watches his friend in shock.']
# Parts: ['EXT. WALLY’S TRUCK - DAY']
# Parts: ['Wally rolls up to a nearby trash pile.']
# Parts: ['Scoops up trash. Spits out a cube.']
# Parts: ['Eve hovers over to him.']
# Parts: ['Still in disbelief.']
# Parts: ['EVE']
# Parts: ['(somber)']
# Parts: ['No.']
# Parts: ['Wally continues to stack his cubes.']
# Parts: ['She stops him.']
# Parts: ['Lifts his head. Stares into his eyes.']
# Parts: ['Nobody home.']
# Parts: ['Eve presses his “play” button.']
# Parts: ['Nothing but STATIC.']
# Parts: ['Eve begins to panic.']
# Parts: ['Shakes him.']
# Parts: ['EVE']
# Parts: ['Wally...Wally! WALLY!']
# Parts: ['No response.']
# Parts: ['He’s gone.']
# Parts: ['She hovers in silence next to him for a long time...']
# Parts: ['Finally', ' Eve grasps Wally’s hand.']
# Parts: ['Forces his fingers to interlace with hers.']
# Parts: ['Holds him close one last time.']
# Parts: ['Leans her head against his.']
# Parts: ['Hums softly.']
# Parts: ['EVE']
# Parts: ['[Hums IOTAM]']
# Parts: ['She touches her forehead to his.']
# Parts: ['Goodbye Wally.']
# Parts: ['A TINY SPARK between them.']
# Parts: ['Eve turns to hover away.']
# Parts: ['Jerked back.']
# Parts: ['Her fingers caught between his.']
# Parts: ['She checks his eyes again.']
# Parts: ['Nothing.']
# Parts: ['But then...']
# Parts: ['92.']
# Parts: ['...a tiny SERVO NOISE.']
# Parts: ['She looks down at their hands.']
# Parts: ['CLOSE ON WALLY’S FINGERS']
# Parts: ['They start to move.']
# Parts: ['Slowly close around Eve’s.']
# Parts: ['She looks back at his face.']
# Parts: ['Wally’s eyes gradually come into focus.']
# Parts: ['His brows raise...']
# Parts: ['WALLY']
# Parts: ['Ee-vah?']
# Parts: ['EVE']
# Parts: ['Wally!']
# Parts: ['He notices their hands entwined.']
# Parts: ['His dream come true.']
# Parts: ['WALLY']
# Parts: ['(amazed)']
# Parts: ['Ee-vah!!']
# Parts: ['She giggles.']
# Parts: ['INSIDE THE TRUCK']
# Parts: ['The “Hello Dolly” tape reaches the finale of IOTAM.']
# Parts: ['“And that is all that love’s about...”']
# Parts: ['BACK OUTSIDE']
# Parts: ['Eve and Wally stare into each other’s eyes.']
# Parts: ['M-O and the Rejects finally reach the truck.']
# Parts: ['They begin to celebrate.']
# Parts: ['Wally’s alive!']
# Parts: ['Then M-O realizes they need privacy.']
# Parts: ['Herds the Rejects O.S.']
# Parts: ['M-O']
# Parts: ['Go! Go', ' go go!']
# Parts: ['Wally and Eve’s foreheads touch.']
# Parts: ['Together now and ever more.']
# Parts: ['“...and we’ll recall when time runs out...”']
# Parts: ['DISSOLVE TO:']
# Parts: ['CLOSE UP OF THE PLANT']
# Parts: ['93.']
# Parts: ['Newly planted in the earth.']
# Parts: ['Small hands water it gently.']
# Parts: ['PULL OUT to reveal it surrounded by kids.']
# Parts: ['The Captain instructs them.']
# Parts: ['John and Mary help unload equipment from the Axiom.']
# Parts: ['Robots and passengers stream off the ship.']
# Parts: ['CAPTAIN']
# Parts: ['This is called “farming”! You kids are']
# Parts: ['going to grow all kinds of plants:']
# Parts: ['vegetable plants', ' pizza plants!']
# Parts: ['(laughs)']
# Parts: ['Ahh', ' it’s good to be home...']
# Parts: ['The CAMERA PULLS OUT from the Axiom...']
# Parts: ['...over the bay...']
# Parts: ['“...That it only took a moment...”']
# Parts: ['...past Wally & Eve holding hands in his truck...']
# Parts: ['...over M-O and the Rejects cleaning outside...']
# Parts: ['...Through the trash towers of the city...']
# Parts: ['...past a FIELD OF PLANTS', ' sprouting from its peak...']
# Parts: ['...up through the cloud cover...']
# Parts: ['...out into space...']
# Parts: ['“...To be loved a whole life long.”']
# Parts: ['...and settles on...']
# Parts: ['...our single...']
# Parts: ['...drab...']
# Parts: ['...brown...']
# Parts: ['...little planet.']
# Parts: ['IRIS OUT']
# Parts: ['THE END']
# Parts: ['94.']

# %% [markdown]
# ### ✏️ Your Turn
# Open a text file and print all lines that contain more than 3 words.

# %%
with open('something.txt', 'r') as f:
    for line in f:
        if len(line.split()) > 3:
          print(line)
# Out:
# The upbeat show tune, Put On Your Sunday Clothes, plays.
#
# “Out there, there’s a world outside of Yonkers...”
#
# Distant galaxies, constellations, nebulas...
#
# Pushing through its polluted atmosphere.
#
# “...Close your eyes and see it glisten...”
#
# EXT. PLANET’S SURFACE - CONTINUOUS
#
# A range of mountains takes form in the haze.
#
# The mountains are piles of TRASH.
#
# The entire surface is nothing but waste.
#
# “...We’re gonna find adventure in the evening air...”
#
# A silhouetted city in the distance.
#
# What looks like skyscrapers turns into trash.
#
# Thousands of neatly stacked CUBES OF TRASH, stories high.
#
# Rows and rows of stacked cubes, like city avenues.
#
# They go on for miles.
#
# EXT. AVENUE OF TRASH
#
# “...Beneath your parasol the world is all a smile...”
#
# Something moving on the ground far below.
#
# A figure at the foot of a trash heap.
#
# A SMALL SERVICE ROBOT diligently cubing trash.
#
# Every inch of him engineered for trash compacting.
#
# Mini-shovel hands collect junk.
#
# Scoop it into his open chassis.
#
# His front plate closes slowly, compressing waste.
#
# A faded label on his corroded chest plate:
#
# “Waste Allocation Loader - Earth Class” (WALLY)
#
# Wally spits out a cube of trash.
#
# Stacks it with the others.
#
# Something catches his eye.
#
# Tugs on a piece of metal stuck in the stack.
#
# The sun reflects off it.
#
# Wally checks the sky.
#
# ON TRASH HEAP HORIZON
#
# The sun sets through the smoggy haze.
#
# “...And we won’t come back until we’ve kissed a girl --”
#
# He places the hubcap in his compactor.
#
# Presses a button on his chest.
#
# The song stops playing.
#
# The end of a work day.
#
# Wally attaches a lunch cooler to his back.
#
# Whistles for his pet COCKROACH.
#
# The insect hops on his shoulder.
#
# They motor down from the top of a GIANT TRASH TOWER.
#
# EXT. AVENUES OF TRASH - DUSK
#
# Traverses miles of desolate waste.
#
# Oblivious to roving storms of toxic weather.
#
# Passes haunting structures buried within the trash.
#
# Buildings, highways, entire cities...
#
# Everything branded with the SAME COMPANY LOGO.
#
# “BNL” stores, restaurants, banks...transportation!
#
# The corporation ran every aspect of life.
#
# There’s even a BNL LOGO on Wally’s chest plate.
#
# CLOSE ON NEWSPAPER Wally drives over.
#
# Headline: “TOO MUCH TRASH!! Earth Covered!!”
#
# The deck: “BNL CEO Declares Global Emergency!”
#
# A photo of the BNL CEO giving a weak smile.
#
# Wally’s old treads are threadbare.
#
# Cause a bumpy ride for his cockroach.
#
# He passes the remains of other RUSTED WALL-E UNITS.
#
# Fancies one with NEWER TREADS than his own...
#
# EXT. DESERTED STREET - MOMENTS LATER
#
# Wally now sports the newer treads.
#
# Rolls past a SERIES OF HOLOGRAPHIC BILLBOARDS.
#
# The solar-powered ads still activate when he passes them.
#
# (Ad #1: BNL logo over trash)
#
# Too much garbage in your face?
#
# (Ad #2: starliner in space)
#
# There’s plenty of space out in space!
#
# (Ad #3: starliners take off
#
# BNL starliners leaving each day.
#
# (Ad #4: WALL-E units wave
#
# We’ll clean up the mess while you’re
#
# EXT. EDGE OF THE CITY
#
# Wally drives down a deserted overpass.
#
# Activates an even LARGER HOLOGRAPHIC BILLBOARD.
#
# CLOSE ON BILLBOARD AD
#
# Shows off a CITY-SIZED LUXURY STARLINER.
#
# Depicts passengers enjoying all its amenities.
#
# The jewel of the BNL fleet: “The Axiom”.
#
# Spend your five year cruise in style.
#
# Waited on 24 hours a day by our fully
#
# automated crew, while your Captain and
#
# Autopilot chart a course for non-stop
#
# entertainment, fine dining. And with our
#
# all-access hover chairs, even Grandma can
#
# join the fun! There’s no need to walk!
#
# “The Axiom”. Putting the “star” in
#
# The BNL CEO appears at the end.
#
# Waves goodbye as the Axiom takes off.
#
# BUY N LARGE CEO
#
# Because, at BNL, space is the final “fun”-
#
# The holographic billboard powers off.
#
# Reveals the AXIOM’S DESERTED LAUNCHPAD in the distance.
#
# The mammoth structure sits across the bay.
#
# Now empty and dry. A polluted, dead valley.
#
# ON COLLAPSED BRIDGE RAMP
#
# Near its edge rests a WALL-E UNIT TRANSPORT TRUCK.
#
# A giant child’s Tonka Truck left to weather the elements.
#
# A “Buy N Large” logo on its side.
#
# Wally approaches the rear of the truck.
#
# Pulls on a lever.
#
# Wally motors up the ramp.
#
# INT. TRUCK - CONTINUOUS
#
# Open racks for storing WALL-Es line both walls.
#
# KNICKKNACKS OF FOUND JUNK littered everywhere.
#
# The tired robot removes his newfound treads.
#
# Wally motors down the center aisle.
#
# Flicks on an ancient BETAMAX PLAYER.
#
# Jury-rigged to an iPod.
#
# Pushes in a cassette labeled, “Hello Dolly!”
#
# The image is very poor quality.
#
# Actors sing and dance to Put On Your Sunday Clothes (POYSC).
#
# The same song Wally worked to.
#
# Wally opens his cooler.
#
# Pulls out the hubcap from his chest.
#
# Looks back at the TV.
#
# Mimics the dancers on the screen.
#
# Pretends the hubcap is a hat.
#
# A Rubik’s Cube (unsolved).
#
# He presses a BUTTON by the rack of shelves.
#
# They rotate until an empty space appears.
#
# His new items are lovingly added to the shelf.
#
# The Zippo joins a pre-existing LIGHTER COLLECTION.
#
# A new song, It Only Takes A Moment, plays on the video.
#
# Wally is drawn to it.
#
# Presses his “Record” button.
#
# Two lovers sing gently to one another.
#
# Wally tilts his head as he watches.
#
# Holds his own hands.
#
# EXT. TRUCK - NIGHT
#
# Turns over his Igloo cooler to clean it out.
#
# Pauses to take in the night sky.
#
# STARS struggle to be seen through the polluted haze.
#
# Wally presses the “Play” button on his chest.
#
# The newly sampled It Only Takes A Moment (IOTAM) plays.
#
# The wind picks up.
#
# A WARNING LIGHT sounds on Wally’s chest.
#
# He looks out into the night.
#
# A RAGING SANDSTORM approaches off the bay...
#
# Unfazed, Wally heads back in the truck.
#
# IOTAM still gently playing.
#
# ...The massive wave of sand roars closer...
#
# Wally raises the door.
#
# WHISTLES for his cockroach to come inside.
#
# The door shuts just as the storm hits.
#
# Obliterates everything in view.
#
# INT. TRUCK - SAME
#
# Wally alone in the center of his shelter.
#
# Unwraps a BNL SPONGECAKE (think Twinkie).
#
# Lays it out for the cockroach to sleep in.
#
# It happily dives in.
#
# Wally collapses himself into a storable cube.
#
# Backs into an empty shelf space.
#
# Rocks it like a cradle...
#
# ...and shuts down for the night.
#
# Outside the wind howls like the Hounds of Hell.
#
# INT. WALLY’S TRUCK - NEXT MORNING
#
# Wally’s CHARGE METER flashes “WARNING”.
#
# EXT. ROOF OF WALLY’S TRUCK
#
# Wally fully exposed in its light.
#
# His front panel splayed out like a tanning shield.
#
# His CHARGE METER chimes full.
#
# Solar panels fold away into hiding.
#
# Wally, now awake, collects his lunch cooler.
#
# Heads off to work.
#
# ...and accidentally runs over the cockroach.
#
# Reveals the FLATTENED INSECT under his tread.
#
# The cockroach simply pops back to life.
#
# No biggie. Ready to go.
#
# Relieved, Wally resumes their commute.
#
# EXT. WALLY’S WORK SITE - THAT MORNING
#
# A SERIES OF “WALLY AT WORK” MOMENTS:
#
# - CU of Wally’s hands digging into garbage.
#
#  CU of trash being scooped into his chest compactor.
#
#  A cube lands by the cockroach.
#
# - Wally discovers a BRA in the garbage.
#
#  Unsure what it’s for.
#
#  Tries placing it over his eyes, like glasses.
#
#  Tosses it in his cooler.
#
# - Wally finds a set of CAR KEYS.
#
#  Presses the remote lock.
#
#  Somewhere in the distance a CAR ALARM CHIRPS.
#
# - Plays with a paddle ball.
#
#  The ball keeps smacking him in the face.
#
#  He doesn’t like it.
#
# - Wally discovers a DIAMOND RING in a JEWEL CASE.
#
#  Throws out the ring. Keeps the case.
#
#  The jewel case drops into the cooler, then...
#
#  ...A BOBBLE HEAD DOLL...
#
# - Wally finds a FIRE EXTINGUISHER.
#
#  FOAM blasts in his face.
#
#  It’s tossed far, far away from his cooler.
#
# - Wally’s shovel hand strikes something solid.
#
#  Faces a REFRIGERATOR much larger than himself.
#
# - CU on fridge door.
#
#  A WELDING BEAM moves down its center.
#
#  It emits from between Wally’s SPLIT BINOCULAR EYES.
#
#  The door falls apart in two pieces. Reveals...
#
# in its early stage of growth.
#
# Carefully, he extracts the section of earth around it.
#
# CLOSE ON IGLOO COOLER
#
# Wally gently places the plant inside the old boot.
#
# Dusts dirt off the leaves.
#
# EXT. TRUCK - DUSK
#
# Robot and faithful cockroach return home.
#
# Wally stops short of the threshold.
#
# Stares at the ground.
#
# quivers on the dirt.
#
# A single laser point of light.
#
# Wally moves to touch it...
#
# ...The dot races along the ground.
#
# Wally drops his Igloo.
#
# Chases after the dot.
#
# The dot leads Wally deep into the polluted expanse.
#
# He is so fixated on it he doesn’t notice
#
# coming from every direction.
#
# All racing into the valley over the contour of the terrain.
#
# Triangulating towards a center.
#
# Wally’s dot suddenly stops.
#
# Slowly he reaches for it.
#
# Can’t grab it. Just light.
#
# ALL THE DOTS converge in front of him.
#
# Doesn’t see above him.
#
# The SUN growing brighter behind the cloud cover.
#
# Wally senses he should look to the sky.
#
# Now THREE SUNS are descending on him.
#
# Wally runs for it.
#
# An enormous COLUMN OF FIRE blocks his path.
#
# A second column of fire.
#
# Wally cubes the ground beneath him.
#
# Digs in just as a tide of flame carpets the ground...
#
# CLOSE ON THE SCORCHED EARTH
#
# Wally’s head rises out of the dirt.
#
# Glows red hot from the heat.
#
# Something very big looms over him.
#
# Wally climbs out of his hole.
#
# Bangs his head on metal.
#
# WIDE on a massive SPACESHIP.
#
# Rests ominously in the empty bay.
#
# A PORTAL on its underside opens.
#
# Frightened, Wally tries to hide.
#
# He places a SMALL ROCK on his head. Boxes up.
#
# A DEVICE lowers to the ground on a long stem.
#
# Wally creeps closer for a better look.
#
# Wally boxes up again.
#
# A CAPSULE descends from a chute in the stem.
#
# ROBOT ARMS emerge from the device.
#
# Place the capsule on the ground. Press buttons.
#
# The capsule falls away in sections, to reveal...
#
# It hovers gracefully above the ground.
#
# Watches Eve from behind the device.
#
# She’s the most beautiful thing he’s ever seen.
#
# Eve hovers over the ground.
#
# A BLUE RAY emits from her front panel.
#
# Fans out 180 degrees.
#
# Scans random objects and areas.
#
# The device rises back into the ship.
#
# He rushes for cover behind the nearest rock.
#
# Never takes his eyes off Eve.
#
# Watches her float away from the ship.
#
# Engines roar back to life.
#
# The rocket takes off.
#
# Again, a red hot Wally peeks out from the ground.
#
# She is watching the ship rise into the clouds.
#
# Waits until it is completely out of sight...
#
# ...then Eve rises high up into the air.
#
# She flies around the bay.
#
# Soars like a graceful bird.
#
# Does loops in the sky.
#
# Zooms right past Wally’s rock.
#
# Eve descends gently to the ground...
#
# Wally sneaks up closer.
#
# Hides behind another boulder.
#
# Instantly, Eve whips around.
#
# Her arm converts into a LASER CANNON.
#
# Blasts Wally’s boulder to smithereens.
#
# Eve, now cold and dangerous.
#
# No sign of life.
#
# Hovers away to probe more of the planet.
#
# ON OTHER SIDE OF BOULDER CRATER
#
# Wally boxed up behind what little remains of the rock.
#
# EXT. AVENUE OF TRASH - DAY
#
# Eve wanders through the pillars of cubed trash.
#
# Wally spies from the shadows.
#
# Too frightened to approach.
#
# She moves on. He follows.
#
# EXT. TIRE DUMP - DAY
#
# Eve probes a mound of tires.
#
# He flinches at the sight of
#
# innocently approaching Eve from behind.
#
# The cockroach climbs out of the smoking crater.
#
# Eve finds the insect intriguing.
#
# The end separates into individual hovering sections...
#
# She lets the insect crawl up her arm.
#
# Wiggles into her workings.
#
# Eve sonically picks up Wally’s location.
#
# Arm converts to laser cannon.
#
# Quick glimpses of Wally dodging the blasts.
#
# Trash piles are systematically obliterated around him.
#
# Boxes himself up. Shakes uncontrollably.
#
# Eve holds her fire.
#
# She slowly approaches Wally’s box.
#
# Keeps her gun trained on him.
#
# Wally peeks out from his box.
#
# Doesn’t understand a thing she says.
#
# Can’t believe she’s real.
#
# The cockroach climbs down her gun arm.
#
# Jumps onto his master.
#
# A RED LIGHT appears on her chest.
#
# He’s not what she’s looking for.
#
# She retracts her gun arm.
#
# Wally watches her go. Lovestruck.
#
# INT. ABANDONED BNL SUPERSTORE - NEXT DAY
#
# LOUIS ARMSTRONG’S “LA VIE EN ROSE” PLAYS
#
# Eve scans through the market.
#
# Wally follows from a safe distance.
#
# Eve glances over at him.
#
# Bumps into a RACK OF SHOPPING CARTS.
#
# They chase him down a flight of stairs.
#
# Wally reaches the exit doors.
#
# Carts pig pile on top of him.
#
# EXT. BNL REFINERY - NIGHT
#
# Wally perched on the roof.
#
# Patiently watches Eve fly.
#
# She scans the ground below her, like a searchlight.
#
# Eve comes in for a landing below.
#
# Shuts down for the night.
#
# Quietly sneaks down the refinery fire escape.
#
# Accidentally trips. Tumbles to the ground.
#
# Wally creeps up to her.
#
# Opens his arms wide...
#
# Turns to a pile of trash.
#
# Splits open his eyes. Begins welding something...
#
# EXT. BNL REFINERY - NEXT MORNING
#
# Eve powers up again.
#
# Does a double take.
#
# A TRASH SCULPTURE OF EVE stands in front of her.
#
# She hovers away, unimpressed.
#
# Doesn’t notice Wally hiding behind a PILE OF PIPES.
#
# Wally kicks the pipes in frustration.
#
# They roll on top of him.
#
# MONTAGE OF EVE SEARCHING
#
# - Scans a car engine.
#
#  Slams the hood shut.
#
# - Scans a Port-A-Potty.
#
#  Slams the door shut.
#
# - Scans an Apollo capsule.
#
#  Slams the hatch shut.
#
# - Scans a FREIGHTER HOLD.
#
#  Slams the lid shut.
#
# EXT. DERELICT SHIPYARD - DUSK
#
# Eve hovers over the freighter.
#
# Not finding what she’s looking for.
#
# Wally eavesdrops from afar.
#
# Eve flies past the ship’s CRANE MAGNET.
#
# Wrestles to free herself.
#
# Furious, she BLOWS UP THE ENTIRE SHIP.
#
# The reaction startles Wally.
#
# Eve slumps down against a dredged anchor.
#
# Concerned, Wally cautiously approaches.
#
# Sits at the other end of the anchor.
#
# Both robots stare silently at the fiery wreck.
#
# ...slowly, very slowly, Wally inches towards her.
#
# Musters the courage to speak, when --
#
# She suddenly turns to him:
#
# [So what’s your story?]
#
# Wally falls backwards with surprise.
#
# Eve scrolls through a variety of languages:
#
# [Oh, I understand that!]
#
# Wally eagerly turns to some nearby trash.
#
# Scoops it into his compactor.
#
# Proudly spits out a cube.
#
# She scans his CHEST LOGO.
#
# She says his name so beautifully.
#
# Wally tries to repeat it:
#
# Wally likes making her giggle.
#
# The wind kicks up.
#
# The WARNING LIGHT sounds on Wally’s chest.
#
# He moves to grab her.
#
# [Hey watch it! Don’t come any closer!]
#
# She draws her gun on him.
#
# Doesn’t understand the danger.
#
# The sandstorm rushes up behind her.
#
# Wally collapses into a box.
#
# The storm hits full force.
#
# Eve is instantly lost, disoriented.
#
# WALLY’S HAND appears out of the dust.
#
# Calmly takes Eve’s hand.
#
# INT. TRUCK - MOMENTS LATER
#
# The back door lowers.
#
# A rush of wind and sand.
#
# Wally pulls Eve inside. Closes the door.
#
# She coughs up dust.
#
# Wally hits a switch...
#
# Strings of CHRISTMAS LIGHTS fill the space.
#
# His racks of oddities painted in colored light.
#
# An air of enchantment.
#
# Eve is taken aback.
#
# She drifts through the sea of knickknacks.
#
# Becomes spooked by a SINGING BILLY BASS FISH.
#
# Threatens to shoot it, but Wally calms her down.
#
# He is compelled to show her everything.
#
# Hands her an eggbeater...
#
# ...bubble wrap (so infectious to pop)...
#
# ...a lightbulb (lights when she holds it)...
#
# ...the Rubik’s Cube (she solves it immediately)...
#
# ...his Hello Dolly tape.
#
# Curious, she begins unspooling the tape.
#
# He grabs it back. Protective.
#
# Inserts it carefully into the VCR. Please still work.
#
# The movie eventually appears on the TV.
#
# Plays a clip of POYSC.
#
# [What do you think?]
#
# Mimics the dancing for Eve.
#
# Encourages her to try.
#
# She clumsily hops up and down.
#
# Makes dents in the floor. Rattles everything.
#
# Wally politely stops her.
#
# [How ‘bout we try a different move?]
#
# Spins in a circle. Arms out.
#
# Spins faster, and faster...
#
# Accidentally strikes Wally. He flies into the shelves.
#
# Eve helps him up from the mess.
#
# Wally’s LEFT BINOCULAR EYE falls off.
#
# Dangles from two wires.
#
# Eve GASPS with concern.
#
# Feels his way to the rack of shelves.
#
# ...SPARE WALL-E PARTS appear.
#
# Replaces his broken eye with a new one.
#
# She eyes his LIGHTER COLLECTION.
#
# Flicks open a Zippo. Ignites a FLAME.
#
# He had no idea it could do that.
#
# Moves closer to inspect it...
#
# It’s the closest he’s ever been to Eve.
#
# She remains focused on the lighter.
#
# Wally stares up at her.
#
# ...The tiny flame flickering between them...
#
# ...The Hello Dolly video plays IOTAM in the background...
#
# Suddenly, he is moved to express his love.
#
# Musters the courage to open his fingers...
#
# ...Timidly reaches his hand out to hers...
#
# -- Eve turns and looks at him.
#
# Pulls his hand back.
#
# Eve becomes intrigued with the TV.
#
# Scans the image of the lovers singing IOTAM...
#
# His infatuation still palpable.
#
# He rushes to his shelves.
#
# Eve watches him rummage through junk.
#
# A drum falls down on his head.
#
# She giggles, charmed by it all.
#
# She is drawn back to the lovers on TV...
#
# ...then the lit Zippo lighter in her hand.
#
# A tap on her shoulder.
#
# She turns to find Wally holding something.
#
# Eve immediately locks onto it.
#
# ...a TRACTOR BEAM snatches the plant away...
#
# ...stores it inside her...
#
# Then she shuts down completely.
#
# Only a SINGLE GREEN LIGHT pulsing on her chest.
#
# Waves his hand in front of her face.
#
# Knocks on her chest plate.
#
# CAMERA MOVES IN on the blinking green light...
#
# EXT. ROOF OF WALLY’S TRUCK - DAY
#
# Wally places Eve in his charging spot.
#
# Aims her hovering form to face the sun.
#
# MONTAGE OF WALLY TRYING TO REVIVE EVE:
#
# - Several hot days pass with Wally holding vigil in the heat.
#
# - A THUNDERSTORM approaches on the horizon.
#
#  Wally holds an UMBRELLA over Eve.
#
#  Gets struck by lightning.
#
#  Holds up another umbrella.
#
# - A SANDSTORM blows through.
#
#  Wally pops out of a dune on the truck’s roof.
#
#  Lifts up an UPSIDE-DOWN BARREL that protected Eve.
#
# - Wally pries open a panel on Eve’s chest.
#
#  Reveals her pulsing BLUE HEART-BATTERY.
#
#  Attaches JUMPER CABLES to his own HEART-BATTERY.
#
#  Tries to connect the other end to hers.
#
#  An automatic defense system blows him off truck.
#
# - Wally & cockroach take Eve for a walk.
#
#  Pull her along on a LEASH OF CHRISTMAS LIGHTS.
#
# - Wally gives Eve a boat ride on a LAKE OF SLUDGE.
#
#  Uses an industrial tire as a boat.
#
#  Rows like a gondolier with a road sign.
#
# - Wally sits by the empty bay with Eve.
#
#  Burns “WALL-E + EVE” on a public trash can.
#
#  Tries to pull out her hand to hold it.
#
#  It snaps back into place, trapping his hand.
#
# EXT. ROOF OF WALLY’S TRUCK - NIGHT
#
# Wally has set up the TV on the roof.
#
# The blank Eve floating next to him.
#
# Tries unsuccessfully to play PONG with her.
#
# Finally, he gives up.
#
# EXT. TRUCK - NEXT MORNING
#
# Wally loads up his cooler.
#
# Checks on Eve one more time.
#
# Heads off to work, defeated.
#
# EXT. WORK SITE - LATER
#
# Wally simply going through the motions.
#
# No spirit in him at all.
#
# Pulls out the Zippo lighter.
#
# Flicks it a few times.
#
# A RUSH OF WIND blows out the flame.
#
# Wally looks in the direction of his home.
#
# A BRIGHT GLOW is lowering down through the clouds.
#
# EXT. TRASH ALLEY - DAY
#
# Wally racing as fast as he can.
#
# The cockroach clings onto him for dear life.
#
# EXT. TRUCK - DAY
#
# The RECON SPACESHIP towers over his truck.
#
# A ROBOT ARM cherry-picks Eve from the roof.
#
# Lifts her up and into the ship’s cargo hold.
#
# Wally racing in the distance.
#
# Reaches the end of the collapsed bridge ramp.
#
# Forced to watch Eve disappear into the ship.
#
# The cargo doors slam shut.
#
# The first of the THREE ROCKET ENGINES powers up.
#
# Wally heads down a hill of rubble to the ship.
#
# Notices his cockroach tagging along behind him.
#
# Leads it back to the top of the hill.
#
# Droops its little antennae.
#
# Wally motors back down to the rocket...
#
# BASE OF RECON SHIP
#
# The engines blast a WALL OF SMOKE.
#
# Eve is secured into a slot.
#
# Joins a ROW OF OTHER EVE PROBES.
#
# Only Eve flashes a GREEN LIGHT.
#
# The CAMERA DRIFTS BACK out a window...
#
# ...where Wally steadily climbs up the side.
#
# The ship’s engines ignite.
#
# Wally clamps his hands tight to a metal support.
#
# The rocket takes off into space.
#
# EXT. TOP OF HILL
#
# The cockroach watches his master go.
#
# The spaceship roars through the sky.
#
# Wally tightens his grip, battling the G’s.
#
# He looks ahead. SCREAMS.
#
# HUNDREDS OF BNL SATELLITES
#
# litter the outer atmosphere.
#
# The ship bursts through the layer.
#
# EXT. SPACE - CONTINUOUS
#
# The recon ship breaks free of the planet.
#
# Its boosters shut down.
#
# Wally takes in the sudden QUIETNESS OF SPACE.
#
# Looks back at his planet.
#
# Wally almost floats away.
#
# Grabs hold of the ship.
#
# Knocks on a WINDOW near Eve.
#
# No response. She remains shut down.
#
# Wally points out at the stars.
#
# It is the most spectacular light show possible.
#
# And Wally has a front row seat.
#
# MONTAGE OF CELESTIAL SPECTACLES
#
# - The ship flies past the MOON.
#
#  A BILLBOARD stands next to the abandoned APOLLO MOON ROVER.
#
#  “BNL Outlet Coming Soon.”
#
# - The ship passes by the SUN.
#
#  Wally pops open his solar panels.
#
# - The ship cruises alongside SATURN’S OUTER RINGS.
#
#  Wally runs his hand through the tiny particles of ice.
#
# EXT. RECON SHIP - DAYS LATER
#
# A DUMBBELL NEBULA slowly twists in space.
#
# Wally is mesmerized by it.
#
# Leads his eye to a LIGHT, growing in the distance ahead.
#
# The now tiny recon ship heads straight for it.
#
# TWO TUG-ROCKETS guide the ship in.
#
# It locks into GIANT BRACES fixed on the deck.
#
# The impact knocks Wally off.
#
# He lands in the scaffolding of the front brace.
#
# Suddenly the entire dock comes to life.
#
# Robotic arms and service robots of all types appear.
#
# ...Rise from the floor...
#
# ..Lower from the ceiling...
#
# It’s a cacophony of automation.
#
# They all attend to the ship.
#
# and four other probes slide out of the ship’s side.
#
# Suspended in a horizontal rack.
#
# Wally is surprised to find her facing him.
#
# She remains shut down.
#
# Just a few feet away with a giant abyss between them.
#
# A SQUAD OF CLEANER ROBOTS emerge onto the dock.
#
# A small roller BRUSH-BOT (M-O) leads.
#
# Waits for the FLOOR LINES to appear.
#
# Depict their exact path of action.
#
# They file out on the line.
#
# A crane-bot lowers Eve from the rack.
#
# M-O and his cleaning crew stand ready.
#
# ON M-O’S DISPLAY POV
#
# Scan reads: “%16 Foreign Contaminant.”
#
# Revs his brush roller. Moves in for the clean.
#
# A VACU-BOT follows after him.
#
# Then a SPRAY-BOT and BUFFER-BOT finish off.
#
# The cleaning crew waits for probe #2.
#
# Wally studies the routine.
#
# Figures out a way to climb down to Eve.
#
# When the crane returns, Wally poses as probe #3.
#
# The crane grabs him instead.
#
# M-O turns around to clean the next probe.
#
# Wally is lowered in front of him.
#
# Confused, M-O scans him.
#
# ON M-O’S DISPLAY POV
#
# Scan reads: “%100 Foreign Contaminant.”
#
# M-O is horrified by such filth.
#
# A RED SIREN LIGHT rises from his head.
#
# [Oh, no, no, no. This is all wrong.]
#
# He scrubs Wally full force.
#
# Wally’s front panel pushes him away.
#
# Confused, M-O moves to clean him again.
#
# Leaves a DIRT TRAIL.
#
# [You made the floor all dirty! Stop it!]
#
# M-O furiously scrubs the floor.
#
# Wally peeks out, amused by this neurotic little guy.
#
# Two STEWARD ROBOTS come out of the wall.
#
# Act like hovering caution signs.
#
# A small robot (GOPHER) shoots out a PNEUMATIC TUBE.
#
# He bears epaulet like shoulders and a siren for a face.
#
# Gopher beeps an ELECTRONIC ORDER for the Stewards to follow.
#
# BACK ON M-O AND WALLY
#
# M-O just finishes cleaning the floor.
#
# Impishly makes another mark.
#
# M-O compulsively cleans it. Can’t resist.
#
# [Look, it stays clean. You got that?]
#
# Wally wipes the bottom of his tread on M-O’s face.
#
# Scrubs his own face.
#
# Gopher and his steward escort arrive.
#
# The cleaning crew stand at attention.
#
# Wally boxes back up with the probes.
#
# Gopher begins scanning each probe.
#
# Moves down the line.
#
# Scans Wally...moves on to the next probe...
#
# Stops -- Wait a minute.
#
# Gopher shrugs it off. Proceeds...
#
# Doesn’t notice Wally hidden behind her.
#
# Gopher scans her BLINKING PLANT LIGHT --
#
# The entire dock goes to “Code Green”!
#
# ...A HOVER-TRANSPORT glides up to Gopher...
#
# ...A crane-bot loads Eve...
#
# ...Curved energy bands lock her down...
#
# ...Gopher assumes the driver’s seat...
#
# It’s all moving too fast for Wally.
#
# Suddenly Eve’s transport heads for the ELEVATOR.
#
# Wally chases after them.
#
# Grabs onto the back of the transport.
#
# They disappear into the elevator.
#
# The cleaning crew files out.
#
# Follow their lines back to their hold.
#
# Notices Wally’s FILTHY TRACKS crossing his path.
#
# The tracks lead to the elevator.
#
# M-O’s neurosis takes over.
#
# He makes a radical decision and...
#
# ...jumps off his line.
#
# Starts methodically cleaning the dirt trail.
#
# Gopher waits patiently as the floors pass.
#
# Wally hidden behind the transport.
#
# Pets her blank faceplate.
#
# [It’ll be okay, Eve.]
#
# The ELEVATOR DOORS suddenly open.
#
# INT. ROBOT SERVICE TUNNEL - CONTINUOUS
#
# DOZENS OF ROBOTS speed along a multi-lane passageway.
#
# All following glowing lines on the floor.
#
# Wally’s head whipsaws back and forth.
#
# Tries to process it all.
#
# Doesn’t notice Gopher’s transport merge into traffic...
#
# Wally shrinks from the high-speed traffic.
#
# Timidly attempts to merge.
#
# Sticks out one tread...
#
# -- Instantly causes a ROBOT PILE-UP.
#
# Wally boxes up. Guns it.
#
# Weaves across all the lines on the floor.
#
# Bounces off robots like bumper cars.
#
# Barely able to navigate the chaos.
#
# Takes refuge in the middle of an INTERSECTION.
#
# ON WALLY’S POV DISPLAY
#
# ...a PAINT-BOT paints a wall sign...
#
# ...A GARBAGE-BOT dumps trash into a wall chute...
#
# ...Down the hall, Eve’s transport glides up a ramp...
#
# Wally chases after them.
#
# INT. UPPER HALLWAY - CONTINUOUS
#
# Wally flies up the ramp.
#
# Nearly collides with a merging HOVER CHAIR.
#
# It blocks his way.
#
# Wally gains alongside it, and discovers
#
# sitting, reclined, in the chair.
#
# He is large, round and soft - like a big baby.
#
# Wears a red, BNL jumpsuit.
#
# The chair seems to be steering itself.
#
# Guided by floor lines, just like the robots.
#
# Speaker headrests block his peripheral vision.
#
# A HOLOGRAPHIC SCREEN floats inches in front of his face.
#
# He converses with a SECOND PASSENGER on screen:
#
# Well, I’ve been in my cabin all morning
#
# so let’s hover over to the driving range
#
# and hit a few virtual balls into space.
#
# PASSENGER #2 (ON SCREEN)
#
# Nah, we did that yesterday. I don’t want
#
# Well then what do you want to do?
#
# He looks over his shoulder.
#
# Passenger #2 is floating right next to them.
#
# Isolated in his own hover chair.
#
# Also in a red jumpsuit. Also a big baby.
#
# I don’t know. Something.
#
# Both humans are totally unaware of the other’s presence.
#
# They all exit the hallway. Merge into the...
#
# Wally is in awe.
#
# Hundreds of floors of GUEST ROOMS rise on all sides.
#
# THOUSANDS OF PASSENGERS fill the giant space.
#
# All reclined and riding on hover chairs.
#
# MULTIPLE FLOOR LINES guide their chairs in all directions.
#
# Humans have become the most extreme form of couch potatoes.
#
# Absolutely no reason to ever get up.
#
# Every one of them engrossed in their video screens.
#
# Cocooned in virtual worlds.
#
# Over-developed fingers tap ARMREST KEYPADS.
#
# The controls allow them to steer...
#
# ...and most of all...
#
# ...CHAT MINDLESSLY with other passengers:
#
# The CHATTER is deafening.
#
# No one notices Wally at all.
#
# He drives into the endless human traffic.
#
# A DRINK-BOT floats over to a passenger.
#
# Puts a fresh drink in her open hand.
#
# Wally flows with the traffic into a LARGE TUNNEL.
#
# I can’t hear you...I’m in a tunnel.
#
# You’re breaking up...Oh, okay. You’re
#
# back. I can hear you now...
#
# They spill out into the BRIGHT LIGHT of the
#
# MAIN CONCOURSE (COACH CLASS)
#
# A city-sized, mall-like environment.
#
# All under a GIANT DOME.
#
# The ceiling simulates the sun and sky.
#
# A BNL LOGO (w/ time & temp) appears on the FACE OF THE SUN.
#
# Buy N Large. Everything you need to be
#
# happy. Your day is very important to us.
#
# A PASSENGER (JOHN) hovers up alongside him.
#
# Tries to hand off his empty drink cup to Wally.
#
# John reaches farther out with the cup.
#
# Here, take the cup. Take the cup -- Whoa!
#
# John falls to the floor.
#
# Flails like an upside down turtle.
#
# Unable to stand on his baby legs.
#
# Wally watches TWO STEWARDS arrive.
#
# EMERGENCY LINES appear on the floor.
#
# Redirect the hover chair traffic.
#
# John reaches out for assistance.
#
# Nobody notices. Just drive past.
#
# Stewards? Hello? Uhh, help.
#
# Please remain stationary. A service-bot
#
# will be here to assist you momentarily.
#
# Suddenly John begins to rise.
#
# Uhh...Hey! What’s going on?
#
# Wally lifting him up from behind.
#
# Loads him back onto his chair.
#
# John doesn’t know how to react.
#
# Wally scans the concourse.
#
# Spots Eve’s transport about to board a MONORAIL.
#
# He races after them.
#
# Abandons the stunned John.
#
# It pulls out of the station.
#
# Barely catches the last car.
#
# It glides down the concourse.
#
# INT. “ALL DAY” CARE CENTER
#
# A NANNY-BOT supervises a group of TODDLERS.
#
# All wearing matching BNL ONESIES.
#
# Motionless in their HOVER RINGS.
#
# They stare at educational programming on their holo-screens.
#
# “A”! “A” is for “Axiom”, your home sweet
#
# home. “B”! “B” is for “Buy N Large”, your
#
# Wally’s monorail glides past.
#
# Wally takes in the overstimulating scenery.
#
# Dozens of THEMED FOOD RESTAURANTS whizz by.
#
# Each specialty is served in the same JUMBO PLASTIC CUP.
#
# Mmmmm! Time for lunch in a cup.
#
# Wally now notices his fellow passengers.
#
# They all slurp from similar cups.
#
# Next, the monorail passes a BEAUTY SALON.
#
# BEAUTICIAN-BOTS primp and style passengers.
#
# ...It’s the new you...Oh stunning...You
#
# look great...I know honey...Ahh. Men...
#
# They pass through the FASHION DISTRICT.
#
# ENORMOUS BILLBOARDS hawk the latest color schemes.
#
# Attention, Axiom shoppers. Try blue! It’s
#
# Passengers next to Wally press their chair buttons.
#
# Their JUMPSUITS change from RED TO BLUE.
#
# Their monorail speeds into a glass tunnel.
#
# Wally looks past a PASSENGER (MARY) next to him.
#
# Spots Eve on the other side.
#
# Wally tries to sneak behind Mary.
#
# But her chair moves backwards.
#
# Smashes Wally against the back wall.
#
# No way getting past her.
#
# Wally politely tries to get Mary’s attention.
#
# Chats incessantly on her holo-screen:
#
# Date?! (derisive snort) Don't get me
#
# started! Every holo-date I've been on has
#
# been a virtual disaster! If I could just
#
# meet one who wasn't so superficial. There
#
# are no good men out there!...
#
# Wally tries to fold back her speaker headrest.
#
# Accidentally breaks it off.
#
# ...I know! I know ‘cause I've scrolled
#
# through them all -- (Gasp) What the --?
#
# Mary’s chair shorts out.
#
# ...jumpsuit defaults back to red...
#
# For the first time Mary has an unobstructed view.
#
# Her eyes slowly dilate.
#
# It’s as if she’s seeing the world for the first time...
#
# Her gaze falls on Wally.
#
# He points to Eve on the other side of Mary.
#
# Gestures he’d like to get by.
#
# She is slow to understand.
#
# Huh? Oh, uh, sure go ahead.
#
# Mary moves her hover chair back.
#
# Wally rolls over to Eve.
#
# INT. AXIOM/LIDO DECK - DAY
#
# The monorail emerges into “First Class.”
#
# A vast, circular plaza of pools.
#
# Surrounded by a ring of high rise apartments.
#
# Hundreds of passengers lounge poolside.
#
# All serviced by their personal UMBRELLA-BOTS.
#
# It stops at the BRIDGE PLAZA.
#
# The base of the Axiom’s Bridge Tower.
#
# Follow their respective lines.
#
# Gopher drives Eve (and Wally) towards the tower.
#
# Pass over a GIANT BNL LOGO on the plaza floor.
#
# She is the last to exit the car.
#
# Doesn’t follow any lines.
#
# Excited by her newfound awareness.
#
# Looks out on the Lido Deck as the monorail pulls away.
#
# I didn’t know we had a pool!
#
# Eve’s transport enters the cavernous hall.
#
# A lone TYPING-BOT is stationed at the far end.
#
# A bridge elevator behind him.
#
# Blocked by a force field gate.
#
# The transport pulls up to the typing-bot.
#
# The typing-bot responds by typing.
#
# Finally, the gate lowers. Elevator doors open.
#
# The typing-bot watches the transport enter the elevator.
#
# Notices Wally hiding at the back.
#
# Wally gives it a FRIENDLY WAVE as the doors close.
#
# The elevator shoots up to the bridge.
#
# The typing-bot looks at its hand.
#
# Mimics Wally’s waving gesture.
#
# Huh. Never done that before.
#
# Tries it some more...
#
# Wally looks out on the descending Lido Deck.
#
# Marvels at it all.
#
# His view suddenly goes dark.
#
# The elevator doors open on...
#
# INT. BRIDGE - CONTINUOUS
#
# The large circular room is dimly lit.
#
# Windows to SPACE on one side, a LIDO DECK view on the other.
#
# A massive console wraps around its entirety.
#
# Covered in buttons. A sea of thinking lights.
#
# A CAPTAIN’S WHEEL automatically steers.
#
# Gopher drives into the middle of the room. Beeps.
#
# Suddenly the wheel disengages.
#
# A single camera eye lights up its center.
#
# A periscope stem connects Auto to the ceiling.
#
# Slides along rails up to Gopher, who salutes.
#
# Auto eyes Eve. Scans her.
#
# Wally sneaks back into the shadows.
#
# Auto detects Eve’s plant light.
#
# The number “A113” flashes on his lens.
#
# An ELECTRONIC EXCHANGE begins between Auto and Gopher.
#
# Wally watches the interchange. Nervous.
#
# Without warning, Auto heads in his direction.
#
# A CIRCULAR SECTION OF FLOOR lights directly below him.
#
# Irises open, like a trapdoor.
#
# INT. CAPTAIN’S QUARTERS - DAY - CONTINUOUS
#
# ...and hits the floor hard in the room below.
#
# Someone stirs, then resumes SNORING.
#
# Auto lowers through the portal.
#
# A CLOCK ALARM BUZZER activates.
#
# Captain. You are needed on the bridge.
#
# Shoots back up. The portal closes.
#
# Wally peeks out of his box.
#
# PAN across the nautical-themed cabin.
#
# One wall lined with PORTRAITS OF FORMER CAPTAINS.
#
# Their years of service listed below.
#
# The autopilot in the background of each picture.
#
# Each generation of Captain more devolved than the other.
#
# From human to gelatinous blob.
#
# We stop on the FINAL PORTRAIT.
#
# It looms above the actual CAPTAIN, snoring in bed.
#
# He reaches out in his sleep to quiet the snooze alarm.
#
# Smacks Wally’s box by mistake.
#
# Activates the POYSC SAMPLE.
#
# The Captain sits straight up, half-awake:
#
# -- All hands on deck!!
#
# Wally is frantic to turn off the music as...
#
# ...PREP ROBOTS burst from the cabinetry...
#
# ...a BEAUTICIAN-BOT, MASSAGE-BOT and WARDROBE-BOT...
#
# ...The Captain’s bed automatically raises...
#
# ...Forms into a hover chair...
#
# The robots rapidly massage, brush, primp and dress him.
#
# Morning! Just a trim?
#
# Wally blends in with the primping.
#
# Uselessly wiggles the Captain’s toes.
#
# Lines light on the floor.
#
# Lead his chair automatically to the elevator.
#
# Wally sneaks aboard just as the doors close.
#
# Elevator doors swish open.
#
# The Captain still half-asleep.
#
# Claps his hands twice.
#
# On cue, a COFFEE MAKER rises from the console.
#
# CLASSICAL MUSIC PLAYS on overhead speakers.
#
# The Captain’s chair links with a LIT FLOOR PATH.
#
# Leads him over to the coffee.
#
# Wally stays lockstep behind him.
#
# Auto glides over to the Captain.
#
# Wally hides under the console just in time.
#
# The Captain reaches for his coffee.
#
# Makes a minimal effort.
#
# Easier to adjust his chairback slowly forward...
#
# ...almost there...and...he grabs the coffee.
#
# Sir, the annual --
#
# The Captain gives Auto the hand.
#
# Protocol, Auto. First things first.
#
# His chair automatically arcs along the console.
#
# SPECIFIC PANELS light up as he passes.
#
# He eyes Eve on the transport across the room.
#
# Has to get to her.
#
# But Auto is right above him. Can’t move.
#
# Auto calls up a screen on the console.
#
# Displays the recon-ship and a flashing positive probe.
#
# Waits patiently for the Captain to notice.
#
# Finally, the Captain turns...
#
# Sir, the annual reconnaissance has --
#
# ...but then notices the time.
#
# Auto, why didn’t you wake me for the
#
# He slingshots his chair to the Lido Deck side of the bridge.
#
# Wally nearly collides with him.
#
# Ducks back under the console.
#
# Honestly, it’s the one thing I get to do
#
# Grabs a large dial.
#
# TIME OF DAY ICONS surround it.
#
# Cranks it from mid-day back to sunrise.
#
# OUT ON LIDO DECK
#
# - The FAKE NOON SUN reverses at high speed to a SUNRISE.
#
# - Passengers’ LUNCH CUPS switch to BREAKFAST CUPS.
#
# - Poolside passengers’ umbrella-bots close up.
#
# An ANNOUNCEMENT WHISTLE BLOWS over the intercom.
#
# A SECTION OF SKY DOME becomes a JUMBOTRON SCREEN.
#
# Displays a live video feed of the Captain.
#
# The image also shows up on every passenger’s CHAIR SCREEN.
#
# Well, good morning everybody, and welcome
#
# to day 255,642 aboard the Axiom. As
#
# always, weather’s a balmy 72 degrees and
#
# sunny, and -- Oh, hey, I see the ship’s
#
# log is showing that today is our 700th
#
# anniversary of our five year cruise.
#
# Well, I’m sure our forefathers would be
#
# proud to know that 700 years later we’d
#
# ...doing the exact same thing...they were
#
# Cut to VARIOUS ASPECTS OF AXIOM LIVING.
#
# The listening passengers look just as bored as the Captain.
#
# (snaps out of ennui)
#
# SO! Be sure next mealtime to ask for your
#
# ...septuacentennial cupcake -- in a cup.
#
# Also today we have, uh...uh...Hey, Auto,
#
# what’s that flashing button?
#
# BACK ON THE BRIDGE
#
# The Captain stares at a FLASHING BUTTON on the console.
#
# It bears the same PLANT ICON as Eve’s display.
#
# The Captain turns to Auto.
#
# For the first time he notices Eve. Finally.
#
# Auto hovers over her. Salutes.
#
# Probe One has returned positive.
#
# Rises to salute the Captain.
#
# Across the room, Wally watches with sheer joy.
#
# He is compelled to head straight for her...
#
# But...no probe’s ever come back
#
# (looks at flashing button)
#
# The flashing button is practically calling to him.
#
# Can’t resist. Presses it.
#
# Instantly SHADES close on all the windows.
#
# The room goes dark.
#
# ...Wally is forced to hide under the console again...
#
# A LARGE HOLO-SCREEN appears right above him.
#
# Pre-recorded footage of the BNL CEO plays:
#
# BUY N LARGE CEO
#
# Greetings and congratulations, Captain!
#
# If you’re seeing this, that means your
#
# ...”EVE” probe, has returned from Earth
#
# with a confirmed specimen of ongoing
#
# The Captain stares slack-jawed at the screen.
#
# Wally sneaks under the console towards Eve...
#
# BUY N LARGE CEO
#
# That’s right, it means it’s time to go
#
# Home? W-w-we’re going back?
#
# BUY N LARGE CEO
#
# Now that Earth has been restored to a
#
# life-sustaining status, by golly, we can
#
# A section of the console illuminates.
#
# An ancient, dusty MANUAL slides out...
#
# ...into a passing Wally’s hands.
#
# Wally immediately boxes up.
#
# Holds the manual over his head.
#
# The Captain mistakes Wally for a book podium.
#
# Grabs the manual. Blows dust off the cover.
#
# It reads: “OPERATION RECOLONIZE”.
#
# Below the title, the same PLANT ICON from Eve’s display.
#
# BUY N LARGE CEO
#
# Simply follow this manual’s instructions
#
# to place the plant in your ship’s holodetector, and the --
#
# -- Axiom -- will immediately navigate
#
# your return to Earth! It’s that easy!
#
# ON VIDEO SCREEN (DURING SPEECH)
#
# An animated diagram depicts a stage below the ship’s bridge.
#
# The symbol of a HOLO-DETECTOR rises up.
#
# A STICK FIGURE places a plant inside the machine.
#
# A STARLINER ICON flies back towards Earth.
#
# The Captain listens closely to the instructions.
#
# Wally paying attention as well.
#
# Wally notices he has a clear shot to Eve.
#
# Heads in her direction.
#
# BUY N LARGE CEO
#
# Now, due to the effects of micro-gravity,
#
# you and your passengers may have suffered
#
# some slight bone loss. But I’m sure a few
#
# laps around your ship’s jogging track
#
# will get you back in shape in no time.
#
# The Captain looks at his VESTIGIAL LEGS.
#
# We have a jogging track?
#
# BUY N LARGE CEO
#
# If you have any further questions just
#
# consult your operation manual. See you
#
# back home real soon.
#
# The Captain examines the manual.
#
# Holds it out in front of him.
#
# Manuel, relay instructions. Manuel?
#
# Clips the corner of the cover with his handle...
#
# ...and simply opens the book.
#
# The Captain is both fascinated and intimidated.
#
# Lifts the cover with his own fingers.
#
# Wow... Will you look at that?
#
# Wally taps her shoulder.
#
# Not now Wally -- Double take!
#
# Eve is in a state of disbelief.
#
# Shoves Wally into the shadows under the console.
#
# [Wally, what are you doing here?! You
#
# can’t be here! You’re going to get me in
#
# Makes a flurry of clandestine gestures at him.
#
# Wally just stares at her.
#
# He manages to turn to the FIRST PAGE OF INSTRUCTIONS.
#
# Well, let’s open her up. Step One. Voice
#
# The bridge suddenly jumps to life.
#
# A LARGE DEVICE appears from the ceiling...
#
# ...Scans the entire room...
#
# ...Rides along the ceiling rails...
#
# ...Stations itself directly above Eve...
#
# ...Arms unfold. Position her...
#
# ...A VOICE ARM swings into the Captain’s face:
#
# A BUTTON-PUSHING ARM lowers.
#
# Presses a sequence of buttons on Eve...
#
# Her chest lights up.
#
# ...and nothing is inside.
#
# Plant. Right. Right. Where is it?
#
# Maybe we missed a step. Show me how you
#
# change the text again...
#
# Auto and the Captain turn away. Re-read the manual.
#
# Searches her chest cavity for the plant.
#
# Wally flinches. Surprised by her anger.
#
# Eve opens Wally’s chest. Empty.
#
# Picks him up. Scans the floor.
#
# Wally scared of her.
#
# Why don’t you scan her to be sure.
#
# Eve jumps back to attention.
#
# Auto slides up to her.
#
# Scans her chest cavity.
#
# Contains no specimen. Probe’s memory is
#
# So, then...we’re NOT going to Earth?
#
# So, uh, I guess things go back to normal,
#
# Instantly the plant retrieval device retracts.
#
# Exits back into the ceiling.
#
# Lights go back on.
#
# The probe must be defective. Gopher, send
#
# her to the Repair Ward.
#
# Gopher hops to attention.
#
# Traps Eve in his SUSPENSION BEAM.
#
# Loads her back onto the transport...
#
# Have them run diagnostics on her. Make
#
# sure she’s not malfunctioning -- EEYAH!!
#
# Everyone stares at him.
#
# Wally innocently motors over to the Captain.
#
# Leaves a CLUMP OF DIRT in his palm.
#
# The Captain stares at it.
#
# INT. LOBBY - MOMENTS LATER
#
# Gopher’s transport drives out.
#
# Both Eve and Wally strapped on it with energy bands.
#
# The typing-bot has now mastered waving.
#
# Waves an enthusiastic goodbye.
#
# Wally tries to get Eve’s attention.
#
# She gives him the cold shoulder.
#
# Refuses to speak to him.
#
# The transport exits the lobby.
#
# BACK UP IN THE CAPTAIN’S QUARTERS
#
# The CLUMP OF DIRT is suspended in a beam of light.
#
# The captain sits at his vanity console.
#
# ANALYSIS DATA scrolls on a HOLO-SCREEN.
#
# Analysis: foreign contaminant. Substance
#
# is a three phase system composed of
#
# various combinations of naturally derived
#
# solids. Subject is most commonly referred
#
# to as “soil”, “dirt”, or “earth”.
#
# The last word piques his interest.
#
# His eyes drift to a GLOBE on his shelf.
#
# “Earth” - the surface of the world as
#
# distinct from the sky or sea.
#
# Dozens of IMAGES OF LAND pop up on screen.
#
# Lush, green, colorful, inviting.
#
# Takes it all in.
#
# EXT. AXIOM/CAPTAIN’S QUARTERS - SAME
#
# THROUGH THE WINDOW we see the Captain.
#
# Glued to his screen.
#
# Filled with ocean images.
#
# ...an expanse of salt water that covers
#
# most of the Earth’s surface and surrounds
#
# The CAMERA DRIFTS AWAY from the window...
#
# ...Moves aft to the Axiom’s stern...
#
# INT. ROBOT SERVICE TUNNEL
#
# M-O continues to clean WALLY’S FILTHY TRAIL.
#
# Oblivious to everything around him.
#
# Robots crash into each other in his wake.
#
# M-O doesn’t notice EVE AND WALLY’S TRANSPORT drive past.
#
# They hover down a corridor, and enter...
#
# INT. REPAIR WARD - CONTINUOUS
#
# It’s a fully automated clinic for broken bots.
#
# Day care for the malfunctioned.
#
# The REJECTS are kept in FORCE FIELD PENS.
#
# Dozens line the walls.
#
# Eve and Wally stop at the INSPECTION STATION.
#
# Watches them systematically check in Eve.
#
# Perform an I.D. scan.
#
# Attach a RED “DEFECT” BOOT to her head.
#
# A button is pressed on the boot.
#
# Eve goes into “sleep” mode. Lifted off the transport.
#
# [Where are you going?!]
#
# The orderly-arms now start on Wally.
#
# He escapes before they can place a defect boot on him.
#
# Races through the ward.
#
# Wally runs smack into a defective BEAUTICIAN-BOT.
#
# Just a trim? Uh huh.
#
# She paints Wally’s face with hideous looking make-up.
#
# Holds up a mirror.
#
# Wally is snatched up by an orderly-arm.
#
# Placed in an empty force field pen.
#
# Sits between a PAINT-BOT and VACU-BOT:
#
# ...The broken paint-bot flings paint at Wally...
#
# ...The vacu-bot sneezes dust in his face...
#
# Across the way a MASSAGE-BOT flails wildly.
#
# Orderly-arms restrain him with an ENERGY STRAIGHTJACKET.
#
# Eve slides past Wally.
#
# Carried by an orderly-arm.
#
# Brought into the “DIAGNOSTICS” ROOM.
#
# The frosted glass doors shut.
#
# Orderly-arms run diagnostics on a few reject robots:
#
# - An UMBRELLA-BOT flips open and overextends.
#
#  The orderly-arms struggle to close it.
#
# - A DEFIBRILLATOR-BOT shocks a CRASH-TEST-DUMMY.
#
#  It bursts into flames.
#
# Eve is awoken from “sleep” mode.
#
# A series of tests begin.
#
# Eve is annoyed but calm.
#
# An orderly-arm easily detaches her gun arm.
#
# OUT IN THE REPAIR WARD
#
# Wally stares at the frosted glass doors.
#
# Can only make out EVE’S SILHOUETTE.
#
# To him, her arm is being ripped off.
#
# BACK INSIDE WITH EVE
#
# The orderly-arm tests Eve’s circuitry.
#
# Her insides light up.
#
# Next to her the UMBRELLA-BOT’s mechanism SCREECHES.
#
# Wally watches in horror.
#
# It looks as if Eve is being tortured.
#
# Mistakes the screeching for her screams.
#
# Wally struggles to free himself.
#
# She is washed and scrubbed.
#
# A CIRCULAR BUFFER cleans between her head and body.
#
# It looks as if Eve is being beheaded.
#
# He needs to stop the torture.
#
# Wally fires his CUTTING LASER at his pen’s force field.
#
# The barrier shorts out.
#
# Wally tumbles to the floor.
#
# Lands on his “Play” button.
#
# POYSC blares across the ward.
#
# The Rejects all stop and stare.
#
# Wally races to the diagnostics room.
#
# Crashes right through the glass doors.
#
# Finds Eve surrounded by orderly-arms.
#
# Grabs Eve’s separated gun arm.
#
# Points it at the orderly-arms.
#
# [Let her go, or I’ll shoot!]
#
# His hands tremble, Don Knotts-style.
#
# ...he’s holding the gun backwards.
#
# Eve slowly reaches for the weapon.
#
# (”Put the gun down...”)
#
# An orderly lunges at him.
#
# The gun fires backwards.
#
# It blasts through the repair ward.
#
# Blows up the REPAIR WARD CONTROL PANEL.
#
# He knows he’s in trouble.
#
# The smoking remains of the control panel SHORT CIRCUIT.
#
# ...All orderly-arms go limp...
#
# ...The repair ward doors open up...
#
# ...and all FORCE FIELDS disappear...
#
# The Rejects look at each other for a beat.
#
# The mob of robots all rush Wally.
#
# Lift him on their shoulders.
#
# Carry their hero out of the ward.
#
# Wally still holding on to Eve’s gun arm.
#
# Eve watches in astonishment.
#
# This day just gets worse and worse.
#
# She flies off after them.
#
# EXT. REPAIR WARD/ROBOT HALLWAY - CONTINUOUS
#
# The rejects march Wally out the entrance.
#
# Their RED “DEFECT” BOOTS all blink.
#
# Activate a WARNING LIGHT above the doorway.
#
# INT. ROBOT SERVICE TUNNEL
#
# Activate an embedded ROW OF STEWARDS.
#
# They pop out of the wall.
#
# Race to the repair ward.
#
# The REJECT MOB stampedes through the halls.
#
# Disrupts all robot traffic.
#
# Wally carried over their heads.
#
# Suddenly, the mob stops in front of...
#
# ...a BLOCKADE OF STEWARDS.
#
# Wally’s dropped in front of them.
#
# Still holds Eve’s gun.
#
# A TINY ROBOT pushes Wally closer.
#
# Show ‘em who’s boss.
#
# Eve catches up to them.
#
# Flies over to Wally.
#
# Snatches her arm back.
#
# Just as she reattaches her gun...
#
# ...The steward CAMERA EYES take a snapshot of them.
#
# ALL AROUND THE SHIP
#
# SCREENS appear, displaying EVE AND WALLY’S IMAGE.
#
# She appears to brandish her gun at camera.
#
# Like Bonnie and Clyde.
#
# Their faces now on every wall...
#
# Caution: Rogue robots...Caution: Rogue
#
# BACK WITH EVE AND WALLY
#
# The stewards prepare to fire SUSPENSION BEAMS (like Gopher).
#
# Eve realizes what’s about to happen.
#
# Flies over the stewards.
#
# The mass of rejects take their cue.
#
# They bust through the steward blockade.
#
# Robots recognize Eve and Wally as they fly past.
#
# Match them with the “Wanted” screens.
#
# Call attention to them. Point.
#
# Stewards in hot pursuit.
#
# Eve hides herself and Wally in a PORTHOLE CUBBY.
#
# Lets the stewards pass by.
#
# She glances out the porthole...
#
# She can see the DOCKING BAY below her.
#
# Just under the bay doors...
#
# ...a row of EMERGENCY ESCAPE PODS.
#
# Eve gets an idea.
#
# Grabs Wally and flies down the hallway...
#
# INSIDE AXIOM ELEVATOR - MOMENTS LATER
#
# Eve and Wally ride in uncomfortable silence.
#
# Their “WANTED” IMAGE plays on an elevator screen.
#
# Wally points to it.
#
# [Hey look! We’re on TV -- !]
#
# Eve aims her gun at the screen.
#
# Blows it to pieces.
#
# Wally shrinks into a box.
#
# INT. ESCAPE POD BAY/OVER HALLWAY
#
# Eve and Wally step out.
#
# Rows of NUMBERED BAY DOORS line the hallway.
#
# Eve approaches “Bay #1”.
#
# She and Wally enter...
#
# INT. ESCAPE POD BAY #1 - CONTINUOUS
#
# Eve navigates the dark.
#
# Approaches a freestanding CONSOLE.
#
# Fiddles with some buttons.
#
# He glances down at EVE’S HAND.
#
# Privately intertwines his fingers.
#
# Maybe now is the right moment...
#
# Banks of controls light up around them.
#
# is revealed at the end of the room.
#
# Its hatch automatically opens.
#
# ...
#
# The Captain, still trapped.
#
# Rams his hover chair against the locked elevator door.
#
# ...Caution: Rogue robots...Caution: Rogue
#
# A flashing light catches his attention.
#
# He looks up on the SKY DOME...
#
# A GIANT “WANTED” IMAGE of Eve and Wally, holding...
#
# The Captain’s eyes light up.
#
# Glances down at the OPEN MANUAL on the floor.
#
# “Plant icon + Holo-detector icon = Earth”
#
# He is filled with renewed determination.
#
# (Laughs) We’ll see who’s powerless now.
#
# Lays flat in his chair.
#
# Floats under his VANITY CONSOLE like a grease monkey.
#
# Pulls off the underside panel.
#
# Yanks out a bundle of wiring.
#
# The console powers up...
#
# INT. ROBOT SERVICE TUNNELS - NIGHT
#
# Eve zooms through the hallways.
#
# A BAND OF REJECTS track behind them.
#
# They reach an intersection when...
#
# ...The CAPTAIN’S FACE appears on holo-screens all around
#
# Testing, testing... Is this thing on?
#
# ALL AROUND THE AXIOM
#
# All screens display the Captain’s live feed.
#
# A few stray passengers are still up.
#
# Watch their screens in confusion.
#
# INT. BRIDGE - NIGHT
#
# Auto watches the Captain on the holo-screen.
#
# Furiously tries to shut off the intercom.
#
# BACK ON EVE AND WALLY
#
# Psssst! Hey! Hey! This is the Captain I'm
#
# locked in my room. Eve, Wally, bring the
#
# plant to the Lido Deck. I'll have
#
# activated the holo-detector. Now hurry!
#
# Auto's probably going to cut me off --
#
# The screens all go dead.
#
# Eve and Wally look at each other with determination.
#
# They’re about to continue on when...
#
# A WALL OF STEWARDS block their path.
#
# Dozens of them stand in a row.
#
# Eve fires her gun. Destroys a steward.
#
# Another one quickly takes its place.
#
# Traps her arm with its SUSPENSION BEAM.
#
# The stewards advance, when suddenly...
#
# ...the Rejects charge the stewards:
#
# ...The beautician-bot deflects rays with her mirrors...
#
# ...The vacu-bot sneezes dust in their faces...
#
# ...The defib-bot shocks them with her paddles...
#
# ...The umbrella-bot opens up...
#
# ...Shields the others from the attack...
#
# A weak Wally activates his welding beam.
#
# Shorts out the Massage-bot’s ENERGY STRAIGHTJACKET.
#
# Leaps at the entire army of Stewards.
#
# Robot parts fly everywhere.
#
# Eve and Wally can’t watch the carnage.
#
# BACK IN THE CAPTAIN’S QUARTERS
#
# He sets Eve’s CYLINDRICAL DEVICE on the floor behind him.
#
# It projects her stored memories.
#
# UP ON THE BRIDGE
#
# Auto watches steward blips disappear from his screen.
#
# A MESSAGE SCREEN pops up.
#
# ...and he’s holding the plant?
#
# Ha, ha! Look what I got, Auto!
#
# Auto’s single lens irises wide.
#
# That’s right! The plant! Oh, you want it?
#
# Come and get it, Blinky!
#
# INT. CAPTAIN’S QUARTERS - SAME
#
# The Captain hovers in front of Eve’s memory screen.
#
# It projects a STILL IMAGE OF WALLY HOLDING THE PLANT.
#
# The Captain blocks the camera’s view of Wally.
#
# Pretends to be holding the projected plant himself.
#
# Turns off the vid-com.
#
# Yanks his bundle of wires out of the wall.
#
# The room goes dark again.
#
# Auto lowers into the dark.
#
# Cautiously searches the empty room...
#
# PANS across the portraits of other captains...
#
# ...past our present Captain...
#
# ...The eyes in the portrait dart nervously...
#
# -- wait a minute.
#
# The Captain lunges at him.
#
# Grabs Auto by the steering wheel.
#
# Hangs onto it like Cap’n Ahab in a gale.
#
# His lower extremities of no use.
#
# Let go. Let go.
#
# Zips back up through the hole in the ceiling.
#
# The Captain gets stuck between floors...
#
# What too heavy for ya, huh?!
#
# UP ON THE BRIDGE
#
# ...Auto tries to pull free.
#
# The Captain won’t let go.
#
# Auto ends up yanking him through.
#
# The Captain rides Auto like a bucking bronco.
#
# Auto swings violently back and forth.
#
# You’re not getting away from me, one-eye!
#
# -- OOF! -- Is that all you got?!
#
# Gopher drops out of his pneumatic tube.
#
# Sees the Captain fighting Auto.
#
# Charges at the Captain...
#
# ...who kicks him straight out the window...
#
# ...his SHADOW growing over the POOL...
#
# ...and smashes in a heap on the cement.
#
# ON WALLY AND EVE
#
# We PAN OVER the smoking wreckage of the stewards.
#
# The massage-bot floats above it all.
#
# Pants like a wild beast.
#
# One steward still twitches.
#
# The massage-bot crushes him with one blow.
#
# Eve grabs Wally and the plant.
#
# They take off for the Concourse Level.
#
# M-O and the Rejects follow behind.
#
# That’s it!...A little closer!
#
# The Captain reaches his one free hand out for...
#
# His hand slams down hard on it.
#
# KLAXONS sound all over the ship.
#
# VARIOUS ANGLES AROUND THE AXIOM
#
# ...Floodlights kick on everywhere...
#
# ...The LIDO DECK POOLS automatically cover up...
#
# ...Stray PASSENGERS pause to take in the alarms...
#
# ...SPACE-LIFE PRESERVERS burst from their hover chairs...
#
# ...Inflate around their necks...
#
# ...GREEN LINES appear on the floors...
#
# ...SLEEPING PASSENGERS are involuntarily led out of their
#
# ...Every hover chair follows the illuminated lines...
#
# The procedure is completely automated.
#
# The passengers are all confused.
#
# Helpless to stop it.
#
# The passengers glide in by the thousands.
#
# Form concentric circles over the closed-up pools.
#
# Fill the multi-storied balconies on all sides.
#
# ON JOHN AND MARY
#
# They arrive together at the Lido Deck.
#
# Mary notices a group of toddlers scared and crying.
#
# A NANNY-BOT tries vainly to placate them.
#
# Remain calm. Remain calm.
#
# CLOSE ON BRIDGE PLAZA
#
# The BNL LOGO on the floor rotates.
#
# A large cylindrical device rises from the stage...
#
# JUMBOTRONS activate on the dome.
#
# Everyone can see the Captain wrestling Auto.
#
# He tries to speak to them during the fight:
#
# Ladies and Gentlemen! This is your
#
# Captain speaking! We’re having a slight
#
# malfunction with the Autopilot! Please
#
# The passengers get caught up in the conflict.
#
# Treat it as if it were a televised fight.
#
# ON THE REAR OF THE DECK
#
# Eve and Wally fly out of the transport tunnel.
#
# Make a beeline for the holo-detector.
#
# Ready and waiting for the plant...
#
# Auto furiously spins his wheel.
#
# Throws the Captain to the floor.
#
# The entire ship lists dangerously to one side.
#
# Eve and Wally slam into the holo-detector’s side.
#
# Wally drops the plant.
#
# It tumbles off the bridge plaza.
#
# Eve is forced to set Wally down.
#
# He clings to the holo-detector.
#
# She flies off to retrieve the plant.
#
# The hover chairs stay locked on their lines.
#
# Passengers all slip off their chairs.
#
# Their uniform color defaults back to RED.
#
# Slowly slide across the deck.
#
# And for the first time...
#
# ...all of humanity reaches out to one another.
#
# CLOSE UPS of hands holding hands.
#
# Everyone piles up on the listing side.
#
# The plant is buried underneath the mass of humanity.
#
# Eve searches desperately amongst them.
#
# ON JOHN & MARY
#
# They hang together off their chairs.
#
# CRYING TODDLERS just above them.
#
# The kiddies slip out of their hover rings.
#
# Mary GASPS in horror.
#
# John, get ready to have some kids!
#
# They purposefully let go of their chairs.
#
# Grab hands, forming a human chain.
#
# All slide together down the Lido Deck.
#
# The TODDLERS GIGGLE the whole way down.
#
# They land at the bottom, next to Eve.
#
# An empty monorail car tips off the upper deck...
#
# ...lands on the pool level.
#
# It begins sliding down the Lido Deck.
#
# Smashes vacant hover chairs in its wake.
#
# Eve looks up. Sees the Monorail sliding towards them.
#
# She stops the car before it hits.
#
# Struggles to hold it up.
#
# Can’t let it crush the passengers below her.
#
# Auto keeps the ship tilted.
#
# Glides over to the HOLO-DETECTOR BUTTON.
#
# The holo-detector begins to lower back into the floor...
#
# Wally is still hanging onto it.
#
# He uses all his strength...
#
# ...and wedges himself under the UPPER LIP of the detector.
#
# Stops it from disappearing into the floor.
#
# The pressure squeezes Wally into a box.
#
# The holo-detector button buzzes and flashes.
#
# Auto calls up a LIDO DECK SECURITY CAMERA VIEW.
#
# Discovers Wally wedged in the device.
#
# Auto presses down on the “off” button.
#
# The holo-detector’s hydraulics fight against him.
#
# Wally desperately fights to hold it up.
#
# Begins slowly to expand himself...
#
# ...and push the holo-detector back up!!
#
# The Captain watches Wally’s heroic rise on screen.
#
# Auto flips out his TASER.
#
# Jams it into the “off” button.
#
# The holo-detector reverses full force.
#
# We can’t tell if he survived the crush.
#
# Eve calls out for him.
#
# Trapped, holding up the monorail car above the passengers.
#
# The Captain watches Wally being crushed.
#
# He braces his arms against the floor...
#
# ...and rises up on HIS OWN TWO FEET...
#
# The passengers collectively GASP.
#
# Their Captain is standing...
#
# ...and walking himself up the railing...
#
# Auto hears the distant cheering.
#
# Shocked to see the Captain standing (albeit wobbly).
#
# Finds himself face to face with him.
#
# Auto flips out his TASER.
#
# The Captain grabs it. They wrestle.
#
# The taser ARCS in the Captain’s face.
#
# He flinches. Looks up.
#
# Sees a CONTROL PANEL high up on Auto’s column...
#
# The Captain looks Auto in the eye.
#
# Raises a finger up to the control panel...
#
# ...to the “AUTOPILOT” BUTTON...
#
# ...and flicks the switch to “MANUAL”.
#
# Auto, you are relieved of duty.
#
# Auto is instantly turned off.
#
# The Captain smiles triumphantly.
#
# Grabs the wheel with both hands.
#
# Makes the ship level again.
#
# The passengers all spill across the deck.
#
# Eve sets the monorail down.
#
# Rockets over to the holo-detector.
#
# Wally is pinned under the lip of the holo-detector.
#
# Eve tries to lift it up.
#
# She looks back to the crowd.
#
# He searches the crowd for the plant.
#
# Humans begin to stand for the first time all around him.
#
# Through his POV he spots the plant mixed in among them.
#
# “FOREIGN CONTAMINANT” flashes on his display screen.
#
# She fights to keep the machine from crushing Wally further.
#
# M-O holds the plant up from across the Lido Deck.
#
# The vacu-bot shoots it into the hands of a passenger.
#
# Humans and robots form an impromptu fire line.
#
# Toss it up to Eve on stage.
#
# She shoves the plant into the device.
#
# The detector instantly scans the plant.
#
# Plant origin verified. Course set for
#
# Slowly, the holo-detector rises...
#
# Wally topples out from underneath.
#
# Badly crushed and leaking oil.
#
# Eve GASPS in horror.
#
# M-O and the Rejects avert their eyes.
#
# Passengers recoil as well.
#
# WIDE ON DOME CEILING
#
# It converts into a GIANT STAR CHART.
#
# Rapidly plots a course for Earth.
#
# Ten seconds to hyperjump.
#
# Eve lifts Wally up.
#
# No sign of life.
#
# M-O’s head drops in despair.
#
# The passengers witness grief for the first time.
#
# Begin to have new feelings of their own: sadness, sympathy.
#
# Mary begins to cry.
#
# Buries her head in John’s shoulder.
#
# Nine, eight, seven, six, five, four,
#
# three, two, one, zero.
#
# The ceiling countdown hits “0:00.”
#
# The ship jumps to light speed.
#
# The passengers and robots are thrown off their feet.
#
# Everyone holds on to one another.
#
# The Captain struggles to keep control of the steering wheel.
#
# Humans and robots hang on for dear life.
#
# John and Mary cling to each other and the babies.
#
# She holds tightly to Wally.
#
# Still calling out his name.
#
# The Axiom zooms through hyperspace.
#
# EXT. EARTH - HILLSIDE - DAY
#
# The cockroach waits obediently on the hill.
#
# Exactly where Wally told him to stay.
#
# His antennae twitch with boredom.
#
# appears on the ground.
#
# The cockroach watches the dot run down the hillside.
#
# The ground begins to shake.
#
# The insect looks to the sky.
#
# A DARK PATCH grows behind the clouds.
#
# Blots out the sunlight.
#
# The Axiom’s keel breaks through.
#
# Its shadow swallows up the entire landscape.
#
# The cockroach senses his master’s return.
#
# HUNDREDS OF RED DOTS rush past him.
#
# He eagerly chases after them.
#
# The city-size starliner lowers gracefully from the sky.
#
# Pushes back the clouds to the horizon.
#
# EXT. OPPOSITE SIDE OF BAY - AXIOM PORT
#
# The CIRCLE OF DOTS triangulate over the abandoned berth.
#
# Converge over the port’s LANDING SHAFT.
#
# Thousands of feet deep.
#
# The ship’s keel descends into it.
#
# Trash towers tumble in the distance.
#
# ...Then all is quiet.
#
# ON BELLY OF THE AXIOM
#
# A ROW OF GIANT DOORS open on the side of the ship.
#
# MULTIPLE GANGWAYS automatically extend.
#
# Connect with BUILT-IN TERMINALS on the port.
#
# The Captain walks out gingerly.
#
# Holding the boot w/ plant.
#
# The other passengers step out on their own legs.
#
# They squint up at the harsh sunlight.
#
# A commotion is heard from the back.
#
# Somebody trying to push through.
#
# appears out of the crowd.
#
# Cradles a BOXED UP WALLY in her arms.
#
# M-O and the Rejects follow behind her.
#
# They rush across the gangway.
#
# The cockroach meets up with Eve.
#
# Climbs up onto Wally.
#
# Doesn’t understand why his master isn’t responding.
#
# Eve urgently scans the landscape.
#
# Locks on to WALLY’S TRUCK in the distance.
#
# She takes to the air.
#
# M-O and the Rejects chase after her down the gangway.
#
# The Captain respectfully removes his hat.
#
# The interior is dark and still.
#
# Suddenly the junk jingles and clinks as the back door opens.
#
# Eve flies inside with Wally.
#
# Sets him on the floor.
#
# She scans the rotating shelves at high speed.
#
# Grabs a CAR JACK.
#
# Ratchets up Wally’s crushed body...
#
# ...SPARE PARTS being grabbed by Eve...
#
# ...Frantically installs the new parts into Wally...
#
# ...Her arms a blur of precision in motion...
#
# ...Replaces his damaged CIRCUIT BOARD. The final piece...
#
# ...She opens his new solar panels...
#
# ...and BLASTS a hole in the ceiling with her gun.
#
# OUT ON THE EMPTY BAY
#
# See the roof of Wally’s truck explode.
#
# BACK IN THE TRUCK
#
# A shaft of sunlight beams down on Wally.
#
# Eve holds her breath, watches...
#
# Wally’s meter fully charges.
#
# His head slowly rises from his box.
#
# The cockroach hops with joy.
#
# ...She holds out her hand to him.
#
# Wally gives her a blank stare.
#
# He turns away from Eve. Motors out the truck.
#
# Turns him back around.
#
# Doesn’t seem to know who she is.
#
# [Here, look at these.]
#
# She grabs the RUBIK’S CUBE and LIGHT BULB from the shelf.
#
# The light bulb glows in her hand.
#
# She gives them to Wally.
#
# Wally looks blankly at the junk on the shelves.
#
# She hovers over to the video player.
#
# Looks back to see if it has any effect.
#
# Wally is over at the shelves.
#
# Has scooped all his prized possessions into his compactor.
#
# Crushes them into a cube.
#
# Runs over the cockroach on his way out.
#
# The insect pops back to life.
#
# Watches his friend in shock.
#
# EXT. WALLY’S TRUCK - DAY
#
# Wally rolls up to a nearby trash pile.
#
# Scoops up trash. Spits out a cube.
#
# Eve hovers over to him.
#
# Wally continues to stack his cubes.
#
# Lifts his head. Stares into his eyes.
#
# Eve presses his “play” button.
#
# Eve begins to panic.
#
# She hovers in silence next to him for a long time...
#
# Finally, Eve grasps Wally’s hand.
#
# Forces his fingers to interlace with hers.
#
# Holds him close one last time.
#
# Leans her head against his.
#
# She touches her forehead to his.
#
# A TINY SPARK between them.
#
# Eve turns to hover away.
#
# Her fingers caught between his.
#
# She checks his eyes again.
#
# ...a tiny SERVO NOISE.
#
# She looks down at their hands.
#
# CLOSE ON WALLY’S FINGERS
#
# They start to move.
#
# Slowly close around Eve’s.
#
# She looks back at his face.
#
# Wally’s eyes gradually come into focus.
#
# He notices their hands entwined.
#
# His dream come true.
#
# The “Hello Dolly” tape reaches the finale of IOTAM.
#
# “And that is all that love’s about...”
#
# Eve and Wally stare into each other’s eyes.
#
# M-O and the Rejects finally reach the truck.
#
# They begin to celebrate.
#
# Then M-O realizes they need privacy.
#
# Herds the Rejects O.S.
#
# Go! Go, go go!
#
# Wally and Eve’s foreheads touch.
#
# Together now and ever more.
#
# “...and we’ll recall when time runs out...”
#
# CLOSE UP OF THE PLANT
#
# Newly planted in the earth.
#
# Small hands water it gently.
#
# PULL OUT to reveal it surrounded by kids.
#
# The Captain instructs them.
#
# John and Mary help unload equipment from the Axiom.
#
# Robots and passengers stream off the ship.
#
# This is called “farming”! You kids are
#
# going to grow all kinds of plants:
#
# vegetable plants, pizza plants!
#
# Ahh, it’s good to be home...
#
# The CAMERA PULLS OUT from the Axiom...
#
# “...That it only took a moment...”
#
# ...past Wally & Eve holding hands in his truck...
#
# ...over M-O and the Rejects cleaning outside...
#
# ...Through the trash towers of the city...
#
# ...past a FIELD OF PLANTS, sprouting from its peak...
#
# ...up through the cloud cover...
#
# “...To be loved a whole life long.”
